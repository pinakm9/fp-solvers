# %% [markdown]
# **Instructions for running this notebook on Colab**
# 1. Run the cell below to download code from GitHub and install correct version of Python modules
# 2. Restart session so that Colab can use the newly installed modules rather than their previously installed versions
# 3. Run all cells

# %%
# run this cell to download data and necessary modules
import os, shutil
repo = 'fp-solvers'
if os.path.isdir(repo):
  shutil.rmtree(repo)
# !git clone https://github.com/pinakm9/fp-solvers.git
# !pip install -r fp-solvers/requirements.txt 2> /dev/null
# Out:
# Cloning into 'fp-solvers'...
# remote: Enumerating objects: 14969, done.
# remote: Counting objects: 100% (339/339), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 14969 (delta 153), reused 313 (delta 135), pack-reused 14630
# Receiving objects: 100% (14969/14969), 805.75 MiB | 43.64 MiB/s, done.
# Resolving deltas: 100% (7308/7308), done.
# Updating files: 100% (14686/14686), done.
# /

# %%
# add modules folder to Python's search path
import os, sys
from pathlib import Path
script_dir = Path(os.path.dirname(os.path.abspath('')))
module_dir = str(script_dir)
sys.path.insert(0, repo + '/modules')
print(module_dir)

# import the rest of the modules
# %matplotlib nbagg
# %matplotlib inline
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import arch
import pandas as pd
import tensorflow_probability as tfp
import time  
import sim
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from mpl_toolkits.axes_grid1 import make_axes_locatable
tfd = tfp.distributions

# %% [markdown]
# **Set computation and plotting parameters**

# %%
# set up computation parameters
dim = 3
n_particles = int(1e7)
n_subdivs = 100
save_folder = '{}/non-grad3D/data/L63'.format(repo)
n_steps = 3
n_repeats = 200
dt = 0.01
alpha, beta, rho = 10., 8./3., 28.
t = dt * n_steps
max_comp = int(1e6)
quad_method = 'Gauss_Legendre'
n_int_subdivs = 120
degree = 10
DTYPE = 'float32'

# set up plotting parameters
scale = 15
xlabel_size = ylabel_size = 15 + scale
tick_size = 10 + scale
legend_size = 15 + scale
title_size = 15 + scale
cbar_tick_size = 10 + scale

# %% [markdown]
# **Define the problem: $\mu, \sigma, p_0$**

# %%
def mu(X):
    x, y, z = tf.split(X, [1, 1, 1], axis=-1)
    p = alpha * (y - x)
    q = x * (rho - z) - y 
    r = x * y - beta * z 
    return tf.concat([p, q, r], axis=-1)

def mu_np(X):
    x, y, z = np.split(X, dim, axis=-1)
    p = alpha * (y - x) 
    q = x * (rho - z) - y 
    r = x * y - beta * z
    return np.concatenate([p, q, r], axis=-1)

sigma = 10.
D = sigma**2 / 2.

l = np.ones(dim, dtype=DTYPE)
g1 = tfd.MultivariateNormalDiag(loc=2.*l, scale_diag=l)
g2 = tfd.MultivariateNormalDiag(loc=-2.*l, scale_diag=l)
mix = 0.5
rv0 = tfd.Mixture(cat=tfd.Categorical(probs=[mix, 1.-mix]), components=[g1, g2])
log_p0 = lambda x: tf.reshape(rv0.log_prob(x), (-1, 1))

# %% [markdown]
# **Set up Monte-Carlo solver**

# %%
X0 = rv0.sample(n_particles).numpy()
mc_prob = sim.MCProb(save_folder, n_subdivs, mu_np, sigma, X0)
mc_prob.ready(n_steps=n_steps, dt=dt, lims=None)
# Out:
# Time taken by propagate is 34.15375208854675 seconds
# Time taken by set_grid is 29.18740749359131 seconds
# Time taken by assign_pts is 36.767688035964966 seconds
# Time taken by ready is 100.10920691490173 seconds

# %% [markdown]
# **Load the neural network**

# %%
n_theta = arch.LSTMForgetNet(50, 3, tf.float32, name="L63")
n_theta.load_weights('{}/non-grad3D/data/L63/1M/{}'.format(repo, n_theta.name)).expect_partial()
X = tf.random.uniform(shape=(10, dim))
n_theta(*tf.split(X, dim, axis=-1))
# Out:
# <tf.Tensor: shape=(10, 1), dtype=float32, numpy=
# array([[2.6180246],
#        [2.5061002],
#        [2.4631143],
#        [2.7349823],
#        [2.711709 ],
#        [2.6634707],
#        [2.750279 ],
#        [2.42796  ],
#        [2.615157 ],
#        [2.3776321]], dtype=float32)>

# %% [markdown]
# **Compute, plot and save**

# %%
grid = mc_prob.get_grid()
low = grid.mins
high = grid.maxs
filter = mc_prob.save_folder + '/ensemble.csv'
prune = False

# define 6 subplots
fig_all = plt.figure(figsize=(30, 30))
ax_1l = fig_all.add_subplot(321) 
ax_1m = fig_all.add_subplot(322)
ax_2l = fig_all.add_subplot(323) 
ax_2m = fig_all.add_subplot(324)
ax_3l = fig_all.add_subplot(325) 
ax_3m = fig_all.add_subplot(326)

# position colorbars
div_1 = make_axes_locatable(ax_1l)
cax_1 = div_1.append_axes('right', '5%', '5%')
div_2 = make_axes_locatable(ax_2l)
cax_2 = div_2.append_axes('right', '5%', '5%')
div_3 = make_axes_locatable(ax_3l)
cax_3 = div_3.append_axes('right', '5%', '5%')
div_4 = make_axes_locatable(ax_1m)
cax_4 = div_4.append_axes('right', '5%', '5%')
div_5 = make_axes_locatable(ax_2m)
cax_5 = div_5.append_axes('right', '5%', '5%')
div_6 = make_axes_locatable(ax_3m)
cax_6 = div_6.append_axes('right', '5%', '5%')

# set label size
ax_1l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1l.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_2l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_2l.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_3l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3l.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='minor', labelsize=tick_size)

# write titles and labels
ax_1l.set_title('Learned solution at time = {:.2f}'.format(t), fontsize=title_size)
ax_1l.set_ylabel(r'$p(x, y)$', fontsize=ylabel_size)
ax_2l.set_ylabel(r'$p(y, z)$', fontsize=ylabel_size)
ax_3l.set_ylabel(r'$p(z, x)$', fontsize=ylabel_size)
ax_1m.set_title('Monte Carlo solution at time {:.2f}'.format(t), fontsize=title_size)
ax_1m.set_xlabel('x', fontsize=xlabel_size)
ax_1m.set_ylabel('y', fontsize=ylabel_size)
ax_2m.set_xlabel('y', fontsize=xlabel_size)
ax_2m.set_ylabel('z', fontsize=ylabel_size)
ax_3m.set_xlabel('z', fontsize=xlabel_size)
ax_3m.set_ylabel('x', fontsize=ylabel_size)



# compute, plot and save Monte-Carlo data
x = np.linspace(low[0], high[0], num=n_subdivs+1)[:-1].astype(DTYPE) + grid.h[0]/2. 
y = np.linspace(low[1], high[1], num=n_subdivs+1)[:-1].astype(DTYPE) + grid.h[1]/2.
z = np.linspace(low[2], high[2], num=n_subdivs+1)[:-1].astype(DTYPE) + grid.h[2]/2.
np.save('{}/x_t.npy'.format(save_folder), x)
np.save('{}/y_t.npy'.format(save_folder), y)
np.save('{}/z_t.npy'.format(save_folder), z)


p_1m = mc_prob.compute_p2(0, 1, save=False)
p_1m  /= (p_1m.sum() * grid.h[0] * grid.h[1])
np.save('{}/p_1m_t.npy'.format(save_folder), p_1m)
im = ax_1m.pcolormesh(x, y, p_1m.T, cmap='inferno', shading='auto')
cbar_1m = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
cbar_1m.ax.tick_params(labelsize=cbar_tick_size)
ax_1m.set_aspect("auto")


p_2m = mc_prob.compute_p2(1, 2, save=False)
p_2m  /= (p_2m.sum() * grid.h[1] * grid.h[2])
np.save('{}/p_2m_t.npy'.format(save_folder), p_2m)
im = ax_2m.pcolormesh(y, z, p_2m.T, cmap='inferno', shading='auto')
cbar_2m = fig_all.colorbar(im, cax=cax_5, ax=ax_2m)
cbar_2m.ax.tick_params(labelsize=cbar_tick_size)
ax_2m.set_aspect("auto")


p_3m = mc_prob.compute_p2(2, 0, save=False)
p_3m  /= (p_3m.sum() * grid.h[2] * grid.h[0])
np.save('{}/p_3m_t.npy'.format(save_folder), p_3m)
im = ax_3m.pcolormesh(z, x, p_3m.T, cmap='inferno', shading='auto')
cbar_3m = fig_all.colorbar(im, cax=cax_6, ax=ax_3m)
cbar_3m.ax.tick_params(labelsize=cbar_tick_size)
ax_3m.set_aspect("auto")


# set up Feynman-Kac procedure
fk = sim.FK32(save_folder=save_folder, n_subdivs=n_subdivs, n_int_subdivs=n_int_subdivs, mu=mu, sigma=sigma,\
               n_theta=n_theta, grid=grid, log_p0=log_p0, max_comp=max_comp)


# compute and save Feynman-Lac solution
nonzero_idx = list(zip(*np.where(p_1m > 0.)))
p_1l = fk.calc_2D_prob(n_steps, dt, n_repeats, 0, 1, filter=nonzero_idx, method=quad_method, prune=prune, num=n_int_subdivs, d=degree)
p_1l /= (p_1l.sum() * grid.h[0] * grid.h[1])
np.save('{}/p_1l_t.npy'.format(save_folder), p_1l)
# p_1l = np.load('{}/p_1l.npy'.format(save_folder))
im = ax_1l.pcolormesh(x, y, p_1l.T, cmap='inferno', shading='auto')
cbar_1l = fig_all.colorbar(im, cax=cax_1, ax=ax_1l)
cbar_1l.ax.tick_params(labelsize=cbar_tick_size)
ax_1l.set_aspect("auto")


nonzero_idx = list(zip(*np.where(p_2m > 0.)))
p_2l = fk.calc_2D_prob(n_steps, dt, n_repeats, 1, 2, filter=nonzero_idx, method=quad_method, prune=prune, num=n_int_subdivs, d=degree)
p_2l /= (p_2l.sum() *  grid.h[1] * grid.h[2])
np.save('{}/p_2l_t.npy'.format(save_folder), p_2l)
im = ax_2l.pcolormesh(y, z, p_2l.T, cmap='inferno')
cbar_2l = fig_all.colorbar(im, cax=cax_2, ax=ax_2l)
cbar_2l.ax.tick_params(labelsize=cbar_tick_size)
ax_2l.set_aspect("auto")


nonzero_idx = list(zip(*np.where(p_3m > 0.)))
p_3l = fk.calc_2D_prob(n_steps, dt, n_repeats, 2, 0, filter=nonzero_idx, method=quad_method, prune=prune, num=n_int_subdivs, d=degree)
p_3l /= (p_3l.sum() *  grid.h[2] * grid.h[0])
np.save('{}/p_3l_t.npy'.format(save_folder), p_3l)
im = ax_3l.pcolormesh(z, x, p_3l.T, cmap='inferno')
cbar_3l = fig_all.colorbar(im, cax=cax_3, ax=ax_3l)
cbar_3l.ax.tick_params(labelsize=cbar_tick_size)
ax_3l.set_aspect("auto")

# plot and save
fig_all.subplots_adjust(wspace=0.4, hspace=0.2)
plt.tight_layout()
plt.savefig('{}/plots/L63-time.png'.format(repo))
# Out:
# Streaming output truncated to the last 5000 lines.
# grid_index = (23, 31), time taken = 158.3673
# grid_index = (23, 32), time taken = 158.5529
# grid_index = (23, 33), time taken = 158.7406
# grid_index = (23, 34), time taken = 158.9282
# grid_index = (23, 35), time taken = 159.1138
# grid_index = (23, 36), time taken = 159.3000
# grid_index = (23, 37), time taken = 159.4854
# grid_index = (23, 38), time taken = 159.6717
# grid_index = (23, 39), time taken = 159.8566
# grid_index = (23, 40), time taken = 160.0427
# grid_index = (23, 41), time taken = 160.2280
# grid_index = (23, 42), time taken = 160.4151
# grid_index = (23, 43), time taken = 160.5990
# grid_index = (23, 44), time taken = 160.7861
# grid_index = (23, 45), time taken = 160.9693
# grid_index = (23, 46), time taken = 161.1545
# grid_index = (23, 47), time taken = 161.3397
# grid_index = (23, 48), time taken = 161.5246
# grid_index = (23, 49), time taken = 161.7090
# grid_index = (23, 50), time taken = 161.8962
# grid_index = (23, 51), time taken = 162.0829
# grid_index = (23, 52), time taken = 162.2704
# grid_index = (23, 53), time taken = 162.4573
# grid_index = (23, 54), time taken = 162.6442
# grid_index = (23, 55), time taken = 162.8312
# grid_index = (23, 56), time taken = 163.0195
# grid_index = (23, 57), time taken = 163.2070
# grid_index = (23, 58), time taken = 163.3993
# grid_index = (23, 59), time taken = 163.5945
# grid_index = (23, 60), time taken = 163.7857
# grid_index = (23, 61), time taken = 163.9790
# grid_index = (23, 62), time taken = 164.1683
# grid_index = (23, 63), time taken = 164.3589
# grid_index = (23, 64), time taken = 164.5466
# grid_index = (23, 65), time taken = 164.7338
# grid_index = (23, 66), time taken = 164.9219
# grid_index = (23, 67), time taken = 165.1138
# grid_index = (23, 68), time taken = 165.3014
# grid_index = (23, 69), time taken = 165.4897
# grid_index = (23, 71), time taken = 165.6775
# grid_index = (23, 73), time taken = 165.8629
# grid_index = (23, 74), time taken = 166.0524
# grid_index = (23, 75), time taken = 166.2403
# grid_index = (24, 4), time taken = 166.4306
# grid_index = (24, 12), time taken = 166.6163
# grid_index = (24, 13), time taken = 166.8019
# grid_index = (24, 14), time taken = 166.9892
# grid_index = (24, 15), time taken = 167.1812
# grid_index = (24, 16), time taken = 167.3669
# grid_index = (24, 17), time taken = 167.5564
# grid_index = (24, 18), time taken = 167.7429
# grid_index = (24, 19), time taken = 167.9328
# grid_index = (24, 20), time taken = 168.1206
# grid_index = (24, 21), time taken = 168.3095
# grid_index = (24, 22), time taken = 168.4962
# grid_index = (24, 23), time taken = 168.6841
# grid_index = (24, 24), time taken = 168.8731
# grid_index = (24, 25), time taken = 169.0607
# grid_index = (24, 26), time taken = 169.2454
# grid_index = (24, 27), time taken = 169.4254
# grid_index = (24, 28), time taken = 169.6077
# grid_index = (24, 29), time taken = 169.7941
# grid_index = (24, 30), time taken = 169.9817
# grid_index = (24, 31), time taken = 170.1696
# grid_index = (24, 32), time taken = 170.3565
# grid_index = (24, 33), time taken = 170.5449
# grid_index = (24, 34), time taken = 170.7323
# grid_index = (24, 35), time taken = 170.9203
# grid_index = (24, 36), time taken = 171.1078
# grid_index = (24, 37), time taken = 171.2955
# grid_index = (24, 38), time taken = 171.4828
# grid_index = (24, 39), time taken = 171.6689
# grid_index = (24, 40), time taken = 171.8571
# grid_index = (24, 41), time taken = 172.0443
# grid_index = (24, 42), time taken = 172.2312
# grid_index = (24, 43), time taken = 172.4207
# grid_index = (24, 44), time taken = 172.6085
# grid_index = (24, 45), time taken = 172.7982
# grid_index = (24, 46), time taken = 172.9875
# grid_index = (24, 47), time taken = 173.1772
# grid_index = (24, 48), time taken = 173.3656
# grid_index = (24, 49), time taken = 173.5523
# grid_index = (24, 50), time taken = 173.7390
# grid_index = (24, 51), time taken = 173.9271
# grid_index = (24, 52), time taken = 174.1158
# grid_index = (24, 53), time taken = 174.3083
# grid_index = (24, 54), time taken = 174.5008
# grid_index = (24, 55), time taken = 174.6871
# grid_index = (24, 56), time taken = 174.8724
# grid_index = (24, 57), time taken = 175.0597
# grid_index = (24, 58), time taken = 175.2469
# grid_index = (24, 59), time taken = 175.4388
# grid_index = (24, 60), time taken = 175.6247
# grid_index = (24, 61), time taken = 175.8139
# grid_index = (24, 62), time taken = 176.0011
# grid_index = (24, 63), time taken = 176.1885
# grid_index = (24, 64), time taken = 176.3755
# grid_index = (24, 65), time taken = 176.5622
# grid_index = (24, 66), time taken = 176.7517
# grid_index = (24, 67), time taken = 176.9395
# grid_index = (24, 68), time taken = 177.1305
# grid_index = (24, 69), time taken = 177.3209
# grid_index = (24, 70), time taken = 177.5077
# grid_index = (24, 72), time taken = 177.6951
# grid_index = (24, 75), time taken = 177.8835
# grid_index = (25, 13), time taken = 178.0723
# grid_index = (25, 14), time taken = 178.2607
# grid_index = (25, 15), time taken = 178.4452
# grid_index = (25, 16), time taken = 178.6327
# grid_index = (25, 17), time taken = 178.8221
# grid_index = (25, 18), time taken = 179.0128
# grid_index = (25, 19), time taken = 179.2010
# grid_index = (25, 20), time taken = 179.3875
# grid_index = (25, 21), time taken = 179.5751
# grid_index = (25, 22), time taken = 179.7608
# grid_index = (25, 23), time taken = 179.9486
# grid_index = (25, 24), time taken = 180.1344
# grid_index = (25, 25), time taken = 180.3216
# grid_index = (25, 26), time taken = 180.5059
# grid_index = (25, 27), time taken = 180.6939
# grid_index = (25, 28), time taken = 180.8816
# grid_index = (25, 29), time taken = 181.0694
# grid_index = (25, 30), time taken = 181.2563
# grid_index = (25, 31), time taken = 181.4417
# grid_index = (25, 32), time taken = 181.6269
# grid_index = (25, 33), time taken = 181.8117
# grid_index = (25, 34), time taken = 181.9975
# grid_index = (25, 35), time taken = 182.1869
# grid_index = (25, 36), time taken = 182.3727
# grid_index = (25, 37), time taken = 182.5599
# grid_index = (25, 38), time taken = 182.7478
# grid_index = (25, 39), time taken = 182.9356
# grid_index = (25, 40), time taken = 183.1236
# grid_index = (25, 41), time taken = 183.3130
# grid_index = (25, 42), time taken = 183.4982
# grid_index = (25, 43), time taken = 183.6825
# grid_index = (25, 44), time taken = 183.8681
# grid_index = (25, 45), time taken = 184.0539
# grid_index = (25, 46), time taken = 184.2398
# grid_index = (25, 47), time taken = 184.4250
# grid_index = (25, 48), time taken = 184.6107
# grid_index = (25, 49), time taken = 184.7949
# grid_index = (25, 50), time taken = 184.9850
# grid_index = (25, 51), time taken = 185.1723
# grid_index = (25, 52), time taken = 185.3596
# grid_index = (25, 53), time taken = 185.5513
# grid_index = (25, 54), time taken = 185.7400
# grid_index = (25, 55), time taken = 185.9315
# grid_index = (25, 56), time taken = 186.1196
# grid_index = (25, 57), time taken = 186.3092
# grid_index = (25, 58), time taken = 186.4969
# grid_index = (25, 59), time taken = 186.6839
# grid_index = (25, 60), time taken = 186.8686
# grid_index = (25, 61), time taken = 187.0565
# grid_index = (25, 62), time taken = 187.2435
# grid_index = (25, 63), time taken = 187.4314
# grid_index = (25, 64), time taken = 187.6145
# grid_index = (25, 65), time taken = 187.7983
# grid_index = (25, 66), time taken = 187.9844
# grid_index = (25, 67), time taken = 188.1688
# grid_index = (25, 68), time taken = 188.3545
# grid_index = (25, 69), time taken = 188.5413
# grid_index = (25, 70), time taken = 188.7275
# grid_index = (25, 71), time taken = 188.9129
# grid_index = (25, 72), time taken = 189.0997
# grid_index = (25, 73), time taken = 189.2846
# grid_index = (25, 75), time taken = 189.4729
# grid_index = (25, 76), time taken = 189.6602
# grid_index = (25, 77), time taken = 189.8521
# grid_index = (25, 82), time taken = 190.0400
# grid_index = (26, 7), time taken = 190.2263
# grid_index = (26, 9), time taken = 190.4150
# grid_index = (26, 11), time taken = 190.6016
# grid_index = (26, 12), time taken = 190.7887
# grid_index = (26, 13), time taken = 190.9768
# grid_index = (26, 14), time taken = 191.1661
# grid_index = (26, 15), time taken = 191.3557
# grid_index = (26, 16), time taken = 191.5448
# grid_index = (26, 17), time taken = 191.7317
# grid_index = (26, 18), time taken = 191.9213
# grid_index = (26, 19), time taken = 192.1087
# grid_index = (26, 20), time taken = 192.2980
# grid_index = (26, 21), time taken = 192.4861
# grid_index = (26, 22), time taken = 192.6717
# grid_index = (26, 23), time taken = 192.8584
# grid_index = (26, 24), time taken = 193.0458
# grid_index = (26, 25), time taken = 193.2299
# grid_index = (26, 26), time taken = 193.4187
# grid_index = (26, 27), time taken = 193.6079
# grid_index = (26, 28), time taken = 193.7941
# grid_index = (26, 29), time taken = 193.9809
# grid_index = (26, 30), time taken = 194.1667
# grid_index = (26, 31), time taken = 194.3533
# grid_index = (26, 32), time taken = 194.5404
# grid_index = (26, 33), time taken = 194.7277
# grid_index = (26, 34), time taken = 194.9153
# grid_index = (26, 35), time taken = 195.1018
# grid_index = (26, 36), time taken = 195.2917
# grid_index = (26, 37), time taken = 195.4753
# grid_index = (26, 38), time taken = 195.6610
# grid_index = (26, 39), time taken = 195.8451
# grid_index = (26, 40), time taken = 196.0303
# grid_index = (26, 41), time taken = 196.2173
# grid_index = (26, 42), time taken = 196.4037
# grid_index = (26, 43), time taken = 196.5906
# grid_index = (26, 44), time taken = 196.7777
# grid_index = (26, 45), time taken = 196.9664
# grid_index = (26, 46), time taken = 197.1538
# grid_index = (26, 47), time taken = 197.3414
# grid_index = (26, 48), time taken = 197.5329
# grid_index = (26, 49), time taken = 197.7209
# grid_index = (26, 50), time taken = 197.9096
# grid_index = (26, 51), time taken = 198.1006
# grid_index = (26, 52), time taken = 198.2868
# grid_index = (26, 53), time taken = 198.4742
# grid_index = (26, 54), time taken = 198.6642
# grid_index = (26, 55), time taken = 198.8554
# grid_index = (26, 56), time taken = 199.0441
# grid_index = (26, 57), time taken = 199.2321
# grid_index = (26, 58), time taken = 199.4214
# grid_index = (26, 59), time taken = 199.6093
# grid_index = (26, 60), time taken = 199.7975
# grid_index = (26, 61), time taken = 199.9864
# grid_index = (26, 62), time taken = 200.1760
# grid_index = (26, 63), time taken = 200.3647
# grid_index = (26, 64), time taken = 200.5524
# grid_index = (26, 65), time taken = 200.7393
# grid_index = (26, 66), time taken = 200.9259
# grid_index = (26, 67), time taken = 201.1147
# grid_index = (26, 68), time taken = 201.3031
# grid_index = (26, 69), time taken = 201.4899
# grid_index = (26, 70), time taken = 201.6762
# grid_index = (26, 71), time taken = 201.8622
# grid_index = (26, 72), time taken = 202.0496
# grid_index = (26, 73), time taken = 202.2376
# grid_index = (26, 74), time taken = 202.4241
# grid_index = (26, 76), time taken = 202.6127
# grid_index = (26, 77), time taken = 202.8031
# grid_index = (26, 81), time taken = 202.9934
# grid_index = (27, 11), time taken = 203.1814
# grid_index = (27, 12), time taken = 203.3687
# grid_index = (27, 13), time taken = 203.5563
# grid_index = (27, 14), time taken = 203.7425
# grid_index = (27, 15), time taken = 203.9303
# grid_index = (27, 16), time taken = 204.1163
# grid_index = (27, 17), time taken = 204.3037
# grid_index = (27, 18), time taken = 204.4906
# grid_index = (27, 19), time taken = 204.6790
# grid_index = (27, 20), time taken = 204.8670
# grid_index = (27, 21), time taken = 205.0530
# grid_index = (27, 22), time taken = 205.2419
# grid_index = (27, 23), time taken = 205.4306
# grid_index = (27, 24), time taken = 205.6177
# grid_index = (27, 25), time taken = 205.8024
# grid_index = (27, 26), time taken = 205.9875
# grid_index = (27, 27), time taken = 206.1751
# grid_index = (27, 28), time taken = 206.3644
# grid_index = (27, 29), time taken = 206.5509
# grid_index = (27, 30), time taken = 206.7370
# grid_index = (27, 31), time taken = 206.9240
# grid_index = (27, 32), time taken = 207.1105
# grid_index = (27, 33), time taken = 207.2979
# grid_index = (27, 34), time taken = 207.4878
# grid_index = (27, 35), time taken = 207.6773
# grid_index = (27, 36), time taken = 207.8679
# grid_index = (27, 37), time taken = 208.0563
# grid_index = (27, 38), time taken = 208.2419
# grid_index = (27, 39), time taken = 208.4285
# grid_index = (27, 40), time taken = 208.6139
# grid_index = (27, 41), time taken = 208.8023
# grid_index = (27, 42), time taken = 208.9995
# grid_index = (27, 43), time taken = 209.1890
# grid_index = (27, 44), time taken = 209.3747
# grid_index = (27, 45), time taken = 209.5656
# grid_index = (27, 46), time taken = 209.7582
# grid_index = (27, 47), time taken = 209.9676
# grid_index = (27, 48), time taken = 210.1548
# grid_index = (27, 49), time taken = 210.3465
# grid_index = (27, 50), time taken = 210.5324
# grid_index = (27, 51), time taken = 210.7192
# grid_index = (27, 52), time taken = 210.9056
# grid_index = (27, 53), time taken = 211.0935
# grid_index = (27, 54), time taken = 211.2784
# grid_index = (27, 55), time taken = 211.4647
# grid_index = (27, 56), time taken = 211.6501
# grid_index = (27, 57), time taken = 211.8356
# grid_index = (27, 58), time taken = 212.0193
# grid_index = (27, 59), time taken = 212.2049
# grid_index = (27, 60), time taken = 212.3897
# grid_index = (27, 61), time taken = 212.5753
# grid_index = (27, 62), time taken = 212.7636
# grid_index = (27, 63), time taken = 212.9528
# grid_index = (27, 64), time taken = 213.1410
# grid_index = (27, 65), time taken = 213.3319
# grid_index = (27, 66), time taken = 213.5225
# grid_index = (27, 67), time taken = 213.7136
# grid_index = (27, 68), time taken = 213.9018
# grid_index = (27, 69), time taken = 214.0898
# grid_index = (27, 70), time taken = 214.2783
# grid_index = (27, 71), time taken = 214.4677
# grid_index = (27, 72), time taken = 214.6548
# grid_index = (27, 73), time taken = 214.8447
# grid_index = (27, 74), time taken = 215.0353
# grid_index = (27, 75), time taken = 215.2249
# grid_index = (27, 76), time taken = 215.4127
# grid_index = (27, 77), time taken = 215.6001
# grid_index = (27, 78), time taken = 215.7926
# grid_index = (27, 79), time taken = 215.9812
# grid_index = (27, 85), time taken = 216.1684
# grid_index = (28, 6), time taken = 216.3564
# grid_index = (28, 11), time taken = 216.5444
# grid_index = (28, 12), time taken = 216.7309
# grid_index = (28, 13), time taken = 216.9192
# grid_index = (28, 14), time taken = 217.1069
# grid_index = (28, 15), time taken = 217.2944
# grid_index = (28, 16), time taken = 217.4822
# grid_index = (28, 17), time taken = 217.6703
# grid_index = (28, 18), time taken = 217.8565
# grid_index = (28, 19), time taken = 218.0460
# grid_index = (28, 20), time taken = 218.2336
# grid_index = (28, 21), time taken = 218.4207
# grid_index = (28, 22), time taken = 218.6107
# grid_index = (28, 23), time taken = 218.7989
# grid_index = (28, 24), time taken = 218.9862
# grid_index = (28, 25), time taken = 219.1732
# grid_index = (28, 26), time taken = 219.3618
# grid_index = (28, 27), time taken = 219.5505
# grid_index = (28, 28), time taken = 219.7383
# grid_index = (28, 29), time taken = 219.9276
# grid_index = (28, 30), time taken = 220.1171
# grid_index = (28, 31), time taken = 220.3068
# grid_index = (28, 32), time taken = 220.4967
# grid_index = (28, 33), time taken = 220.6833
# grid_index = (28, 34), time taken = 220.8695
# grid_index = (28, 35), time taken = 221.0588
# grid_index = (28, 36), time taken = 221.2455
# grid_index = (28, 37), time taken = 221.4330
# grid_index = (28, 38), time taken = 221.6200
# grid_index = (28, 39), time taken = 221.8084
# grid_index = (28, 40), time taken = 221.9941
# grid_index = (28, 41), time taken = 222.1801
# grid_index = (28, 42), time taken = 222.3693
# grid_index = (28, 43), time taken = 222.5569
# grid_index = (28, 44), time taken = 222.7422
# grid_index = (28, 45), time taken = 222.9289
# grid_index = (28, 46), time taken = 223.1180
# grid_index = (28, 47), time taken = 223.3077
# grid_index = (28, 48), time taken = 223.4948
# grid_index = (28, 49), time taken = 223.6824
# grid_index = (28, 50), time taken = 223.8726
# grid_index = (28, 51), time taken = 224.0624
# grid_index = (28, 52), time taken = 224.2507
# grid_index = (28, 53), time taken = 224.4396
# grid_index = (28, 54), time taken = 224.6314
# grid_index = (28, 55), time taken = 224.8179
# grid_index = (28, 56), time taken = 225.0055
# grid_index = (28, 57), time taken = 225.1928
# grid_index = (28, 58), time taken = 225.3804
# grid_index = (28, 59), time taken = 225.5695
# grid_index = (28, 60), time taken = 225.7556
# grid_index = (28, 61), time taken = 225.9432
# grid_index = (28, 62), time taken = 226.1296
# grid_index = (28, 63), time taken = 226.3178
# grid_index = (28, 64), time taken = 226.5066
# grid_index = (28, 65), time taken = 226.6946
# grid_index = (28, 66), time taken = 226.8810
# grid_index = (28, 67), time taken = 227.0683
# grid_index = (28, 68), time taken = 227.2560
# grid_index = (28, 69), time taken = 227.4432
# grid_index = (28, 70), time taken = 227.6336
# grid_index = (28, 71), time taken = 227.8199
# grid_index = (28, 72), time taken = 228.0076
# grid_index = (28, 73), time taken = 228.1947
# grid_index = (28, 74), time taken = 228.3835
# grid_index = (28, 75), time taken = 228.5732
# grid_index = (28, 76), time taken = 228.7655
# grid_index = (28, 77), time taken = 228.9532
# grid_index = (28, 79), time taken = 229.1408
# grid_index = (29, 7), time taken = 229.3345
# grid_index = (29, 12), time taken = 229.5208
# grid_index = (29, 13), time taken = 229.7131
# grid_index = (29, 14), time taken = 229.8985
# grid_index = (29, 15), time taken = 230.0875
# grid_index = (29, 16), time taken = 230.2734
# grid_index = (29, 17), time taken = 230.4618
# grid_index = (29, 18), time taken = 230.6509
# grid_index = (29, 19), time taken = 230.8399
# grid_index = (29, 20), time taken = 231.0287
# grid_index = (29, 21), time taken = 231.2168
# grid_index = (29, 22), time taken = 231.4036
# grid_index = (29, 23), time taken = 231.5903
# grid_index = (29, 24), time taken = 231.7770
# grid_index = (29, 25), time taken = 231.9679
# grid_index = (29, 26), time taken = 232.1556
# grid_index = (29, 27), time taken = 232.3431
# grid_index = (29, 28), time taken = 232.5296
# grid_index = (29, 29), time taken = 232.7184
# grid_index = (29, 30), time taken = 232.9050
# grid_index = (29, 31), time taken = 233.0914
# grid_index = (29, 32), time taken = 233.2824
# grid_index = (29, 33), time taken = 233.4679
# grid_index = (29, 34), time taken = 233.6556
# grid_index = (29, 35), time taken = 233.8449
# grid_index = (29, 36), time taken = 234.0325
# grid_index = (29, 37), time taken = 234.2196
# grid_index = (29, 38), time taken = 234.4075
# grid_index = (29, 39), time taken = 234.5941
# grid_index = (29, 40), time taken = 234.7798
# grid_index = (29, 41), time taken = 234.9667
# grid_index = (29, 42), time taken = 235.1523
# grid_index = (29, 43), time taken = 235.3390
# grid_index = (29, 44), time taken = 235.5269
# grid_index = (29, 45), time taken = 235.7121
# grid_index = (29, 46), time taken = 235.9007
# grid_index = (29, 47), time taken = 236.0893
# grid_index = (29, 48), time taken = 236.2787
# grid_index = (29, 49), time taken = 236.4672
# grid_index = (29, 50), time taken = 236.6565
# grid_index = (29, 51), time taken = 236.8410
# grid_index = (29, 52), time taken = 237.0277
# grid_index = (29, 53), time taken = 237.2142
# grid_index = (29, 54), time taken = 237.4014
# grid_index = (29, 55), time taken = 237.5873
# grid_index = (29, 56), time taken = 237.7742
# grid_index = (29, 57), time taken = 237.9612
# grid_index = (29, 58), time taken = 238.1504
# grid_index = (29, 59), time taken = 238.3385
# grid_index = (29, 60), time taken = 238.5256
# grid_index = (29, 61), time taken = 238.7125
# grid_index = (29, 62), time taken = 238.9016
# grid_index = (29, 63), time taken = 239.0878
# grid_index = (29, 64), time taken = 239.2785
# grid_index = (29, 65), time taken = 239.4666
# grid_index = (29, 66), time taken = 239.6540
# grid_index = (29, 67), time taken = 239.8415
# grid_index = (29, 68), time taken = 240.0273
# grid_index = (29, 69), time taken = 240.2145
# grid_index = (29, 70), time taken = 240.4020
# grid_index = (29, 71), time taken = 240.5875
# grid_index = (29, 72), time taken = 240.7758
# grid_index = (29, 73), time taken = 240.9609
# grid_index = (29, 74), time taken = 241.1490
# grid_index = (29, 75), time taken = 241.3365
# grid_index = (29, 76), time taken = 241.5268
# grid_index = (29, 77), time taken = 241.7156
# grid_index = (29, 78), time taken = 241.9057
# grid_index = (29, 79), time taken = 242.0943
# grid_index = (29, 81), time taken = 242.2812
# grid_index = (30, 9), time taken = 242.4676
# grid_index = (30, 10), time taken = 242.6540
# grid_index = (30, 11), time taken = 242.8381
# grid_index = (30, 12), time taken = 243.0242
# grid_index = (30, 13), time taken = 243.2101
# grid_index = (30, 14), time taken = 243.4060
# grid_index = (30, 15), time taken = 243.5952
# grid_index = (30, 16), time taken = 243.7829
# grid_index = (30, 17), time taken = 243.9710
# grid_index = (30, 18), time taken = 244.1595
# grid_index = (30, 19), time taken = 244.3442
# grid_index = (30, 20), time taken = 244.5313
# grid_index = (30, 21), time taken = 244.7179
# grid_index = (30, 22), time taken = 244.9064
# grid_index = (30, 23), time taken = 245.0946
# grid_index = (30, 24), time taken = 245.2834
# grid_index = (30, 25), time taken = 245.4676
# grid_index = (30, 26), time taken = 245.6537
# grid_index = (30, 27), time taken = 245.8411
# grid_index = (30, 28), time taken = 246.0294
# grid_index = (30, 29), time taken = 246.2151
# grid_index = (30, 30), time taken = 246.4006
# grid_index = (30, 31), time taken = 246.5845
# grid_index = (30, 32), time taken = 246.7731
# grid_index = (30, 33), time taken = 246.9615
# grid_index = (30, 34), time taken = 247.1476
# grid_index = (30, 35), time taken = 247.3324
# grid_index = (30, 36), time taken = 247.5180
# grid_index = (30, 37), time taken = 247.7022
# grid_index = (30, 38), time taken = 247.8894
# grid_index = (30, 39), time taken = 248.0775
# grid_index = (30, 40), time taken = 248.2652
# grid_index = (30, 41), time taken = 248.4524
# grid_index = (30, 42), time taken = 248.6386
# grid_index = (30, 43), time taken = 248.8259
# grid_index = (30, 44), time taken = 249.0165
# grid_index = (30, 45), time taken = 249.2041
# grid_index = (30, 46), time taken = 249.3936
# grid_index = (30, 47), time taken = 249.5809
# grid_index = (30, 48), time taken = 249.7671
# grid_index = (30, 49), time taken = 249.9544
# grid_index = (30, 50), time taken = 250.1428
# grid_index = (30, 51), time taken = 250.3282
# grid_index = (30, 52), time taken = 250.5159
# grid_index = (30, 53), time taken = 250.7028
# grid_index = (30, 54), time taken = 250.8883
# grid_index = (30, 55), time taken = 251.0749
# grid_index = (30, 56), time taken = 251.2599
# grid_index = (30, 57), time taken = 251.4495
# grid_index = (30, 58), time taken = 251.6355
# grid_index = (30, 59), time taken = 251.8237
# grid_index = (30, 60), time taken = 252.0098
# grid_index = (30, 61), time taken = 252.1945
# grid_index = (30, 62), time taken = 252.3821
# grid_index = (30, 63), time taken = 252.5675
# grid_index = (30, 64), time taken = 252.7512
# grid_index = (30, 65), time taken = 252.9356
# grid_index = (30, 66), time taken = 253.1207
# grid_index = (30, 67), time taken = 253.3039
# grid_index = (30, 68), time taken = 253.4883
# grid_index = (30, 69), time taken = 253.6704
# grid_index = (30, 70), time taken = 253.8530
# grid_index = (30, 71), time taken = 254.0353
# grid_index = (30, 72), time taken = 254.2210
# grid_index = (30, 73), time taken = 254.4054
# grid_index = (30, 74), time taken = 254.5906
# grid_index = (30, 75), time taken = 254.7769
# grid_index = (30, 76), time taken = 254.9678
# grid_index = (30, 77), time taken = 255.1549
# grid_index = (30, 79), time taken = 255.3451
# grid_index = (30, 82), time taken = 255.5319
# grid_index = (31, 7), time taken = 255.7196
# grid_index = (31, 9), time taken = 255.9055
# grid_index = (31, 10), time taken = 256.0932
# grid_index = (31, 11), time taken = 256.2817
# grid_index = (31, 12), time taken = 256.4671
# grid_index = (31, 13), time taken = 256.6530
# grid_index = (31, 14), time taken = 256.8387
# grid_index = (31, 15), time taken = 257.0236
# grid_index = (31, 16), time taken = 257.2105
# grid_index = (31, 17), time taken = 257.3985
# grid_index = (31, 18), time taken = 257.5849
# grid_index = (31, 19), time taken = 257.7699
# grid_index = (31, 20), time taken = 257.9563
# grid_index = (31, 21), time taken = 258.1409
# grid_index = (31, 22), time taken = 258.3298
# grid_index = (31, 23), time taken = 258.5178
# grid_index = (31, 24), time taken = 258.7015
# grid_index = (31, 25), time taken = 258.8856
# grid_index = (31, 26), time taken = 259.0693
# grid_index = (31, 27), time taken = 259.2556
# grid_index = (31, 28), time taken = 259.4436
# grid_index = (31, 29), time taken = 259.6299
# grid_index = (31, 30), time taken = 259.8176
# grid_index = (31, 31), time taken = 260.0059
# grid_index = (31, 32), time taken = 260.1926
# grid_index = (31, 33), time taken = 260.3812
# grid_index = (31, 34), time taken = 260.5683
# grid_index = (31, 35), time taken = 260.7534
# grid_index = (31, 36), time taken = 260.9400
# grid_index = (31, 37), time taken = 261.1239
# grid_index = (31, 38), time taken = 261.3105
# grid_index = (31, 39), time taken = 261.4970
# grid_index = (31, 40), time taken = 261.6847
# grid_index = (31, 41), time taken = 261.8706
# grid_index = (31, 42), time taken = 262.0575
# grid_index = (31, 43), time taken = 262.2447
# grid_index = (31, 44), time taken = 262.4317
# grid_index = (31, 45), time taken = 262.6180
# grid_index = (31, 46), time taken = 262.8066
# grid_index = (31, 47), time taken = 262.9922
# grid_index = (31, 48), time taken = 263.1788
# grid_index = (31, 49), time taken = 263.3655
# grid_index = (31, 50), time taken = 263.5509
# grid_index = (31, 51), time taken = 263.7360
# grid_index = (31, 52), time taken = 263.9230
# grid_index = (31, 53), time taken = 264.1096
# grid_index = (31, 54), time taken = 264.2973
# grid_index = (31, 55), time taken = 264.4825
# grid_index = (31, 56), time taken = 264.6697
# grid_index = (31, 57), time taken = 264.8541
# grid_index = (31, 58), time taken = 265.0385
# grid_index = (31, 59), time taken = 265.2262
# grid_index = (31, 60), time taken = 265.4125
# grid_index = (31, 61), time taken = 265.6034
# grid_index = (31, 62), time taken = 265.7900
# grid_index = (31, 63), time taken = 265.9743
# grid_index = (31, 64), time taken = 266.1589
# grid_index = (31, 65), time taken = 266.3454
# grid_index = (31, 66), time taken = 266.5318
# grid_index = (31, 67), time taken = 266.7179
# grid_index = (31, 68), time taken = 266.9069
# grid_index = (31, 69), time taken = 267.0938
# grid_index = (31, 70), time taken = 267.2845
# grid_index = (31, 71), time taken = 267.4748
# grid_index = (31, 72), time taken = 267.6625
# grid_index = (31, 73), time taken = 267.8559
# grid_index = (31, 74), time taken = 268.0428
# grid_index = (31, 75), time taken = 268.2323
# grid_index = (31, 76), time taken = 268.4195
# grid_index = (31, 77), time taken = 268.6068
# grid_index = (31, 78), time taken = 268.7962
# grid_index = (31, 79), time taken = 268.9847
# grid_index = (31, 80), time taken = 269.1722
# grid_index = (31, 81), time taken = 269.3606
# grid_index = (31, 85), time taken = 269.5502
# grid_index = (32, 7), time taken = 269.7356
# grid_index = (32, 9), time taken = 269.9232
# grid_index = (32, 10), time taken = 270.1130
# grid_index = (32, 11), time taken = 270.3042
# grid_index = (32, 12), time taken = 270.4907
# grid_index = (32, 13), time taken = 270.6764
# grid_index = (32, 14), time taken = 270.8625
# grid_index = (32, 15), time taken = 271.0477
# grid_index = (32, 16), time taken = 271.2374
# grid_index = (32, 17), time taken = 271.4221
# grid_index = (32, 18), time taken = 271.6081
# grid_index = (32, 19), time taken = 271.7982
# grid_index = (32, 20), time taken = 271.9866
# grid_index = (32, 21), time taken = 272.1747
# grid_index = (32, 22), time taken = 272.3590
# grid_index = (32, 23), time taken = 272.5453
# grid_index = (32, 24), time taken = 272.7299
# grid_index = (32, 25), time taken = 272.9158
# grid_index = (32, 26), time taken = 273.1022
# grid_index = (32, 27), time taken = 273.2922
# grid_index = (32, 28), time taken = 273.4773
# grid_index = (32, 29), time taken = 273.6629
# grid_index = (32, 30), time taken = 273.8498
# grid_index = (32, 31), time taken = 274.0401
# grid_index = (32, 32), time taken = 274.2281
# grid_index = (32, 33), time taken = 274.4173
# grid_index = (32, 34), time taken = 274.6020
# grid_index = (32, 35), time taken = 274.7883
# grid_index = (32, 36), time taken = 274.9744
# grid_index = (32, 37), time taken = 275.1600
# grid_index = (32, 38), time taken = 275.3474
# grid_index = (32, 39), time taken = 275.5321
# grid_index = (32, 40), time taken = 275.7170
# grid_index = (32, 41), time taken = 275.9048
# grid_index = (32, 42), time taken = 276.0918
# grid_index = (32, 43), time taken = 276.2809
# grid_index = (32, 44), time taken = 276.4651
# grid_index = (32, 45), time taken = 276.6515
# grid_index = (32, 46), time taken = 276.8399
# grid_index = (32, 47), time taken = 277.0277
# grid_index = (32, 48), time taken = 277.2150
# grid_index = (32, 49), time taken = 277.4034
# grid_index = (32, 50), time taken = 277.5904
# grid_index = (32, 51), time taken = 277.7778
# grid_index = (32, 52), time taken = 277.9677
# grid_index = (32, 53), time taken = 278.1600
# grid_index = (32, 54), time taken = 278.3468
# grid_index = (32, 55), time taken = 278.5328
# grid_index = (32, 56), time taken = 278.7181
# grid_index = (32, 57), time taken = 278.9039
# grid_index = (32, 58), time taken = 279.0974
# grid_index = (32, 59), time taken = 279.2864
# grid_index = (32, 60), time taken = 279.4706
# grid_index = (32, 61), time taken = 279.6576
# grid_index = (32, 62), time taken = 279.8454
# grid_index = (32, 63), time taken = 280.0304
# grid_index = (32, 64), time taken = 280.2179
# grid_index = (32, 65), time taken = 280.4042
# grid_index = (32, 66), time taken = 280.5893
# grid_index = (32, 67), time taken = 280.7787
# grid_index = (32, 68), time taken = 280.9670
# grid_index = (32, 69), time taken = 281.1545
# grid_index = (32, 70), time taken = 281.3410
# grid_index = (32, 71), time taken = 281.5256
# grid_index = (32, 72), time taken = 281.7117
# grid_index = (32, 73), time taken = 281.8980
# grid_index = (32, 74), time taken = 282.0827
# grid_index = (32, 75), time taken = 282.2695
# grid_index = (32, 76), time taken = 282.4535
# grid_index = (32, 77), time taken = 282.6379
# grid_index = (32, 78), time taken = 282.8224
# grid_index = (32, 79), time taken = 283.0084
# grid_index = (32, 80), time taken = 283.1950
# grid_index = (32, 81), time taken = 283.3823
# grid_index = (32, 82), time taken = 283.5685
# grid_index = (33, 8), time taken = 283.7557
# grid_index = (33, 10), time taken = 283.9428
# grid_index = (33, 11), time taken = 284.1318
# grid_index = (33, 12), time taken = 284.3179
# grid_index = (33, 13), time taken = 284.5033
# grid_index = (33, 14), time taken = 284.6900
# grid_index = (33, 15), time taken = 284.8764
# grid_index = (33, 16), time taken = 285.0614
# grid_index = (33, 17), time taken = 285.2462
# grid_index = (33, 18), time taken = 285.4343
# grid_index = (33, 19), time taken = 285.6212
# grid_index = (33, 20), time taken = 285.8080
# grid_index = (33, 21), time taken = 285.9949
# grid_index = (33, 22), time taken = 286.1812
# grid_index = (33, 23), time taken = 286.3696
# grid_index = (33, 24), time taken = 286.5562
# grid_index = (33, 25), time taken = 286.7431
# grid_index = (33, 26), time taken = 286.9273
# grid_index = (33, 27), time taken = 287.1173
# grid_index = (33, 28), time taken = 287.3048
# grid_index = (33, 29), time taken = 287.4913
# grid_index = (33, 30), time taken = 287.6787
# grid_index = (33, 31), time taken = 287.8647
# grid_index = (33, 32), time taken = 288.0512
# grid_index = (33, 33), time taken = 288.2411
# grid_index = (33, 34), time taken = 288.4287
# grid_index = (33, 35), time taken = 288.6178
# grid_index = (33, 36), time taken = 288.8053
# grid_index = (33, 37), time taken = 288.9927
# grid_index = (33, 38), time taken = 289.1832
# grid_index = (33, 39), time taken = 289.3746
# grid_index = (33, 40), time taken = 289.5622
# grid_index = (33, 41), time taken = 289.7496
# grid_index = (33, 42), time taken = 289.9368
# grid_index = (33, 43), time taken = 290.1256
# grid_index = (33, 44), time taken = 290.3142
# grid_index = (33, 45), time taken = 290.5038
# grid_index = (33, 46), time taken = 290.6942
# grid_index = (33, 47), time taken = 290.8814
# grid_index = (33, 48), time taken = 291.0693
# grid_index = (33, 49), time taken = 291.2590
# grid_index = (33, 50), time taken = 291.4468
# grid_index = (33, 51), time taken = 291.6362
# grid_index = (33, 52), time taken = 291.8238
# grid_index = (33, 53), time taken = 292.0113
# grid_index = (33, 54), time taken = 292.2002
# grid_index = (33, 55), time taken = 292.3865
# grid_index = (33, 56), time taken = 292.5726
# grid_index = (33, 57), time taken = 292.7587
# grid_index = (33, 58), time taken = 292.9450
# grid_index = (33, 59), time taken = 293.1333
# grid_index = (33, 60), time taken = 293.3217
# grid_index = (33, 61), time taken = 293.5084
# grid_index = (33, 62), time taken = 293.6948
# grid_index = (33, 63), time taken = 293.8815
# grid_index = (33, 64), time taken = 294.0690
# grid_index = (33, 65), time taken = 294.2593
# grid_index = (33, 66), time taken = 294.4460
# grid_index = (33, 67), time taken = 294.6324
# grid_index = (33, 68), time taken = 294.8172
# grid_index = (33, 69), time taken = 295.0039
# grid_index = (33, 70), time taken = 295.1887
# grid_index = (33, 71), time taken = 295.3754
# grid_index = (33, 72), time taken = 295.5612
# grid_index = (33, 73), time taken = 295.7474
# grid_index = (33, 74), time taken = 295.9337
# grid_index = (33, 75), time taken = 296.1199
# grid_index = (33, 76), time taken = 296.3059
# grid_index = (33, 77), time taken = 296.4930
# grid_index = (33, 78), time taken = 296.6784
# grid_index = (33, 79), time taken = 296.8649
# grid_index = (33, 80), time taken = 297.0501
# grid_index = (33, 81), time taken = 297.2378
# grid_index = (33, 82), time taken = 297.4235
# grid_index = (33, 83), time taken = 297.6093
# grid_index = (33, 91), time taken = 297.7940
# grid_index = (34, 7), time taken = 297.9819
# grid_index = (34, 8), time taken = 298.1675
# grid_index = (34, 10), time taken = 298.3551
# grid_index = (34, 11), time taken = 298.5429
# grid_index = (34, 12), time taken = 298.7320
# grid_index = (34, 13), time taken = 298.9198
# grid_index = (34, 14), time taken = 299.1080
# grid_index = (34, 15), time taken = 299.2961
# grid_index = (34, 16), time taken = 299.4833
# grid_index = (34, 17), time taken = 299.6702
# grid_index = (34, 18), time taken = 299.8588
# grid_index = (34, 19), time taken = 300.0458
# grid_index = (34, 20), time taken = 300.2333
# grid_index = (34, 21), time taken = 300.4196
# grid_index = (34, 22), time taken = 300.6075
# grid_index = (34, 23), time taken = 300.7947
# grid_index = (34, 24), time taken = 300.9822
# grid_index = (34, 25), time taken = 301.1699
# grid_index = (34, 26), time taken = 301.3589
# grid_index = (34, 27), time taken = 301.5439
# grid_index = (34, 28), time taken = 301.7316
# grid_index = (34, 29), time taken = 301.9198
# grid_index = (34, 30), time taken = 302.1082
# grid_index = (34, 31), time taken = 302.2971
# grid_index = (34, 32), time taken = 302.4822
# grid_index = (34, 33), time taken = 302.6675
# grid_index = (34, 34), time taken = 302.8527
# grid_index = (34, 35), time taken = 303.0396
# grid_index = (34, 36), time taken = 303.2305
# grid_index = (34, 37), time taken = 303.4184
# grid_index = (34, 38), time taken = 303.6074
# grid_index = (34, 39), time taken = 303.7961
# grid_index = (34, 40), time taken = 303.9855
# grid_index = (34, 41), time taken = 304.1747
# grid_index = (34, 42), time taken = 304.3610
# grid_index = (34, 43), time taken = 304.5462
# grid_index = (34, 44), time taken = 304.7332
# grid_index = (34, 45), time taken = 304.9197
# grid_index = (34, 46), time taken = 305.1112
# grid_index = (34, 47), time taken = 305.2990
# grid_index = (34, 48), time taken = 305.4893
# grid_index = (34, 49), time taken = 305.6785
# grid_index = (34, 50), time taken = 305.8684
# grid_index = (34, 51), time taken = 306.0567
# grid_index = (34, 52), time taken = 306.2466
# grid_index = (34, 53), time taken = 306.4347
# grid_index = (34, 54), time taken = 306.6211
# grid_index = (34, 55), time taken = 306.8087
# grid_index = (34, 56), time taken = 306.9966
# grid_index = (34, 57), time taken = 307.1840
# grid_index = (34, 58), time taken = 307.3735
# grid_index = (34, 59), time taken = 307.5608
# grid_index = (34, 60), time taken = 307.7492
# grid_index = (34, 61), time taken = 307.9358
# grid_index = (34, 62), time taken = 308.1263
# grid_index = (34, 63), time taken = 308.3158
# grid_index = (34, 64), time taken = 308.5066
# grid_index = (34, 65), time taken = 308.6929
# grid_index = (34, 66), time taken = 308.8823
# grid_index = (34, 67), time taken = 309.0716
# grid_index = (34, 68), time taken = 309.2625
# grid_index = (34, 69), time taken = 309.4513
# grid_index = (34, 70), time taken = 309.6416
# grid_index = (34, 71), time taken = 309.8301
# grid_index = (34, 72), time taken = 310.0157
# grid_index = (34, 73), time taken = 310.2046
# grid_index = (34, 74), time taken = 310.3912
# grid_index = (34, 75), time taken = 310.5753
# grid_index = (34, 76), time taken = 310.7605
# grid_index = (34, 77), time taken = 310.9458
# grid_index = (34, 78), time taken = 311.1333
# grid_index = (34, 79), time taken = 311.3189
# grid_index = (34, 80), time taken = 311.5041
# grid_index = (34, 81), time taken = 311.6896
# grid_index = (34, 82), time taken = 311.8756
# grid_index = (34, 83), time taken = 312.0616
# grid_index = (34, 85), time taken = 312.2496
# grid_index = (34, 88), time taken = 312.4385
# grid_index = (35, 7), time taken = 312.6274
# grid_index = (35, 9), time taken = 312.8153
# grid_index = (35, 10), time taken = 313.0045
# grid_index = (35, 11), time taken = 313.1923
# grid_index = (35, 12), time taken = 313.3811
# grid_index = (35, 13), time taken = 313.5704
# grid_index = (35, 14), time taken = 313.7574
# grid_index = (35, 15), time taken = 313.9434
# grid_index = (35, 16), time taken = 314.1307
# grid_index = (35, 17), time taken = 314.3175
# grid_index = (35, 18), time taken = 314.5066
# grid_index = (35, 19), time taken = 314.6921
# grid_index = (35, 20), time taken = 314.8781
# grid_index = (35, 21), time taken = 315.0671
# grid_index = (35, 22), time taken = 315.2554
# grid_index = (35, 23), time taken = 315.4449
# grid_index = (35, 24), time taken = 315.6346
# grid_index = (35, 25), time taken = 315.8214
# grid_index = (35, 26), time taken = 316.0084
# grid_index = (35, 27), time taken = 316.1948
# grid_index = (35, 28), time taken = 316.3816
# grid_index = (35, 29), time taken = 316.5683
# grid_index = (35, 30), time taken = 316.7553
# grid_index = (35, 31), time taken = 316.9427
# grid_index = (35, 32), time taken = 317.1326
# grid_index = (35, 33), time taken = 317.3241
# grid_index = (35, 34), time taken = 317.5113
# grid_index = (35, 35), time taken = 317.6957
# grid_index = (35, 36), time taken = 317.8837
# grid_index = (35, 37), time taken = 318.0698
# grid_index = (35, 38), time taken = 318.2581
# grid_index = (35, 39), time taken = 318.4472
# grid_index = (35, 40), time taken = 318.6335
# grid_index = (35, 41), time taken = 318.8230
# grid_index = (35, 42), time taken = 319.0114
# grid_index = (35, 43), time taken = 319.1988
# grid_index = (35, 44), time taken = 319.3867
# grid_index = (35, 45), time taken = 319.5748
# grid_index = (35, 46), time taken = 319.7629
# grid_index = (35, 47), time taken = 319.9491
# grid_index = (35, 48), time taken = 320.1367
# grid_index = (35, 49), time taken = 320.3233
# grid_index = (35, 50), time taken = 320.5095
# grid_index = (35, 51), time taken = 320.6978
# grid_index = (35, 52), time taken = 320.8843
# grid_index = (35, 53), time taken = 321.0725
# grid_index = (35, 54), time taken = 321.2611
# grid_index = (35, 55), time taken = 321.4459
# grid_index = (35, 56), time taken = 321.6317
# grid_index = (35, 57), time taken = 321.8177
# grid_index = (35, 58), time taken = 322.0044
# grid_index = (35, 59), time taken = 322.1906
# grid_index = (35, 60), time taken = 322.3767
# grid_index = (35, 61), time taken = 322.5613
# grid_index = (35, 62), time taken = 322.7466
# grid_index = (35, 63), time taken = 322.9315
# grid_index = (35, 64), time taken = 323.1177
# grid_index = (35, 65), time taken = 323.3033
# grid_index = (35, 66), time taken = 323.4918
# grid_index = (35, 67), time taken = 323.6793
# grid_index = (35, 68), time taken = 323.8726
# grid_index = (35, 69), time taken = 324.0594
# grid_index = (35, 70), time taken = 324.2480
# grid_index = (35, 71), time taken = 324.4354
# grid_index = (35, 72), time taken = 324.6274
# grid_index = (35, 73), time taken = 324.8136
# grid_index = (35, 74), time taken = 325.0050
# grid_index = (35, 75), time taken = 325.1962
# grid_index = (35, 76), time taken = 325.3854
# grid_index = (35, 77), time taken = 325.5765
# grid_index = (35, 78), time taken = 325.7628
# grid_index = (35, 79), time taken = 325.9496
# grid_index = (35, 80), time taken = 326.1391
# grid_index = (35, 81), time taken = 326.3289
# grid_index = (35, 82), time taken = 326.5196
# grid_index = (35, 83), time taken = 326.7078
# grid_index = (35, 85), time taken = 326.8982
# grid_index = (35, 88), time taken = 327.0859
# grid_index = (36, 8), time taken = 327.2719
# grid_index = (36, 10), time taken = 327.4576
# grid_index = (36, 11), time taken = 327.6441
# grid_index = (36, 12), time taken = 327.8292
# grid_index = (36, 13), time taken = 328.0160
# grid_index = (36, 14), time taken = 328.2015
# grid_index = (36, 15), time taken = 328.3909
# grid_index = (36, 16), time taken = 328.5788
# grid_index = (36, 17), time taken = 328.7671
# grid_index = (36, 18), time taken = 328.9573
# grid_index = (36, 19), time taken = 329.1458
# grid_index = (36, 20), time taken = 329.3354
# grid_index = (36, 21), time taken = 329.5230
# grid_index = (36, 22), time taken = 329.7084
# grid_index = (36, 23), time taken = 329.8984
# grid_index = (36, 24), time taken = 330.0861
# grid_index = (36, 25), time taken = 330.2792
# grid_index = (36, 26), time taken = 330.4643
# grid_index = (36, 27), time taken = 330.6512
# grid_index = (36, 28), time taken = 330.8390
# grid_index = (36, 29), time taken = 331.0270
# grid_index = (36, 30), time taken = 331.2153
# grid_index = (36, 31), time taken = 331.4044
# grid_index = (36, 32), time taken = 331.5912
# grid_index = (36, 33), time taken = 331.7790
# grid_index = (36, 34), time taken = 331.9663
# grid_index = (36, 35), time taken = 332.1533
# grid_index = (36, 36), time taken = 332.3403
# grid_index = (36, 37), time taken = 332.5288
# grid_index = (36, 38), time taken = 332.7151
# grid_index = (36, 39), time taken = 332.9016
# grid_index = (36, 40), time taken = 333.0895
# grid_index = (36, 41), time taken = 333.2785
# grid_index = (36, 42), time taken = 333.4657
# grid_index = (36, 43), time taken = 333.6522
# grid_index = (36, 44), time taken = 333.8383
# grid_index = (36, 45), time taken = 334.0253
# grid_index = (36, 46), time taken = 334.2108
# grid_index = (36, 47), time taken = 334.3988
# grid_index = (36, 48), time taken = 334.5833
# grid_index = (36, 49), time taken = 334.7698
# grid_index = (36, 50), time taken = 334.9559
# grid_index = (36, 51), time taken = 335.1421
# grid_index = (36, 52), time taken = 335.3312
# grid_index = (36, 53), time taken = 335.5204
# grid_index = (36, 54), time taken = 335.7059
# grid_index = (36, 55), time taken = 335.8961
# grid_index = (36, 56), time taken = 336.0842
# grid_index = (36, 57), time taken = 336.2747
# grid_index = (36, 58), time taken = 336.4658
# grid_index = (36, 59), time taken = 336.6577
# grid_index = (36, 60), time taken = 336.8493
# grid_index = (36, 61), time taken = 337.0376
# grid_index = (36, 62), time taken = 337.2241
# grid_index = (36, 63), time taken = 337.4117
# grid_index = (36, 64), time taken = 337.6012
# grid_index = (36, 65), time taken = 337.7920
# grid_index = (36, 66), time taken = 337.9812
# grid_index = (36, 67), time taken = 338.1681
# grid_index = (36, 68), time taken = 338.3559
# grid_index = (36, 69), time taken = 338.5430
# grid_index = (36, 70), time taken = 338.7296
# grid_index = (36, 71), time taken = 338.9184
# grid_index = (36, 72), time taken = 339.1045
# grid_index = (36, 73), time taken = 339.2925
# grid_index = (36, 74), time taken = 339.4793
# grid_index = (36, 75), time taken = 339.6668
# grid_index = (36, 76), time taken = 339.8557
# grid_index = (36, 77), time taken = 340.0431
# grid_index = (36, 78), time taken = 340.2311
# grid_index = (36, 79), time taken = 340.4175
# grid_index = (36, 80), time taken = 340.6022
# grid_index = (36, 81), time taken = 340.7895
# grid_index = (36, 82), time taken = 340.9771
# grid_index = (36, 83), time taken = 341.1660
# grid_index = (36, 84), time taken = 341.3540
# grid_index = (36, 86), time taken = 341.5403
# grid_index = (36, 87), time taken = 341.7283
# grid_index = (37, 5), time taken = 341.9161
# grid_index = (37, 7), time taken = 342.1027
# grid_index = (37, 8), time taken = 342.2883
# grid_index = (37, 9), time taken = 342.4716
# grid_index = (37, 10), time taken = 342.6587
# grid_index = (37, 11), time taken = 342.8444
# grid_index = (37, 12), time taken = 343.0295
# grid_index = (37, 13), time taken = 343.2144
# grid_index = (37, 14), time taken = 343.3997
# grid_index = (37, 15), time taken = 343.5873
# grid_index = (37, 16), time taken = 343.7748
# grid_index = (37, 17), time taken = 343.9606
# grid_index = (37, 18), time taken = 344.1490
# grid_index = (37, 19), time taken = 344.3339
# grid_index = (37, 20), time taken = 344.5193
# grid_index = (37, 21), time taken = 344.7024
# grid_index = (37, 22), time taken = 344.8868
# grid_index = (37, 23), time taken = 345.0729
# grid_index = (37, 24), time taken = 345.2599
# grid_index = (37, 25), time taken = 345.4465
# grid_index = (37, 26), time taken = 345.6315
# grid_index = (37, 27), time taken = 345.8173
# grid_index = (37, 28), time taken = 346.0109
# grid_index = (37, 29), time taken = 346.1976
# grid_index = (37, 30), time taken = 346.3873
# grid_index = (37, 31), time taken = 346.5757
# grid_index = (37, 32), time taken = 346.7632
# grid_index = (37, 33), time taken = 346.9520
# grid_index = (37, 34), time taken = 347.1409
# grid_index = (37, 35), time taken = 347.3290
# grid_index = (37, 36), time taken = 347.5166
# grid_index = (37, 37), time taken = 347.7058
# grid_index = (37, 38), time taken = 347.8928
# grid_index = (37, 39), time taken = 348.0817
# grid_index = (37, 40), time taken = 348.2709
# grid_index = (37, 41), time taken = 348.4574
# grid_index = (37, 42), time taken = 348.6456
# grid_index = (37, 43), time taken = 348.8318
# grid_index = (37, 44), time taken = 349.0195
# grid_index = (37, 45), time taken = 349.2063
# grid_index = (37, 46), time taken = 349.3925
# grid_index = (37, 47), time taken = 349.5795
# grid_index = (37, 48), time taken = 349.7659
# grid_index = (37, 49), time taken = 349.9522
# grid_index = (37, 50), time taken = 350.1379
# grid_index = (37, 51), time taken = 350.3247
# grid_index = (37, 52), time taken = 350.5107
# grid_index = (37, 53), time taken = 350.6962
# grid_index = (37, 54), time taken = 350.8811
# grid_index = (37, 55), time taken = 351.0679
# grid_index = (37, 56), time taken = 351.2562
# grid_index = (37, 57), time taken = 351.4466
# grid_index = (37, 58), time taken = 351.6376
# grid_index = (37, 59), time taken = 351.8266
# grid_index = (37, 60), time taken = 352.0162
# grid_index = (37, 61), time taken = 352.2027
# grid_index = (37, 62), time taken = 352.3917
# grid_index = (37, 63), time taken = 352.5773
# grid_index = (37, 64), time taken = 352.7646
# grid_index = (37, 65), time taken = 352.9494
# grid_index = (37, 66), time taken = 353.1366
# grid_index = (37, 67), time taken = 353.3245
# grid_index = (37, 68), time taken = 353.5133
# grid_index = (37, 69), time taken = 353.7023
# grid_index = (37, 70), time taken = 353.8915
# grid_index = (37, 71), time taken = 354.0798
# grid_index = (37, 72), time taken = 354.2677
# grid_index = (37, 73), time taken = 354.4545
# grid_index = (37, 74), time taken = 354.6407
# grid_index = (37, 75), time taken = 354.8280
# grid_index = (37, 76), time taken = 355.0155
# grid_index = (37, 77), time taken = 355.2031
# grid_index = (37, 78), time taken = 355.3919
# grid_index = (37, 79), time taken = 355.5773
# grid_index = (37, 80), time taken = 355.7640
# grid_index = (37, 81), time taken = 355.9490
# grid_index = (37, 82), time taken = 356.1359
# grid_index = (37, 83), time taken = 356.3247
# grid_index = (37, 84), time taken = 356.5137
# grid_index = (37, 85), time taken = 356.7017
# grid_index = (37, 86), time taken = 356.8907
# grid_index = (37, 89), time taken = 357.0776
# grid_index = (38, 5), time taken = 357.2666
# grid_index = (38, 7), time taken = 357.4535
# grid_index = (38, 8), time taken = 357.6404
# grid_index = (38, 9), time taken = 357.8272
# grid_index = (38, 10), time taken = 358.0152
# ...
# grid_index = (85, 43), time taken = 1030.8200
# grid_index = (85, 44), time taken = 1031.0067
# grid_index = (85, 45), time taken = 1031.1947
# grid_index = (85, 46), time taken = 1031.3818
# grid_index = (85, 47), time taken = 1031.5690
# grid_index = (85, 48), time taken = 1031.7560
# grid_index = (85, 49), time taken = 1031.9416
# grid_index = (85, 50), time taken = 1032.1268
# grid_index = (85, 51), time taken = 1032.3149
# grid_index = (85, 52), time taken = 1032.5027
# grid_index = (85, 53), time taken = 1032.6888
# grid_index = (85, 54), time taken = 1032.8736
# grid_index = (85, 55), time taken = 1033.0612
# grid_index = (85, 56), time taken = 1033.2478
# grid_index = (85, 57), time taken = 1033.4342
# grid_index = (85, 58), time taken = 1033.6195
# grid_index = (85, 59), time taken = 1033.8038
# grid_index = (85, 60), time taken = 1033.9891
# grid_index = (85, 61), time taken = 1034.1778
# grid_index = (85, 62), time taken = 1034.3663
# grid_index = (85, 63), time taken = 1034.5535
# grid_index = (85, 64), time taken = 1034.7396
# grid_index = (85, 65), time taken = 1034.9243
# grid_index = (85, 66), time taken = 1035.1120
# grid_index = (85, 67), time taken = 1035.2994
# grid_index = (85, 68), time taken = 1035.4881
# grid_index = (85, 69), time taken = 1035.6759
# grid_index = (85, 70), time taken = 1035.8616
# grid_index = (85, 71), time taken = 1036.0478
# grid_index = (85, 72), time taken = 1036.2316
# grid_index = (85, 73), time taken = 1036.4185
# grid_index = (85, 74), time taken = 1036.6073
# grid_index = (85, 75), time taken = 1036.7982
# grid_index = (85, 76), time taken = 1036.9866
# grid_index = (85, 77), time taken = 1037.1746
# grid_index = (85, 78), time taken = 1037.3636
# grid_index = (85, 79), time taken = 1037.5538
# grid_index = (85, 81), time taken = 1037.7445
# grid_index = (85, 82), time taken = 1037.9343
# grid_index = (85, 83), time taken = 1038.1214
# grid_index = (85, 91), time taken = 1038.3071
# grid_index = (86, 35), time taken = 1038.4945
# grid_index = (86, 39), time taken = 1038.6819
# grid_index = (86, 41), time taken = 1038.8663
# grid_index = (86, 42), time taken = 1039.0534
# grid_index = (86, 43), time taken = 1039.2401
# grid_index = (86, 44), time taken = 1039.4261
# grid_index = (86, 45), time taken = 1039.6118
# grid_index = (86, 46), time taken = 1039.7972
# grid_index = (86, 47), time taken = 1039.9860
# grid_index = (86, 48), time taken = 1040.1720
# grid_index = (86, 49), time taken = 1040.3609
# grid_index = (86, 50), time taken = 1040.5493
# grid_index = (86, 51), time taken = 1040.7371
# grid_index = (86, 52), time taken = 1040.9237
# grid_index = (86, 53), time taken = 1041.1091
# grid_index = (86, 54), time taken = 1041.2983
# grid_index = (86, 55), time taken = 1041.4868
# grid_index = (86, 56), time taken = 1041.6766
# grid_index = (86, 57), time taken = 1041.8635
# grid_index = (86, 58), time taken = 1042.0520
# grid_index = (86, 59), time taken = 1042.2405
# grid_index = (86, 60), time taken = 1042.4263
# grid_index = (86, 61), time taken = 1042.6119
# grid_index = (86, 62), time taken = 1042.8007
# grid_index = (86, 63), time taken = 1042.9877
# grid_index = (86, 64), time taken = 1043.1756
# grid_index = (86, 65), time taken = 1043.3629
# grid_index = (86, 66), time taken = 1043.5515
# grid_index = (86, 67), time taken = 1043.7394
# grid_index = (86, 68), time taken = 1043.9290
# grid_index = (86, 69), time taken = 1044.1160
# grid_index = (86, 70), time taken = 1044.3033
# grid_index = (86, 71), time taken = 1044.4909
# grid_index = (86, 72), time taken = 1044.6783
# grid_index = (86, 73), time taken = 1044.8683
# grid_index = (86, 74), time taken = 1045.0561
# grid_index = (86, 75), time taken = 1045.2413
# grid_index = (86, 76), time taken = 1045.4339
# grid_index = (86, 77), time taken = 1045.6199
# grid_index = (86, 78), time taken = 1045.8092
# grid_index = (86, 79), time taken = 1045.9967
# grid_index = (86, 80), time taken = 1046.1830
# grid_index = (86, 81), time taken = 1046.3706
# grid_index = (86, 84), time taken = 1046.5605
# grid_index = (86, 85), time taken = 1046.7523
# grid_index = (87, 41), time taken = 1046.9410
# grid_index = (87, 42), time taken = 1047.1289
# grid_index = (87, 43), time taken = 1047.3196
# grid_index = (87, 44), time taken = 1047.5062
# grid_index = (87, 45), time taken = 1047.6956
# grid_index = (87, 46), time taken = 1047.8840
# grid_index = (87, 47), time taken = 1048.0746
# grid_index = (87, 48), time taken = 1048.2650
# grid_index = (87, 49), time taken = 1048.4549
# grid_index = (87, 50), time taken = 1048.6429
# grid_index = (87, 51), time taken = 1048.8315
# grid_index = (87, 52), time taken = 1049.0189
# grid_index = (87, 53), time taken = 1049.2081
# grid_index = (87, 54), time taken = 1049.3950
# grid_index = (87, 55), time taken = 1049.5839
# grid_index = (87, 56), time taken = 1049.7692
# grid_index = (87, 57), time taken = 1049.9584
# grid_index = (87, 58), time taken = 1050.1435
# grid_index = (87, 59), time taken = 1050.3333
# grid_index = (87, 60), time taken = 1050.5204
# grid_index = (87, 61), time taken = 1050.7081
# grid_index = (87, 62), time taken = 1050.8946
# grid_index = (87, 63), time taken = 1051.0820
# grid_index = (87, 64), time taken = 1051.2717
# grid_index = (87, 65), time taken = 1051.4586
# grid_index = (87, 66), time taken = 1051.6472
# grid_index = (87, 67), time taken = 1051.8335
# grid_index = (87, 68), time taken = 1052.0213
# grid_index = (87, 69), time taken = 1052.2108
# grid_index = (87, 70), time taken = 1052.3970
# grid_index = (87, 71), time taken = 1052.5827
# grid_index = (87, 72), time taken = 1052.7692
# grid_index = (87, 73), time taken = 1052.9572
# grid_index = (87, 74), time taken = 1053.1432
# grid_index = (87, 75), time taken = 1053.3304
# grid_index = (87, 76), time taken = 1053.5191
# grid_index = (87, 77), time taken = 1053.7061
# grid_index = (87, 78), time taken = 1053.8922
# grid_index = (87, 79), time taken = 1054.0803
# grid_index = (87, 80), time taken = 1054.2662
# grid_index = (88, 38), time taken = 1054.4551
# grid_index = (88, 40), time taken = 1054.6424
# grid_index = (88, 42), time taken = 1054.8316
# grid_index = (88, 43), time taken = 1055.0212
# grid_index = (88, 44), time taken = 1055.2083
# grid_index = (88, 45), time taken = 1055.3955
# grid_index = (88, 46), time taken = 1055.5821
# grid_index = (88, 47), time taken = 1055.7685
# grid_index = (88, 48), time taken = 1055.9551
# grid_index = (88, 49), time taken = 1056.1440
# grid_index = (88, 50), time taken = 1056.3313
# grid_index = (88, 51), time taken = 1056.5186
# grid_index = (88, 52), time taken = 1056.7060
# grid_index = (88, 53), time taken = 1056.8931
# grid_index = (88, 54), time taken = 1057.0827
# grid_index = (88, 55), time taken = 1057.2696
# grid_index = (88, 56), time taken = 1057.4567
# grid_index = (88, 57), time taken = 1057.6420
# grid_index = (88, 58), time taken = 1057.8290
# grid_index = (88, 59), time taken = 1058.0187
# grid_index = (88, 60), time taken = 1058.2066
# grid_index = (88, 61), time taken = 1058.3919
# grid_index = (88, 62), time taken = 1058.5814
# grid_index = (88, 63), time taken = 1058.7683
# grid_index = (88, 64), time taken = 1058.9602
# grid_index = (88, 65), time taken = 1059.1477
# grid_index = (88, 66), time taken = 1059.3380
# grid_index = (88, 67), time taken = 1059.5353
# grid_index = (88, 68), time taken = 1059.7237
# grid_index = (88, 69), time taken = 1059.9127
# grid_index = (88, 70), time taken = 1060.1032
# grid_index = (88, 71), time taken = 1060.2924
# grid_index = (88, 72), time taken = 1060.4828
# grid_index = (88, 73), time taken = 1060.6710
# grid_index = (88, 74), time taken = 1060.8591
# grid_index = (88, 75), time taken = 1061.0501
# grid_index = (88, 76), time taken = 1061.2411
# grid_index = (88, 79), time taken = 1061.4287
# grid_index = (88, 85), time taken = 1061.6201
# grid_index = (89, 31), time taken = 1061.8086
# grid_index = (89, 43), time taken = 1061.9990
# grid_index = (89, 45), time taken = 1062.1866
# grid_index = (89, 46), time taken = 1062.3733
# grid_index = (89, 47), time taken = 1062.5611
# grid_index = (89, 48), time taken = 1062.7483
# grid_index = (89, 49), time taken = 1062.9381
# grid_index = (89, 50), time taken = 1063.1275
# grid_index = (89, 51), time taken = 1063.3161
# grid_index = (89, 52), time taken = 1063.5023
# grid_index = (89, 53), time taken = 1063.6881
# grid_index = (89, 54), time taken = 1063.8746
# grid_index = (89, 55), time taken = 1064.0623
# grid_index = (89, 56), time taken = 1064.2509
# grid_index = (89, 57), time taken = 1064.4364
# grid_index = (89, 58), time taken = 1064.6216
# grid_index = (89, 59), time taken = 1064.8105
# grid_index = (89, 60), time taken = 1064.9993
# grid_index = (89, 61), time taken = 1065.1890
# grid_index = (89, 62), time taken = 1065.3793
# grid_index = (89, 63), time taken = 1065.5666
# grid_index = (89, 64), time taken = 1065.7539
# grid_index = (89, 65), time taken = 1065.9422
# grid_index = (89, 66), time taken = 1066.1307
# grid_index = (89, 67), time taken = 1066.3182
# grid_index = (89, 68), time taken = 1066.5036
# grid_index = (89, 69), time taken = 1066.6887
# grid_index = (89, 70), time taken = 1066.8753
# grid_index = (89, 71), time taken = 1067.0634
# grid_index = (89, 72), time taken = 1067.2503
# grid_index = (89, 73), time taken = 1067.4398
# grid_index = (89, 74), time taken = 1067.6280
# grid_index = (89, 75), time taken = 1067.8169
# grid_index = (89, 77), time taken = 1068.0071
# grid_index = (89, 78), time taken = 1068.1963
# grid_index = (89, 81), time taken = 1068.3868
# grid_index = (90, 42), time taken = 1068.5738
# grid_index = (90, 43), time taken = 1068.7613
# grid_index = (90, 44), time taken = 1068.9486
# grid_index = (90, 46), time taken = 1069.1372
# grid_index = (90, 48), time taken = 1069.3268
# grid_index = (90, 49), time taken = 1069.5141
# grid_index = (90, 50), time taken = 1069.7031
# grid_index = (90, 51), time taken = 1069.8907
# grid_index = (90, 52), time taken = 1070.0778
# grid_index = (90, 53), time taken = 1070.2670
# grid_index = (90, 54), time taken = 1070.4525
# grid_index = (90, 55), time taken = 1070.6389
# grid_index = (90, 56), time taken = 1070.8257
# grid_index = (90, 57), time taken = 1071.0153
# grid_index = (90, 58), time taken = 1071.2044
# grid_index = (90, 59), time taken = 1071.3907
# grid_index = (90, 60), time taken = 1071.5778
# grid_index = (90, 61), time taken = 1071.7644
# grid_index = (90, 62), time taken = 1071.9525
# grid_index = (90, 63), time taken = 1072.1404
# grid_index = (90, 64), time taken = 1072.3288
# grid_index = (90, 65), time taken = 1072.5163
# grid_index = (90, 66), time taken = 1072.7032
# grid_index = (90, 67), time taken = 1072.8892
# grid_index = (90, 68), time taken = 1073.0770
# grid_index = (90, 69), time taken = 1073.2669
# grid_index = (90, 70), time taken = 1073.4538
# grid_index = (90, 71), time taken = 1073.6412
# grid_index = (90, 72), time taken = 1073.8271
# grid_index = (90, 73), time taken = 1074.0122
# grid_index = (90, 74), time taken = 1074.1991
# grid_index = (90, 77), time taken = 1074.3883
# grid_index = (90, 78), time taken = 1074.5773
# grid_index = (90, 82), time taken = 1074.7654
# grid_index = (91, 39), time taken = 1074.9528
# grid_index = (91, 45), time taken = 1075.1415
# grid_index = (91, 47), time taken = 1075.3307
# grid_index = (91, 48), time taken = 1075.5186
# grid_index = (91, 50), time taken = 1075.7044
# grid_index = (91, 51), time taken = 1075.8933
# grid_index = (91, 52), time taken = 1076.0824
# grid_index = (91, 53), time taken = 1076.2713
# grid_index = (91, 54), time taken = 1076.4605
# grid_index = (91, 55), time taken = 1076.6493
# grid_index = (91, 56), time taken = 1076.8365
# grid_index = (91, 57), time taken = 1077.0237
# grid_index = (91, 58), time taken = 1077.2106
# grid_index = (91, 59), time taken = 1077.3967
# grid_index = (91, 60), time taken = 1077.5835
# grid_index = (91, 61), time taken = 1077.7692
# grid_index = (91, 62), time taken = 1077.9551
# grid_index = (91, 63), time taken = 1078.1430
# grid_index = (91, 64), time taken = 1078.3343
# grid_index = (91, 65), time taken = 1078.5222
# grid_index = (91, 66), time taken = 1078.7078
# grid_index = (91, 67), time taken = 1078.8955
# grid_index = (91, 69), time taken = 1079.0832
# grid_index = (91, 70), time taken = 1079.2721
# grid_index = (91, 71), time taken = 1079.4638
# grid_index = (91, 72), time taken = 1079.6538
# grid_index = (91, 73), time taken = 1079.8429
# grid_index = (91, 74), time taken = 1080.0343
# grid_index = (91, 76), time taken = 1080.2204
# grid_index = (92, 41), time taken = 1080.4103
# grid_index = (92, 47), time taken = 1080.5988
# grid_index = (92, 48), time taken = 1080.7877
# grid_index = (92, 50), time taken = 1080.9758
# grid_index = (92, 52), time taken = 1081.1641
# grid_index = (92, 53), time taken = 1081.3532
# grid_index = (92, 55), time taken = 1081.5388
# grid_index = (92, 56), time taken = 1081.7236
# grid_index = (92, 57), time taken = 1081.9103
# grid_index = (92, 58), time taken = 1082.0982
# grid_index = (92, 59), time taken = 1082.2887
# grid_index = (92, 60), time taken = 1082.4828
# grid_index = (92, 61), time taken = 1082.6714
# grid_index = (92, 62), time taken = 1082.8596
# grid_index = (92, 63), time taken = 1083.0500
# grid_index = (92, 64), time taken = 1083.2359
# grid_index = (92, 65), time taken = 1083.4234
# grid_index = (92, 66), time taken = 1083.6131
# grid_index = (92, 70), time taken = 1083.8067
# grid_index = (92, 74), time taken = 1083.9923
# grid_index = (92, 77), time taken = 1084.1784
# grid_index = (92, 79), time taken = 1084.3671
# grid_index = (93, 42), time taken = 1084.5564
# grid_index = (93, 50), time taken = 1084.7418
# grid_index = (93, 51), time taken = 1084.9277
# grid_index = (93, 52), time taken = 1085.1137
# grid_index = (93, 53), time taken = 1085.3048
# grid_index = (93, 54), time taken = 1085.4925
# grid_index = (93, 57), time taken = 1085.6816
# grid_index = (93, 59), time taken = 1085.8661
# grid_index = (93, 61), time taken = 1086.0544
# grid_index = (93, 62), time taken = 1086.2415
# grid_index = (93, 64), time taken = 1086.4308
# grid_index = (93, 65), time taken = 1086.6164
# grid_index = (93, 66), time taken = 1086.8054
# grid_index = (93, 67), time taken = 1086.9903
# grid_index = (93, 68), time taken = 1087.1777
# grid_index = (93, 69), time taken = 1087.3661
# grid_index = (93, 70), time taken = 1087.5558
# grid_index = (93, 73), time taken = 1087.7432
# grid_index = (93, 75), time taken = 1087.9326
# grid_index = (94, 46), time taken = 1088.1273
# grid_index = (94, 47), time taken = 1088.3169
# grid_index = (94, 50), time taken = 1088.5088
# grid_index = (94, 54), time taken = 1088.6934
# grid_index = (94, 55), time taken = 1088.8780
# grid_index = (94, 57), time taken = 1089.0637
# grid_index = (94, 59), time taken = 1089.2519
# grid_index = (94, 60), time taken = 1089.4393
# grid_index = (94, 61), time taken = 1089.6251
# grid_index = (94, 62), time taken = 1089.8128
# grid_index = (94, 63), time taken = 1089.9995
# grid_index = (94, 65), time taken = 1090.1866
# grid_index = (94, 66), time taken = 1090.3733
# grid_index = (94, 67), time taken = 1090.5634
# grid_index = (94, 68), time taken = 1090.7508
# grid_index = (94, 69), time taken = 1090.9372
# grid_index = (94, 73), time taken = 1091.1231
# grid_index = (94, 76), time taken = 1091.3117
# grid_index = (95, 48), time taken = 1091.5000
# grid_index = (95, 51), time taken = 1091.6884
# grid_index = (95, 53), time taken = 1091.8777
# grid_index = (95, 58), time taken = 1092.0667
# grid_index = (95, 61), time taken = 1092.2542
# grid_index = (95, 64), time taken = 1092.4409
# grid_index = (95, 70), time taken = 1092.6262
# grid_index = (95, 71), time taken = 1092.8110
# grid_index = (95, 74), time taken = 1092.9957
# grid_index = (96, 48), time taken = 1093.1818
# grid_index = (96, 54), time taken = 1093.3702
# grid_index = (96, 55), time taken = 1093.5566
# grid_index = (96, 58), time taken = 1093.7424
# grid_index = (96, 61), time taken = 1093.9332
# grid_index = (96, 64), time taken = 1094.1211
# grid_index = (96, 69), time taken = 1094.3097
# grid_index = (97, 57), time taken = 1094.4969
# grid_index = (97, 58), time taken = 1094.6853
# grid_index = (97, 68), time taken = 1094.8756
# grid_index = (97, 70), time taken = 1095.0680
# grid_index = (98, 63), time taken = 1095.2599
# grid_index = (98, 65), time taken = 1095.4518
# grid_index = (99, 47), time taken = 1095.6409
# Time taken by calc_2D_prob is 1095.712234735489 seconds

# %% [markdown]
# **Plot and save $p_0$**

# %%
scale = 4
xlabel_size = ylabel_size = 15 + scale
tick_size = 10 + scale
legend_size = 15 + scale
title_size = 15 + scale
cbar_tick_size = 10 + scale

# define 6 subplots
fig_p0 = plt.figure(figsize=(8, 8))
ax = fig_p0.add_subplot(111) 


# position colorbars
div = make_axes_locatable(ax)
cax= div.append_axes('right', '5%', '5%')


# set label size
ax.tick_params(axis='both', which='major', labelsize=tick_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_size)


# write titles and labels
ax.set_title(r'$p_0(a, b)$', fontsize=title_size)
ax.set_xlabel('a', fontsize=xlabel_size)
ax.set_ylabel('b', fontsize=ylabel_size)



# compute, plot and save p0 data
mc0 = sim.MCProb(save_folder, n_subdivs, mu_np, sigma, X0 = rv0.sample(int(1e7)).numpy())
mc0.ready(n_steps=0, dt=dt, lims=None)
grid = mc0.get_grid()
low = grid.mins
high = grid.maxs
x = np.linspace(low[0], high[0], num=n_subdivs+1)[:-1].astype(DTYPE) + grid.h[0]/2.
y = np.linspace(low[1], high[1], num=n_subdivs+1)[:-1].astype(DTYPE) + grid.h[1]/2.
np.save('{}/x_0.npy'.format(save_folder), x)
np.save('{}/y_0.npy'.format(save_folder), y)
p_0 = mc0.compute_p2(0, 1, save=False)
np.save('{}/p_0.npy'.format(save_folder), p_0)
im = ax.pcolormesh(x, y, p_0.T, cmap='inferno', shading='auto')
cbar = fig_p0.colorbar(im, cax=cax, ax=ax)
cbar.ax.tick_params(labelsize=cbar_tick_size)
ax.set_aspect("auto")
plt.tight_layout()
plt.savefig('{}/plots/L63-0.png'.format(repo))
# Out:
# Time taken by propagate is 30.265854120254517 seconds
# Time taken by set_grid is 29.482074737548828 seconds
# Time taken by assign_pts is 36.94929647445679 seconds
# Time taken by ready is 96.6976101398468 seconds
# Time taken by compute_p2 is 38.218586444854736 seconds
