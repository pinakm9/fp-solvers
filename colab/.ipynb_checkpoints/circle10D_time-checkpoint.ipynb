# %% [markdown]
# **Instructions for running this notebook on Colab**
# 1. Run the cell below to download code from GitHub and install correct version of Python modules
# 2. Restart session so that Colab can use the newly installed modules rather than their previously installed versions
# 3. Run all cells

# %%
# run this cell to download data and necessary modules
import os, shutil
repo = 'fp-solvers'
if os.path.isdir(repo):
  shutil.rmtree(repo)
# !git clone https://github.com/pinakm9/fp-solvers.git
# !pip install -r fp-solvers/requirements.txt 2> /dev/null
# Out:
# Cloning into 'fp-solvers'...
# remote: Enumerating objects: 15081, done.
# remote: Counting objects: 100% (451/451), done.
# remote: Compressing objects: 100% (288/288), done.
# remote: Total 15081 (delta 184), reused 404 (delta 153), pack-reused 14630
# Receiving objects: 100% (15081/15081), 842.93 MiB | 43.11 MiB/s, done.
# Resolving deltas: 100% (7339/7339), done.
# Updating files: 100% (14713/14713), done.

# %%
# add modules folder to Python's search path
import sys
sys.path.insert(0, repo + '/modules')
# import the rest of the modules
# %matplotlib nbagg
# %matplotlib inline
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import arch
import pandas as pd
import tensorflow_probability as tfp
import time  
import sim
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %% [markdown]
# **Define $p_0$**

# %%
dtype = 'float32'
c = 2. * np.pi

def left(x, y):
    return np.exp(-((x+.5)**2 + (y+.5)**2)/(.5)) 

def right(x, y):
    return np.exp(-((x-.5)**2 + (y-.5)**2)/(.5)) 

def middle(x, y):
    return 0.5 * left(x, y) + 0.5 * right(x, y)

def p0(X):
    x0, x1, x2, x3, x4, x5, x6, x7, x8, x9 = tf.split(X, 10, axis=-1)
    return middle(x0, x1) * middle(x2, x3) * middle(x4, x5) * middle(x6, x7) * middle(x8, x9)
     
locs = 0.5*np.array([[-1., -1.], [1., 1.]]).astype(dtype)
scales = 0.5*np.array([[1., 1.], [1., 1.]]).astype(dtype)
weights = np.array([.5, .5]).astype(dtype)
Xs = [tfp.distributions.MultivariateNormalDiag(loc=locs[i], scale_diag=scales[i]) for i in range(len(locs))]
rv0 = tfp.distributions.Mixture(cat=tfp.distributions.Categorical(probs=weights), components=Xs)

# %% [markdown]
# **Define $p_\infty$**

# %%
# load learned solution
dim = 10
o1 = tf.ones((1, 1), dtype=dtype)
z1 = tf.zeros((1, 1), dtype=dtype)
n_theta = arch.LSTMForgetNet(50, 3, tf.float32, name="circle10D")
n_theta.load_weights('{}/circle-fp/data/10D/460/{}'.format(repo, n_theta.name)).expect_partial()


def p_inf(X):
    return np.exp(n_theta(X))

def p_inf_45(x4, x5):
    return np.exp(n_theta(z1, z1, z1, z1, o1*x4, o1*x5, z1, z1, z1, z1))[0][0]

def p_inf_true(X):
    x0, x1, x2, x3, x4, x5, x6, x7, x8, x9 = tf.split(X, 10, axis=-1)
    v0 = (x0*x0 + x1*x1 - 1.)**2
    v1 = (x2*x2 + x3*x3 - 1.)**2
    v2 = (x4*x4 + x5*x5 - 1.)**2
    v3 = (x6*x6 + x7*x7 - 1.)**2
    v4 = (x8*x8 + x9*x9 - 1.)**2
    return np.exp(-v0-v1-v2-v3-v4)

def p_inf_2(X):
    x0, x1 = tf.split(X, 2, axis=-1)
    v0 = (x0*x0 + x1*x1 - 1.)**2
    return np.exp(-v0)

# %% [markdown]
# **Define the $h$-equation**

# %%
# define p-drift
def mu_10(X):
    x0, x1, x2, x3, x4, x5, x6, x7, x8, x9 = tf.split(X, 10, axis=-1)
    z0 = -4. * (x0*x0 + x1*x1 - 1.)
    z1 = -4. * (x2*x2 + x3*x3 - 1.)
    z2 = -4. * (x4*x4 + x5*x5 - 1.)
    z3 = -4. * (x6*x6 + x7*x7 - 1.)
    z4 = -4. * (x8*x8 + x9*x9 - 1.)
    return tf.concat([x0*z0, x1*z0, x2*z1, x3*z1, x4*z2, x5*z2, x6*z3, x7*z3, x8*z4, x9*z4], axis=-1)

def mu_2(X):
    x0, x1 = tf.split(X, 2, axis=-1)
    z0 = -4. * (x0*x0 + x1*x1 - 1.)
    return tf.concat([x0*z0, x1*z0], axis=-1)

# define diffusion
sigma = np.sqrt(2., dtype=dtype)
D = sigma**2 / 2.


# define h-drift
@tf.function
def h_mu(X):
    x0, x1, x2, x3, x4, x5, x6, x7, x8, x9 = tf.split(X, 10, axis=-1)
    with tf.GradientTape() as tape:
        tape.watch([x0, x1, x2, x3, x4, x5, x6, x7, x8, x9])
        n_ = n_theta(x0, x1, x2, x3, x4, x5, x6, x7, x8, x9) 
    grad_n = tf.concat(tape.gradient(n_, [x0, x1, x2, x3, x4, x5, x6, x7, x8, x9]), axis=-1)
    return sigma**2*grad_n - mu_10(X)

# define h0
def h0(X):
    return p0(X) / p_inf(X)

# %% [markdown]
# **Compute the Monte-Carlo solution**

# %%
n_particles = int(1e7)
n_subdivs = 100
save_folder = '{}/circle-fp/data/10D'.format(repo)
n_steps = 10
dt = 0.01
t = dt * n_steps

X0 =  rv0.sample(n_particles).numpy()
mc_prob = sim.MCProb(save_folder, n_subdivs, lambda X: mu_2(X).numpy(), sigma,\
                     X0, tick_size=20, title_size=20, cbar_tick_size=15)
mc_prob.ready(n_steps=n_steps, dt=dt, lims=None)
z_1m = mc_prob.compute_p2(0, 1, save=False) 
nonzero_idx = list(zip(*np.where(z_1m > 0.)))
# Out:
# Time taken by propagate is 30.498265027999878 seconds
# Time taken by set_grid is 23.036843061447144 seconds
# Time taken by assign_pts is 32.249549865722656 seconds
# Time taken by ready is 85.78506112098694 seconds
# Time taken by compute_p2 is 35.07015013694763 seconds

# %% [markdown]
# **Compute the Feynman-Kac solution**

# %%
n_repeats = 10000
o = tf.ones((n_repeats, 1), dtype=dtype)
z = tf.zeros((n_repeats, 1), dtype=dtype)

def get_endpts(x4, x5):
    X = tf.concat([z, z, z, z, o*x4, o*x5, z, z, z, z], axis=-1).numpy()
    dW = np.random.normal(scale=np.sqrt(dt), size=(n_steps, X.shape[0], dim)).astype(dtype)
    for step in range(n_steps):
        X += mu_10(X).numpy() * dt + sigma * dW[step]
    return X 


def fk(x4, x5):
    X = get_endpts(x4, x5)
    x = np.array([[0., 0., 0., 0., x4, x5, 0., 0., 0., 0.]], dtype=dtype)
    return p_inf(x) * (h0(X).sum()) / n_repeats


# calculate the learned probability
grid = mc_prob.get_grid()
low = grid.mins
high = grid.maxs
x4 = np.linspace(low[0], high[0], num=n_subdivs+1)[:-1].astype(dtype) + grid.h[0]/2.
x5 = np.linspace(low[1], high[1], num=n_subdivs+1)[:-1].astype(dtype) + grid.h[1]/2.
np.save('{}/x4_t.npy'.format(save_folder), x4)
np.save('{}/x5_t.npy'.format(save_folder), x5)

z_1l = np.zeros((n_subdivs, n_subdivs))
start = time.time()
for i, j in nonzero_idx:
    if i <= j:
      print('Calculating probability for grid at {}'.format((i, j)), end='\n')
      z_1l[i][j] = fk(x4[i], x5[j])
for i, j in nonzero_idx:
    if i > j:
      z_1l[i][j] = z_1l[j][i]
end = time.time()
print('Time taken by Feynman-Kac computation = {}s'.format(end - start))
# Out:
# Calculating probability for grid at (0, 41)
# Calculating probability for grid at (0, 42)
# Calculating probability for grid at (0, 53)
# Calculating probability for grid at (1, 34)
# Calculating probability for grid at (1, 41)
# Calculating probability for grid at (1, 46)
# Calculating probability for grid at (1, 53)
# Calculating probability for grid at (2, 36)
# Calculating probability for grid at (2, 44)
# Calculating probability for grid at (2, 45)
# Calculating probability for grid at (2, 47)
# Calculating probability for grid at (2, 48)
# Calculating probability for grid at (2, 49)
# Calculating probability for grid at (2, 50)
# Calculating probability for grid at (2, 51)
# Calculating probability for grid at (2, 52)
# Calculating probability for grid at (2, 58)
# Calculating probability for grid at (3, 33)
# Calculating probability for grid at (3, 35)
# Calculating probability for grid at (3, 36)
# Calculating probability for grid at (3, 37)
# Calculating probability for grid at (3, 38)
# Calculating probability for grid at (3, 39)
# Calculating probability for grid at (3, 42)
# Calculating probability for grid at (3, 44)
# Calculating probability for grid at (3, 45)
# Calculating probability for grid at (3, 46)
# Calculating probability for grid at (3, 47)
# Calculating probability for grid at (3, 48)
# Calculating probability for grid at (3, 49)
# Calculating probability for grid at (3, 50)
# Calculating probability for grid at (3, 51)
# Calculating probability for grid at (3, 54)
# Calculating probability for grid at (3, 55)
# Calculating probability for grid at (3, 59)
# Calculating probability for grid at (3, 60)
# Calculating probability for grid at (3, 61)
# Calculating probability for grid at (3, 62)
# Calculating probability for grid at (3, 63)
# Calculating probability for grid at (3, 65)
# Calculating probability for grid at (4, 34)
# Calculating probability for grid at (4, 37)
# Calculating probability for grid at (4, 38)
# Calculating probability for grid at (4, 39)
# Calculating probability for grid at (4, 40)
# Calculating probability for grid at (4, 42)
# Calculating probability for grid at (4, 43)
# Calculating probability for grid at (4, 44)
# Calculating probability for grid at (4, 45)
# Calculating probability for grid at (4, 46)
# Calculating probability for grid at (4, 47)
# Calculating probability for grid at (4, 48)
# Calculating probability for grid at (4, 49)
# Calculating probability for grid at (4, 50)
# Calculating probability for grid at (4, 51)
# Calculating probability for grid at (4, 52)
# Calculating probability for grid at (4, 53)
# Calculating probability for grid at (4, 54)
# Calculating probability for grid at (4, 55)
# Calculating probability for grid at (4, 56)
# Calculating probability for grid at (4, 57)
# Calculating probability for grid at (4, 58)
# Calculating probability for grid at (4, 59)
# Calculating probability for grid at (4, 63)
# Calculating probability for grid at (4, 64)
# Calculating probability for grid at (5, 32)
# Calculating probability for grid at (5, 33)
# Calculating probability for grid at (5, 34)
# Calculating probability for grid at (5, 35)
# Calculating probability for grid at (5, 36)
# Calculating probability for grid at (5, 37)
# Calculating probability for grid at (5, 38)
# Calculating probability for grid at (5, 39)
# Calculating probability for grid at (5, 40)
# Calculating probability for grid at (5, 41)
# Calculating probability for grid at (5, 42)
# Calculating probability for grid at (5, 43)
# Calculating probability for grid at (5, 44)
# Calculating probability for grid at (5, 45)
# Calculating probability for grid at (5, 46)
# Calculating probability for grid at (5, 47)
# Calculating probability for grid at (5, 48)
# Calculating probability for grid at (5, 49)
# Calculating probability for grid at (5, 50)
# Calculating probability for grid at (5, 51)
# Calculating probability for grid at (5, 52)
# Calculating probability for grid at (5, 53)
# Calculating probability for grid at (5, 54)
# Calculating probability for grid at (5, 55)
# Calculating probability for grid at (5, 56)
# Calculating probability for grid at (5, 57)
# Calculating probability for grid at (5, 59)
# Calculating probability for grid at (5, 60)
# Calculating probability for grid at (5, 61)
# Calculating probability for grid at (5, 62)
# Calculating probability for grid at (5, 63)
# Calculating probability for grid at (5, 64)
# Calculating probability for grid at (5, 65)
# Calculating probability for grid at (6, 24)
# Calculating probability for grid at (6, 28)
# Calculating probability for grid at (6, 29)
# Calculating probability for grid at (6, 30)
# Calculating probability for grid at (6, 31)
# Calculating probability for grid at (6, 32)
# Calculating probability for grid at (6, 33)
# Calculating probability for grid at (6, 34)
# Calculating probability for grid at (6, 35)
# Calculating probability for grid at (6, 36)
# Calculating probability for grid at (6, 37)
# Calculating probability for grid at (6, 38)
# Calculating probability for grid at (6, 39)
# Calculating probability for grid at (6, 40)
# Calculating probability for grid at (6, 41)
# Calculating probability for grid at (6, 42)
# Calculating probability for grid at (6, 43)
# Calculating probability for grid at (6, 44)
# Calculating probability for grid at (6, 45)
# Calculating probability for grid at (6, 46)
# Calculating probability for grid at (6, 47)
# Calculating probability for grid at (6, 48)
# Calculating probability for grid at (6, 49)
# Calculating probability for grid at (6, 50)
# Calculating probability for grid at (6, 51)
# Calculating probability for grid at (6, 52)
# Calculating probability for grid at (6, 53)
# Calculating probability for grid at (6, 54)
# Calculating probability for grid at (6, 55)
# Calculating probability for grid at (6, 56)
# Calculating probability for grid at (6, 57)
# Calculating probability for grid at (6, 58)
# Calculating probability for grid at (6, 59)
# Calculating probability for grid at (6, 60)
# Calculating probability for grid at (6, 61)
# Calculating probability for grid at (6, 62)
# Calculating probability for grid at (6, 63)
# Calculating probability for grid at (6, 64)
# Calculating probability for grid at (6, 65)
# Calculating probability for grid at (6, 66)
# Calculating probability for grid at (6, 69)
# Calculating probability for grid at (6, 71)
# Calculating probability for grid at (7, 21)
# Calculating probability for grid at (7, 26)
# Calculating probability for grid at (7, 28)
# Calculating probability for grid at (7, 30)
# Calculating probability for grid at (7, 31)
# Calculating probability for grid at (7, 32)
# Calculating probability for grid at (7, 33)
# Calculating probability for grid at (7, 34)
# Calculating probability for grid at (7, 35)
# Calculating probability for grid at (7, 36)
# Calculating probability for grid at (7, 37)
# Calculating probability for grid at (7, 38)
# Calculating probability for grid at (7, 39)
# Calculating probability for grid at (7, 40)
# Calculating probability for grid at (7, 41)
# Calculating probability for grid at (7, 42)
# Calculating probability for grid at (7, 43)
# Calculating probability for grid at (7, 44)
# Calculating probability for grid at (7, 45)
# Calculating probability for grid at (7, 46)
# Calculating probability for grid at (7, 47)
# Calculating probability for grid at (7, 48)
# Calculating probability for grid at (7, 49)
# Calculating probability for grid at (7, 50)
# Calculating probability for grid at (7, 51)
# Calculating probability for grid at (7, 52)
# Calculating probability for grid at (7, 53)
# Calculating probability for grid at (7, 54)
# Calculating probability for grid at (7, 55)
# Calculating probability for grid at (7, 56)
# Calculating probability for grid at (7, 57)
# Calculating probability for grid at (7, 58)
# Calculating probability for grid at (7, 59)
# Calculating probability for grid at (7, 60)
# Calculating probability for grid at (7, 61)
# Calculating probability for grid at (7, 62)
# Calculating probability for grid at (7, 63)
# Calculating probability for grid at (7, 64)
# Calculating probability for grid at (7, 65)
# Calculating probability for grid at (7, 66)
# Calculating probability for grid at (7, 68)
# Calculating probability for grid at (7, 69)
# Calculating probability for grid at (7, 70)
# Calculating probability for grid at (7, 74)
# Calculating probability for grid at (8, 27)
# Calculating probability for grid at (8, 28)
# Calculating probability for grid at (8, 29)
# Calculating probability for grid at (8, 30)
# Calculating probability for grid at (8, 31)
# Calculating probability for grid at (8, 32)
# Calculating probability for grid at (8, 33)
# Calculating probability for grid at (8, 34)
# Calculating probability for grid at (8, 35)
# Calculating probability for grid at (8, 36)
# Calculating probability for grid at (8, 37)
# Calculating probability for grid at (8, 38)
# Calculating probability for grid at (8, 39)
# Calculating probability for grid at (8, 40)
# Calculating probability for grid at (8, 41)
# Calculating probability for grid at (8, 42)
# Calculating probability for grid at (8, 43)
# Calculating probability for grid at (8, 44)
# Calculating probability for grid at (8, 45)
# Calculating probability for grid at (8, 46)
# Calculating probability for grid at (8, 47)
# Calculating probability for grid at (8, 48)
# Calculating probability for grid at (8, 49)
# Calculating probability for grid at (8, 50)
# Calculating probability for grid at (8, 51)
# Calculating probability for grid at (8, 52)
# Calculating probability for grid at (8, 53)
# Calculating probability for grid at (8, 54)
# Calculating probability for grid at (8, 55)
# Calculating probability for grid at (8, 56)
# Calculating probability for grid at (8, 57)
# Calculating probability for grid at (8, 58)
# Calculating probability for grid at (8, 59)
# Calculating probability for grid at (8, 60)
# Calculating probability for grid at (8, 61)
# Calculating probability for grid at (8, 62)
# Calculating probability for grid at (8, 63)
# Calculating probability for grid at (8, 64)
# Calculating probability for grid at (8, 65)
# Calculating probability for grid at (8, 66)
# Calculating probability for grid at (8, 67)
# Calculating probability for grid at (8, 68)
# Calculating probability for grid at (8, 70)
# Calculating probability for grid at (8, 71)
# Calculating probability for grid at (9, 23)
# Calculating probability for grid at (9, 24)
# Calculating probability for grid at (9, 25)
# Calculating probability for grid at (9, 26)
# Calculating probability for grid at (9, 27)
# Calculating probability for grid at (9, 28)
# Calculating probability for grid at (9, 29)
# Calculating probability for grid at (9, 30)
# Calculating probability for grid at (9, 31)
# Calculating probability for grid at (9, 32)
# Calculating probability for grid at (9, 33)
# Calculating probability for grid at (9, 34)
# Calculating probability for grid at (9, 35)
# Calculating probability for grid at (9, 36)
# Calculating probability for grid at (9, 37)
# Calculating probability for grid at (9, 38)
# Calculating probability for grid at (9, 39)
# Calculating probability for grid at (9, 40)
# Calculating probability for grid at (9, 41)
# Calculating probability for grid at (9, 42)
# Calculating probability for grid at (9, 43)
# Calculating probability for grid at (9, 44)
# Calculating probability for grid at (9, 45)
# Calculating probability for grid at (9, 46)
# Calculating probability for grid at (9, 47)
# Calculating probability for grid at (9, 48)
# Calculating probability for grid at (9, 49)
# Calculating probability for grid at (9, 50)
# Calculating probability for grid at (9, 51)
# Calculating probability for grid at (9, 52)
# Calculating probability for grid at (9, 53)
# Calculating probability for grid at (9, 54)
# Calculating probability for grid at (9, 55)
# Calculating probability for grid at (9, 56)
# Calculating probability for grid at (9, 57)
# Calculating probability for grid at (9, 58)
# Calculating probability for grid at (9, 59)
# Calculating probability for grid at (9, 60)
# Calculating probability for grid at (9, 61)
# Calculating probability for grid at (9, 62)
# Calculating probability for grid at (9, 63)
# Calculating probability for grid at (9, 64)
# Calculating probability for grid at (9, 65)
# Calculating probability for grid at (9, 66)
# Calculating probability for grid at (9, 67)
# Calculating probability for grid at (9, 68)
# Calculating probability for grid at (9, 69)
# Calculating probability for grid at (9, 70)
# Calculating probability for grid at (9, 71)
# Calculating probability for grid at (9, 72)
# Calculating probability for grid at (9, 73)
# Calculating probability for grid at (9, 78)
# Calculating probability for grid at (10, 20)
# Calculating probability for grid at (10, 23)
# Calculating probability for grid at (10, 24)
# Calculating probability for grid at (10, 25)
# Calculating probability for grid at (10, 26)
# Calculating probability for grid at (10, 27)
# Calculating probability for grid at (10, 28)
# Calculating probability for grid at (10, 29)
# Calculating probability for grid at (10, 30)
# Calculating probability for grid at (10, 31)
# Calculating probability for grid at (10, 32)
# Calculating probability for grid at (10, 33)
# Calculating probability for grid at (10, 34)
# Calculating probability for grid at (10, 35)
# Calculating probability for grid at (10, 36)
# Calculating probability for grid at (10, 37)
# Calculating probability for grid at (10, 38)
# Calculating probability for grid at (10, 39)
# Calculating probability for grid at (10, 40)
# Calculating probability for grid at (10, 41)
# Calculating probability for grid at (10, 42)
# Calculating probability for grid at (10, 43)
# Calculating probability for grid at (10, 44)
# Calculating probability for grid at (10, 45)
# Calculating probability for grid at (10, 46)
# Calculating probability for grid at (10, 47)
# Calculating probability for grid at (10, 48)
# Calculating probability for grid at (10, 49)
# Calculating probability for grid at (10, 50)
# Calculating probability for grid at (10, 51)
# Calculating probability for grid at (10, 52)
# Calculating probability for grid at (10, 53)
# Calculating probability for grid at (10, 54)
# Calculating probability for grid at (10, 55)
# Calculating probability for grid at (10, 56)
# Calculating probability for grid at (10, 57)
# Calculating probability for grid at (10, 58)
# Calculating probability for grid at (10, 59)
# Calculating probability for grid at (10, 60)
# Calculating probability for grid at (10, 61)
# Calculating probability for grid at (10, 62)
# Calculating probability for grid at (10, 63)
# Calculating probability for grid at (10, 64)
# Calculating probability for grid at (10, 65)
# Calculating probability for grid at (10, 66)
# Calculating probability for grid at (10, 67)
# Calculating probability for grid at (10, 68)
# Calculating probability for grid at (10, 69)
# Calculating probability for grid at (10, 70)
# Calculating probability for grid at (10, 71)
# Calculating probability for grid at (10, 72)
# Calculating probability for grid at (10, 73)
# Calculating probability for grid at (10, 74)
# Calculating probability for grid at (10, 78)
# Calculating probability for grid at (11, 21)
# Calculating probability for grid at (11, 22)
# Calculating probability for grid at (11, 23)
# Calculating probability for grid at (11, 24)
# Calculating probability for grid at (11, 25)
# Calculating probability for grid at (11, 26)
# Calculating probability for grid at (11, 27)
# Calculating probability for grid at (11, 28)
# Calculating probability for grid at (11, 29)
# Calculating probability for grid at (11, 30)
# Calculating probability for grid at (11, 31)
# Calculating probability for grid at (11, 32)
# Calculating probability for grid at (11, 33)
# Calculating probability for grid at (11, 34)
# Calculating probability for grid at (11, 35)
# Calculating probability for grid at (11, 36)
# Calculating probability for grid at (11, 37)
# Calculating probability for grid at (11, 38)
# Calculating probability for grid at (11, 39)
# Calculating probability for grid at (11, 40)
# Calculating probability for grid at (11, 41)
# Calculating probability for grid at (11, 42)
# Calculating probability for grid at (11, 43)
# Calculating probability for grid at (11, 44)
# Calculating probability for grid at (11, 45)
# Calculating probability for grid at (11, 46)
# Calculating probability for grid at (11, 47)
# Calculating probability for grid at (11, 48)
# Calculating probability for grid at (11, 49)
# Calculating probability for grid at (11, 50)
# Calculating probability for grid at (11, 51)
# Calculating probability for grid at (11, 52)
# Calculating probability for grid at (11, 53)
# Calculating probability for grid at (11, 54)
# Calculating probability for grid at (11, 55)
# Calculating probability for grid at (11, 56)
# Calculating probability for grid at (11, 57)
# Calculating probability for grid at (11, 58)
# Calculating probability for grid at (11, 59)
# Calculating probability for grid at (11, 60)
# Calculating probability for grid at (11, 61)
# Calculating probability for grid at (11, 62)
# Calculating probability for grid at (11, 63)
# Calculating probability for grid at (11, 64)
# Calculating probability for grid at (11, 65)
# Calculating probability for grid at (11, 66)
# Calculating probability for grid at (11, 67)
# Calculating probability for grid at (11, 68)
# Calculating probability for grid at (11, 69)
# Calculating probability for grid at (11, 70)
# Calculating probability for grid at (11, 71)
# Calculating probability for grid at (11, 72)
# Calculating probability for grid at (11, 73)
# Calculating probability for grid at (11, 75)
# Calculating probability for grid at (11, 76)
# Calculating probability for grid at (12, 14)
# Calculating probability for grid at (12, 17)
# Calculating probability for grid at (12, 21)
# Calculating probability for grid at (12, 22)
# Calculating probability for grid at (12, 23)
# Calculating probability for grid at (12, 24)
# Calculating probability for grid at (12, 25)
# Calculating probability for grid at (12, 26)
# Calculating probability for grid at (12, 27)
# Calculating probability for grid at (12, 28)
# Calculating probability for grid at (12, 29)
# Calculating probability for grid at (12, 30)
# Calculating probability for grid at (12, 31)
# Calculating probability for grid at (12, 32)
# Calculating probability for grid at (12, 33)
# Calculating probability for grid at (12, 34)
# Calculating probability for grid at (12, 35)
# Calculating probability for grid at (12, 36)
# Calculating probability for grid at (12, 37)
# Calculating probability for grid at (12, 38)
# Calculating probability for grid at (12, 39)
# Calculating probability for grid at (12, 40)
# Calculating probability for grid at (12, 41)
# Calculating probability for grid at (12, 42)
# Calculating probability for grid at (12, 43)
# Calculating probability for grid at (12, 44)
# Calculating probability for grid at (12, 45)
# Calculating probability for grid at (12, 46)
# Calculating probability for grid at (12, 47)
# Calculating probability for grid at (12, 48)
# Calculating probability for grid at (12, 49)
# Calculating probability for grid at (12, 50)
# Calculating probability for grid at (12, 51)
# Calculating probability for grid at (12, 52)
# Calculating probability for grid at (12, 53)
# Calculating probability for grid at (12, 54)
# Calculating probability for grid at (12, 55)
# Calculating probability for grid at (12, 56)
# Calculating probability for grid at (12, 57)
# Calculating probability for grid at (12, 58)
# Calculating probability for grid at (12, 59)
# Calculating probability for grid at (12, 60)
# Calculating probability for grid at (12, 61)
# Calculating probability for grid at (12, 62)
# Calculating probability for grid at (12, 63)
# Calculating probability for grid at (12, 64)
# Calculating probability for grid at (12, 65)
# Calculating probability for grid at (12, 66)
# Calculating probability for grid at (12, 67)
# Calculating probability for grid at (12, 68)
# Calculating probability for grid at (12, 69)
# Calculating probability for grid at (12, 70)
# Calculating probability for grid at (12, 71)
# Calculating probability for grid at (12, 72)
# Calculating probability for grid at (12, 73)
# Calculating probability for grid at (12, 74)
# Calculating probability for grid at (12, 75)
# Calculating probability for grid at (12, 77)
# Calculating probability for grid at (12, 78)
# Calculating probability for grid at (13, 18)
# Calculating probability for grid at (13, 19)
# Calculating probability for grid at (13, 20)
# Calculating probability for grid at (13, 21)
# Calculating probability for grid at (13, 22)
# Calculating probability for grid at (13, 23)
# Calculating probability for grid at (13, 24)
# Calculating probability for grid at (13, 25)
# Calculating probability for grid at (13, 26)
# Calculating probability for grid at (13, 27)
# Calculating probability for grid at (13, 28)
# Calculating probability for grid at (13, 29)
# Calculating probability for grid at (13, 30)
# Calculating probability for grid at (13, 31)
# Calculating probability for grid at (13, 32)
# Calculating probability for grid at (13, 33)
# Calculating probability for grid at (13, 34)
# Calculating probability for grid at (13, 35)
# Calculating probability for grid at (13, 36)
# Calculating probability for grid at (13, 37)
# Calculating probability for grid at (13, 38)
# Calculating probability for grid at (13, 39)
# Calculating probability for grid at (13, 40)
# Calculating probability for grid at (13, 41)
# Calculating probability for grid at (13, 42)
# Calculating probability for grid at (13, 43)
# Calculating probability for grid at (13, 44)
# Calculating probability for grid at (13, 45)
# Calculating probability for grid at (13, 46)
# Calculating probability for grid at (13, 47)
# Calculating probability for grid at (13, 48)
# Calculating probability for grid at (13, 49)
# Calculating probability for grid at (13, 50)
# Calculating probability for grid at (13, 51)
# Calculating probability for grid at (13, 52)
# Calculating probability for grid at (13, 53)
# Calculating probability for grid at (13, 54)
# Calculating probability for grid at (13, 55)
# Calculating probability for grid at (13, 56)
# Calculating probability for grid at (13, 57)
# Calculating probability for grid at (13, 58)
# Calculating probability for grid at (13, 59)
# Calculating probability for grid at (13, 60)
# Calculating probability for grid at (13, 61)
# Calculating probability for grid at (13, 62)
# Calculating probability for grid at (13, 63)
# Calculating probability for grid at (13, 64)
# Calculating probability for grid at (13, 65)
# Calculating probability for grid at (13, 66)
# Calculating probability for grid at (13, 67)
# Calculating probability for grid at (13, 68)
# Calculating probability for grid at (13, 69)
# Calculating probability for grid at (13, 70)
# Calculating probability for grid at (13, 71)
# Calculating probability for grid at (13, 72)
# Calculating probability for grid at (13, 73)
# Calculating probability for grid at (13, 74)
# Calculating probability for grid at (13, 75)
# Calculating probability for grid at (13, 76)
# Calculating probability for grid at (13, 78)
# Calculating probability for grid at (13, 79)
# Calculating probability for grid at (14, 16)
# Calculating probability for grid at (14, 17)
# Calculating probability for grid at (14, 18)
# Calculating probability for grid at (14, 19)
# Calculating probability for grid at (14, 20)
# Calculating probability for grid at (14, 21)
# Calculating probability for grid at (14, 22)
# Calculating probability for grid at (14, 23)
# Calculating probability for grid at (14, 24)
# Calculating probability for grid at (14, 25)
# Calculating probability for grid at (14, 26)
# Calculating probability for grid at (14, 27)
# Calculating probability for grid at (14, 28)
# Calculating probability for grid at (14, 29)
# Calculating probability for grid at (14, 30)
# Calculating probability for grid at (14, 31)
# Calculating probability for grid at (14, 32)
# Calculating probability for grid at (14, 33)
# Calculating probability for grid at (14, 34)
# Calculating probability for grid at (14, 35)
# Calculating probability for grid at (14, 36)
# Calculating probability for grid at (14, 37)
# Calculating probability for grid at (14, 38)
# Calculating probability for grid at (14, 39)
# Calculating probability for grid at (14, 40)
# Calculating probability for grid at (14, 41)
# Calculating probability for grid at (14, 42)
# Calculating probability for grid at (14, 43)
# Calculating probability for grid at (14, 44)
# Calculating probability for grid at (14, 45)
# Calculating probability for grid at (14, 46)
# Calculating probability for grid at (14, 47)
# Calculating probability for grid at (14, 48)
# Calculating probability for grid at (14, 49)
# Calculating probability for grid at (14, 50)
# Calculating probability for grid at (14, 51)
# Calculating probability for grid at (14, 52)
# Calculating probability for grid at (14, 53)
# Calculating probability for grid at (14, 54)
# Calculating probability for grid at (14, 55)
# Calculating probability for grid at (14, 56)
# Calculating probability for grid at (14, 57)
# Calculating probability for grid at (14, 58)
# Calculating probability for grid at (14, 59)
# Calculating probability for grid at (14, 60)
# Calculating probability for grid at (14, 61)
# Calculating probability for grid at (14, 62)
# Calculating probability for grid at (14, 63)
# Calculating probability for grid at (14, 64)
# Calculating probability for grid at (14, 65)
# Calculating probability for grid at (14, 66)
# Calculating probability for grid at (14, 67)
# Calculating probability for grid at (14, 68)
# Calculating probability for grid at (14, 69)
# Calculating probability for grid at (14, 70)
# Calculating probability for grid at (14, 71)
# Calculating probability for grid at (14, 72)
# Calculating probability for grid at (14, 73)
# Calculating probability for grid at (14, 74)
# Calculating probability for grid at (14, 75)
# Calculating probability for grid at (14, 76)
# Calculating probability for grid at (14, 77)
# Calculating probability for grid at (14, 79)
# Calculating probability for grid at (15, 17)
# Calculating probability for grid at (15, 18)
# Calculating probability for grid at (15, 19)
# Calculating probability for grid at (15, 20)
# Calculating probability for grid at (15, 21)
# Calculating probability for grid at (15, 22)
# Calculating probability for grid at (15, 23)
# Calculating probability for grid at (15, 24)
# Calculating probability for grid at (15, 25)
# Calculating probability for grid at (15, 26)
# Calculating probability for grid at (15, 27)
# Calculating probability for grid at (15, 28)
# Calculating probability for grid at (15, 29)
# Calculating probability for grid at (15, 30)
# Calculating probability for grid at (15, 31)
# Calculating probability for grid at (15, 32)
# Calculating probability for grid at (15, 33)
# Calculating probability for grid at (15, 34)
# Calculating probability for grid at (15, 35)
# Calculating probability for grid at (15, 36)
# Calculating probability for grid at (15, 37)
# Calculating probability for grid at (15, 38)
# Calculating probability for grid at (15, 39)
# Calculating probability for grid at (15, 40)
# Calculating probability for grid at (15, 41)
# Calculating probability for grid at (15, 42)
# Calculating probability for grid at (15, 43)
# Calculating probability for grid at (15, 44)
# Calculating probability for grid at (15, 45)
# Calculating probability for grid at (15, 46)
# Calculating probability for grid at (15, 47)
# Calculating probability for grid at (15, 48)
# Calculating probability for grid at (15, 49)
# Calculating probability for grid at (15, 50)
# Calculating probability for grid at (15, 51)
# Calculating probability for grid at (15, 52)
# Calculating probability for grid at (15, 53)
# Calculating probability for grid at (15, 54)
# Calculating probability for grid at (15, 55)
# Calculating probability for grid at (15, 56)
# Calculating probability for grid at (15, 57)
# Calculating probability for grid at (15, 58)
# Calculating probability for grid at (15, 59)
# Calculating probability for grid at (15, 60)
# Calculating probability for grid at (15, 61)
# Calculating probability for grid at (15, 62)
# Calculating probability for grid at (15, 63)
# Calculating probability for grid at (15, 64)
# Calculating probability for grid at (15, 65)
# Calculating probability for grid at (15, 66)
# Calculating probability for grid at (15, 67)
# Calculating probability for grid at (15, 68)
# Calculating probability for grid at (15, 69)
# Calculating probability for grid at (15, 70)
# Calculating probability for grid at (15, 71)
# Calculating probability for grid at (15, 72)
# Calculating probability for grid at (15, 73)
# Calculating probability for grid at (15, 74)
# Calculating probability for grid at (15, 75)
# Calculating probability for grid at (15, 76)
# Calculating probability for grid at (15, 77)
# Calculating probability for grid at (15, 78)
# Calculating probability for grid at (15, 79)
# Calculating probability for grid at (15, 80)
# Calculating probability for grid at (15, 82)
# Calculating probability for grid at (16, 16)
# Calculating probability for grid at (16, 17)
# Calculating probability for grid at (16, 18)
# Calculating probability for grid at (16, 19)
# Calculating probability for grid at (16, 20)
# Calculating probability for grid at (16, 21)
# Calculating probability for grid at (16, 22)
# Calculating probability for grid at (16, 23)
# Calculating probability for grid at (16, 24)
# Calculating probability for grid at (16, 25)
# Calculating probability for grid at (16, 26)
# Calculating probability for grid at (16, 27)
# Calculating probability for grid at (16, 28)
# Calculating probability for grid at (16, 29)
# Calculating probability for grid at (16, 30)
# Calculating probability for grid at (16, 31)
# Calculating probability for grid at (16, 32)
# Calculating probability for grid at (16, 33)
# Calculating probability for grid at (16, 34)
# Calculating probability for grid at (16, 35)
# Calculating probability for grid at (16, 36)
# Calculating probability for grid at (16, 37)
# Calculating probability for grid at (16, 38)
# Calculating probability for grid at (16, 39)
# Calculating probability for grid at (16, 40)
# Calculating probability for grid at (16, 41)
# Calculating probability for grid at (16, 42)
# Calculating probability for grid at (16, 43)
# Calculating probability for grid at (16, 44)
# Calculating probability for grid at (16, 45)
# Calculating probability for grid at (16, 46)
# Calculating probability for grid at (16, 47)
# Calculating probability for grid at (16, 48)
# Calculating probability for grid at (16, 49)
# Calculating probability for grid at (16, 50)
# Calculating probability for grid at (16, 51)
# Calculating probability for grid at (16, 52)
# Calculating probability for grid at (16, 53)
# Calculating probability for grid at (16, 54)
# Calculating probability for grid at (16, 55)
# Calculating probability for grid at (16, 56)
# Calculating probability for grid at (16, 57)
# Calculating probability for grid at (16, 58)
# Calculating probability for grid at (16, 59)
# Calculating probability for grid at (16, 60)
# Calculating probability for grid at (16, 61)
# Calculating probability for grid at (16, 62)
# Calculating probability for grid at (16, 63)
# Calculating probability for grid at (16, 64)
# Calculating probability for grid at (16, 65)
# Calculating probability for grid at (16, 66)
# Calculating probability for grid at (16, 67)
# Calculating probability for grid at (16, 68)
# Calculating probability for grid at (16, 69)
# Calculating probability for grid at (16, 70)
# Calculating probability for grid at (16, 71)
# Calculating probability for grid at (16, 72)
# Calculating probability for grid at (16, 73)
# Calculating probability for grid at (16, 74)
# Calculating probability for grid at (16, 75)
# Calculating probability for grid at (16, 76)
# Calculating probability for grid at (16, 77)
# Calculating probability for grid at (16, 78)
# Calculating probability for grid at (16, 79)
# Calculating probability for grid at (16, 80)
# Calculating probability for grid at (16, 81)
# Calculating probability for grid at (16, 84)
# Calculating probability for grid at (17, 17)
# Calculating probability for grid at (17, 18)
# Calculating probability for grid at (17, 19)
# Calculating probability for grid at (17, 20)
# Calculating probability for grid at (17, 21)
# Calculating probability for grid at (17, 22)
# Calculating probability for grid at (17, 23)
# Calculating probability for grid at (17, 24)
# Calculating probability for grid at (17, 25)
# Calculating probability for grid at (17, 26)
# Calculating probability for grid at (17, 27)
# Calculating probability for grid at (17, 28)
# Calculating probability for grid at (17, 29)
# Calculating probability for grid at (17, 30)
# Calculating probability for grid at (17, 31)
# Calculating probability for grid at (17, 32)
# Calculating probability for grid at (17, 33)
# Calculating probability for grid at (17, 34)
# Calculating probability for grid at (17, 35)
# Calculating probability for grid at (17, 36)
# Calculating probability for grid at (17, 37)
# Calculating probability for grid at (17, 38)
# Calculating probability for grid at (17, 39)
# Calculating probability for grid at (17, 40)
# Calculating probability for grid at (17, 41)
# Calculating probability for grid at (17, 42)
# Calculating probability for grid at (17, 43)
# Calculating probability for grid at (17, 44)
# Calculating probability for grid at (17, 45)
# Calculating probability for grid at (17, 46)
# Calculating probability for grid at (17, 47)
# Calculating probability for grid at (17, 48)
# Calculating probability for grid at (17, 49)
# Calculating probability for grid at (17, 50)
# Calculating probability for grid at (17, 51)
# Calculating probability for grid at (17, 52)
# Calculating probability for grid at (17, 53)
# Calculating probability for grid at (17, 54)
# Calculating probability for grid at (17, 55)
# Calculating probability for grid at (17, 56)
# Calculating probability for grid at (17, 57)
# Calculating probability for grid at (17, 58)
# Calculating probability for grid at (17, 59)
# Calculating probability for grid at (17, 60)
# Calculating probability for grid at (17, 61)
# Calculating probability for grid at (17, 62)
# Calculating probability for grid at (17, 63)
# Calculating probability for grid at (17, 64)
# Calculating probability for grid at (17, 65)
# Calculating probability for grid at (17, 66)
# Calculating probability for grid at (17, 67)
# Calculating probability for grid at (17, 68)
# Calculating probability for grid at (17, 69)
# Calculating probability for grid at (17, 70)
# Calculating probability for grid at (17, 71)
# Calculating probability for grid at (17, 72)
# Calculating probability for grid at (17, 73)
# Calculating probability for grid at (17, 74)
# Calculating probability for grid at (17, 75)
# Calculating probability for grid at (17, 76)
# Calculating probability for grid at (17, 77)
# Calculating probability for grid at (17, 78)
# Calculating probability for grid at (17, 79)
# Calculating probability for grid at (17, 80)
# Calculating probability for grid at (17, 81)
# Calculating probability for grid at (17, 82)
# Calculating probability for grid at (17, 84)
# Calculating probability for grid at (18, 18)
# Calculating probability for grid at (18, 19)
# Calculating probability for grid at (18, 20)
# Calculating probability for grid at (18, 21)
# Calculating probability for grid at (18, 22)
# Calculating probability for grid at (18, 23)
# Calculating probability for grid at (18, 24)
# Calculating probability for grid at (18, 25)
# Calculating probability for grid at (18, 26)
# Calculating probability for grid at (18, 27)
# Calculating probability for grid at (18, 28)
# Calculating probability for grid at (18, 29)
# Calculating probability for grid at (18, 30)
# Calculating probability for grid at (18, 31)
# Calculating probability for grid at (18, 32)
# Calculating probability for grid at (18, 33)
# Calculating probability for grid at (18, 34)
# Calculating probability for grid at (18, 35)
# Calculating probability for grid at (18, 36)
# Calculating probability for grid at (18, 37)
# Calculating probability for grid at (18, 38)
# Calculating probability for grid at (18, 39)
# Calculating probability for grid at (18, 40)
# Calculating probability for grid at (18, 41)
# Calculating probability for grid at (18, 42)
# Calculating probability for grid at (18, 43)
# Calculating probability for grid at (18, 44)
# Calculating probability for grid at (18, 45)
# Calculating probability for grid at (18, 46)
# Calculating probability for grid at (18, 47)
# Calculating probability for grid at (18, 48)
# Calculating probability for grid at (18, 49)
# Calculating probability for grid at (18, 50)
# Calculating probability for grid at (18, 51)
# Calculating probability for grid at (18, 52)
# Calculating probability for grid at (18, 53)
# Calculating probability for grid at (18, 54)
# Calculating probability for grid at (18, 55)
# Calculating probability for grid at (18, 56)
# Calculating probability for grid at (18, 57)
# Calculating probability for grid at (18, 58)
# Calculating probability for grid at (18, 59)
# Calculating probability for grid at (18, 60)
# Calculating probability for grid at (18, 61)
# Calculating probability for grid at (18, 62)
# Calculating probability for grid at (18, 63)
# Calculating probability for grid at (18, 64)
# Calculating probability for grid at (18, 65)
# Calculating probability for grid at (18, 66)
# Calculating probability for grid at (18, 67)
# Calculating probability for grid at (18, 68)
# Calculating probability for grid at (18, 69)
# Calculating probability for grid at (18, 70)
# Calculating probability for grid at (18, 71)
# Calculating probability for grid at (18, 72)
# Calculating probability for grid at (18, 73)
# Calculating probability for grid at (18, 74)
# Calculating probability for grid at (18, 75)
# Calculating probability for grid at (18, 76)
# Calculating probability for grid at (18, 77)
# Calculating probability for grid at (18, 78)
# Calculating probability for grid at (18, 79)
# Calculating probability for grid at (18, 80)
# Calculating probability for grid at (18, 81)
# Calculating probability for grid at (18, 82)
# Calculating probability for grid at (18, 83)
# Calculating probability for grid at (18, 86)
# Calculating probability for grid at (19, 19)
# Calculating probability for grid at (19, 20)
# Calculating probability for grid at (19, 21)
# Calculating probability for grid at (19, 22)
# Calculating probability for grid at (19, 23)
# Calculating probability for grid at (19, 24)
# Calculating probability for grid at (19, 25)
# Calculating probability for grid at (19, 26)
# Calculating probability for grid at (19, 27)
# Calculating probability for grid at (19, 28)
# Calculating probability for grid at (19, 29)
# Calculating probability for grid at (19, 30)
# Calculating probability for grid at (19, 31)
# Calculating probability for grid at (19, 32)
# Calculating probability for grid at (19, 33)
# Calculating probability for grid at (19, 34)
# Calculating probability for grid at (19, 35)
# Calculating probability for grid at (19, 36)
# Calculating probability for grid at (19, 37)
# Calculating probability for grid at (19, 38)
# Calculating probability for grid at (19, 39)
# Calculating probability for grid at (19, 40)
# Calculating probability for grid at (19, 41)
# Calculating probability for grid at (19, 42)
# Calculating probability for grid at (19, 43)
# Calculating probability for grid at (19, 44)
# Calculating probability for grid at (19, 45)
# Calculating probability for grid at (19, 46)
# Calculating probability for grid at (19, 47)
# Calculating probability for grid at (19, 48)
# Calculating probability for grid at (19, 49)
# Calculating probability for grid at (19, 50)
# Calculating probability for grid at (19, 51)
# Calculating probability for grid at (19, 52)
# Calculating probability for grid at (19, 53)
# Calculating probability for grid at (19, 54)
# Calculating probability for grid at (19, 55)
# Calculating probability for grid at (19, 56)
# Calculating probability for grid at (19, 57)
# Calculating probability for grid at (19, 58)
# Calculating probability for grid at (19, 59)
# Calculating probability for grid at (19, 60)
# Calculating probability for grid at (19, 61)
# Calculating probability for grid at (19, 62)
# Calculating probability for grid at (19, 63)
# Calculating probability for grid at (19, 64)
# Calculating probability for grid at (19, 65)
# Calculating probability for grid at (19, 66)
# Calculating probability for grid at (19, 67)
# Calculating probability for grid at (19, 68)
# Calculating probability for grid at (19, 69)
# Calculating probability for grid at (19, 70)
# Calculating probability for grid at (19, 71)
# Calculating probability for grid at (19, 72)
# Calculating probability for grid at (19, 73)
# Calculating probability for grid at (19, 74)
# Calculating probability for grid at (19, 75)
# Calculating probability for grid at (19, 76)
# Calculating probability for grid at (19, 77)
# Calculating probability for grid at (19, 78)
# Calculating probability for grid at (19, 79)
# Calculating probability for grid at (19, 80)
# Calculating probability for grid at (19, 81)
# Calculating probability for grid at (19, 82)
# Calculating probability for grid at (19, 83)
# Calculating probability for grid at (19, 84)
# Calculating probability for grid at (20, 20)
# Calculating probability for grid at (20, 21)
# Calculating probability for grid at (20, 22)
# Calculating probability for grid at (20, 23)
# Calculating probability for grid at (20, 24)
# Calculating probability for grid at (20, 25)
# Calculating probability for grid at (20, 26)
# Calculating probability for grid at (20, 27)
# Calculating probability for grid at (20, 28)
# Calculating probability for grid at (20, 29)
# Calculating probability for grid at (20, 30)
# Calculating probability for grid at (20, 31)
# Calculating probability for grid at (20, 32)
# Calculating probability for grid at (20, 33)
# Calculating probability for grid at (20, 34)
# Calculating probability for grid at (20, 35)
# Calculating probability for grid at (20, 36)
# Calculating probability for grid at (20, 37)
# Calculating probability for grid at (20, 38)
# Calculating probability for grid at (20, 39)
# Calculating probability for grid at (20, 40)
# Calculating probability for grid at (20, 41)
# Calculating probability for grid at (20, 42)
# Calculating probability for grid at (20, 43)
# Calculating probability for grid at (20, 44)
# Calculating probability for grid at (20, 45)
# Calculating probability for grid at (20, 46)
# Calculating probability for grid at (20, 47)
# Calculating probability for grid at (20, 48)
# Calculating probability for grid at (20, 49)
# Calculating probability for grid at (20, 50)
# Calculating probability for grid at (20, 51)
# Calculating probability for grid at (20, 52)
# Calculating probability for grid at (20, 53)
# Calculating probability for grid at (20, 54)
# Calculating probability for grid at (20, 55)
# Calculating probability for grid at (20, 56)
# Calculating probability for grid at (20, 57)
# Calculating probability for grid at (20, 58)
# Calculating probability for grid at (20, 59)
# Calculating probability for grid at (20, 60)
# Calculating probability for grid at (20, 61)
# Calculating probability for grid at (20, 62)
# Calculating probability for grid at (20, 63)
# Calculating probability for grid at (20, 64)
# Calculating probability for grid at (20, 65)
# Calculating probability for grid at (20, 66)
# Calculating probability for grid at (20, 67)
# Calculating probability for grid at (20, 68)
# Calculating probability for grid at (20, 69)
# Calculating probability for grid at (20, 70)
# Calculating probability for grid at (20, 71)
# Calculating probability for grid at (20, 72)
# Calculating probability for grid at (20, 73)
# Calculating probability for grid at (20, 74)
# Calculating probability for grid at (20, 75)
# Calculating probability for grid at (20, 76)
# Calculating probability for grid at (20, 77)
# Calculating probability for grid at (20, 78)
# Calculating probability for grid at (20, 79)
# Calculating probability for grid at (20, 80)
# Calculating probability for grid at (20, 81)
# Calculating probability for grid at (20, 82)
# Calculating probability for grid at (20, 83)
# Calculating probability for grid at (20, 84)
# Calculating probability for grid at (20, 85)
# Calculating probability for grid at (20, 86)
# Calculating probability for grid at (20, 87)
# Calculating probability for grid at (21, 21)
# Calculating probability for grid at (21, 22)
# Calculating probability for grid at (21, 23)
# Calculating probability for grid at (21, 24)
# Calculating probability for grid at (21, 25)
# Calculating probability for grid at (21, 26)
# Calculating probability for grid at (21, 27)
# Calculating probability for grid at (21, 28)
# Calculating probability for grid at (21, 29)
# Calculating probability for grid at (21, 30)
# Calculating probability for grid at (21, 31)
# Calculating probability for grid at (21, 32)
# Calculating probability for grid at (21, 33)
# Calculating probability for grid at (21, 34)
# Calculating probability for grid at (21, 35)
# Calculating probability for grid at (21, 36)
# Calculating probability for grid at (21, 37)
# Calculating probability for grid at (21, 38)
# Calculating probability for grid at (21, 39)
# Calculating probability for grid at (21, 40)
# Calculating probability for grid at (21, 41)
# Calculating probability for grid at (21, 42)
# Calculating probability for grid at (21, 43)
# Calculating probability for grid at (21, 44)
# Calculating probability for grid at (21, 45)
# Calculating probability for grid at (21, 46)
# Calculating probability for grid at (21, 47)
# Calculating probability for grid at (21, 48)
# Calculating probability for grid at (21, 49)
# Calculating probability for grid at (21, 50)
# Calculating probability for grid at (21, 51)
# Calculating probability for grid at (21, 52)
# Calculating probability for grid at (21, 53)
# Calculating probability for grid at (21, 54)
# Calculating probability for grid at (21, 55)
# Calculating probability for grid at (21, 56)
# Calculating probability for grid at (21, 57)
# Calculating probability for grid at (21, 58)
# Calculating probability for grid at (21, 59)
# Calculating probability for grid at (21, 60)
# Calculating probability for grid at (21, 61)
# Calculating probability for grid at (21, 62)
# Calculating probability for grid at (21, 63)
# Calculating probability for grid at (21, 64)
# Calculating probability for grid at (21, 65)
# Calculating probability for grid at (21, 66)
# Calculating probability for grid at (21, 67)
# Calculating probability for grid at (21, 68)
# Calculating probability for grid at (21, 69)
# Calculating probability for grid at (21, 70)
# Calculating probability for grid at (21, 71)
# Calculating probability for grid at (21, 72)
# Calculating probability for grid at (21, 73)
# Calculating probability for grid at (21, 74)
# Calculating probability for grid at (21, 75)
# Calculating probability for grid at (21, 76)
# Calculating probability for grid at (21, 77)
# Calculating probability for grid at (21, 78)
# Calculating probability for grid at (21, 79)
# Calculating probability for grid at (21, 80)
# Calculating probability for grid at (21, 81)
# Calculating probability for grid at (21, 82)
# Calculating probability for grid at (21, 83)
# Calculating probability for grid at (21, 84)
# Calculating probability for grid at (21, 85)
# Calculating probability for grid at (21, 86)
# Calculating probability for grid at (21, 90)
# Calculating probability for grid at (22, 22)
# Calculating probability for grid at (22, 23)
# Calculating probability for grid at (22, 24)
# Calculating probability for grid at (22, 25)
# Calculating probability for grid at (22, 26)
# Calculating probability for grid at (22, 27)
# Calculating probability for grid at (22, 28)
# Calculating probability for grid at (22, 29)
# Calculating probability for grid at (22, 30)
# Calculating probability for grid at (22, 31)
# Calculating probability for grid at (22, 32)
# Calculating probability for grid at (22, 33)
# Calculating probability for grid at (22, 34)
# Calculating probability for grid at (22, 35)
# Calculating probability for grid at (22, 36)
# Calculating probability for grid at (22, 37)
# Calculating probability for grid at (22, 38)
# Calculating probability for grid at (22, 39)
# Calculating probability for grid at (22, 40)
# Calculating probability for grid at (22, 41)
# Calculating probability for grid at (22, 42)
# Calculating probability for grid at (22, 43)
# Calculating probability for grid at (22, 44)
# Calculating probability for grid at (22, 45)
# Calculating probability for grid at (22, 46)
# Calculating probability for grid at (22, 47)
# Calculating probability for grid at (22, 48)
# Calculating probability for grid at (22, 49)
# Calculating probability for grid at (22, 50)
# Calculating probability for grid at (22, 51)
# Calculating probability for grid at (22, 52)
# Calculating probability for grid at (22, 53)
# Calculating probability for grid at (22, 54)
# ...
# Calculating probability for grid at (63, 94)
# Calculating probability for grid at (63, 95)
# Calculating probability for grid at (63, 96)
# Calculating probability for grid at (64, 64)
# Calculating probability for grid at (64, 65)
# Calculating probability for grid at (64, 66)
# Calculating probability for grid at (64, 67)
# Calculating probability for grid at (64, 68)
# Calculating probability for grid at (64, 69)
# Calculating probability for grid at (64, 70)
# Calculating probability for grid at (64, 71)
# Calculating probability for grid at (64, 72)
# Calculating probability for grid at (64, 73)
# Calculating probability for grid at (64, 74)
# Calculating probability for grid at (64, 75)
# Calculating probability for grid at (64, 76)
# Calculating probability for grid at (64, 77)
# Calculating probability for grid at (64, 78)
# Calculating probability for grid at (64, 79)
# Calculating probability for grid at (64, 80)
# Calculating probability for grid at (64, 81)
# Calculating probability for grid at (64, 82)
# Calculating probability for grid at (64, 83)
# Calculating probability for grid at (64, 84)
# Calculating probability for grid at (64, 85)
# Calculating probability for grid at (64, 86)
# Calculating probability for grid at (64, 87)
# Calculating probability for grid at (64, 88)
# Calculating probability for grid at (64, 89)
# Calculating probability for grid at (64, 90)
# Calculating probability for grid at (64, 91)
# Calculating probability for grid at (64, 92)
# Calculating probability for grid at (64, 93)
# Calculating probability for grid at (64, 94)
# Calculating probability for grid at (64, 95)
# Calculating probability for grid at (65, 65)
# Calculating probability for grid at (65, 66)
# Calculating probability for grid at (65, 67)
# Calculating probability for grid at (65, 68)
# Calculating probability for grid at (65, 69)
# Calculating probability for grid at (65, 70)
# Calculating probability for grid at (65, 71)
# Calculating probability for grid at (65, 72)
# Calculating probability for grid at (65, 73)
# Calculating probability for grid at (65, 74)
# Calculating probability for grid at (65, 75)
# Calculating probability for grid at (65, 76)
# Calculating probability for grid at (65, 77)
# Calculating probability for grid at (65, 78)
# Calculating probability for grid at (65, 79)
# Calculating probability for grid at (65, 80)
# Calculating probability for grid at (65, 81)
# Calculating probability for grid at (65, 82)
# Calculating probability for grid at (65, 83)
# Calculating probability for grid at (65, 84)
# Calculating probability for grid at (65, 85)
# Calculating probability for grid at (65, 86)
# Calculating probability for grid at (65, 87)
# Calculating probability for grid at (65, 88)
# Calculating probability for grid at (65, 89)
# Calculating probability for grid at (65, 90)
# Calculating probability for grid at (65, 91)
# Calculating probability for grid at (65, 92)
# Calculating probability for grid at (65, 93)
# Calculating probability for grid at (66, 66)
# Calculating probability for grid at (66, 67)
# Calculating probability for grid at (66, 68)
# Calculating probability for grid at (66, 69)
# Calculating probability for grid at (66, 70)
# Calculating probability for grid at (66, 71)
# Calculating probability for grid at (66, 72)
# Calculating probability for grid at (66, 73)
# Calculating probability for grid at (66, 74)
# Calculating probability for grid at (66, 75)
# Calculating probability for grid at (66, 76)
# Calculating probability for grid at (66, 77)
# Calculating probability for grid at (66, 78)
# Calculating probability for grid at (66, 79)
# Calculating probability for grid at (66, 80)
# Calculating probability for grid at (66, 81)
# Calculating probability for grid at (66, 82)
# Calculating probability for grid at (66, 83)
# Calculating probability for grid at (66, 84)
# Calculating probability for grid at (66, 85)
# Calculating probability for grid at (66, 86)
# Calculating probability for grid at (66, 87)
# Calculating probability for grid at (66, 88)
# Calculating probability for grid at (66, 89)
# Calculating probability for grid at (66, 90)
# Calculating probability for grid at (66, 91)
# Calculating probability for grid at (66, 92)
# Calculating probability for grid at (66, 93)
# Calculating probability for grid at (67, 67)
# Calculating probability for grid at (67, 68)
# Calculating probability for grid at (67, 69)
# Calculating probability for grid at (67, 70)
# Calculating probability for grid at (67, 71)
# Calculating probability for grid at (67, 72)
# Calculating probability for grid at (67, 73)
# Calculating probability for grid at (67, 74)
# Calculating probability for grid at (67, 75)
# Calculating probability for grid at (67, 76)
# Calculating probability for grid at (67, 77)
# Calculating probability for grid at (67, 78)
# Calculating probability for grid at (67, 79)
# Calculating probability for grid at (67, 80)
# Calculating probability for grid at (67, 81)
# Calculating probability for grid at (67, 82)
# Calculating probability for grid at (67, 83)
# Calculating probability for grid at (67, 84)
# Calculating probability for grid at (67, 85)
# Calculating probability for grid at (67, 86)
# Calculating probability for grid at (67, 87)
# Calculating probability for grid at (67, 88)
# Calculating probability for grid at (67, 89)
# Calculating probability for grid at (67, 90)
# Calculating probability for grid at (67, 91)
# Calculating probability for grid at (67, 92)
# Calculating probability for grid at (67, 93)
# Calculating probability for grid at (67, 94)
# Calculating probability for grid at (68, 68)
# Calculating probability for grid at (68, 69)
# Calculating probability for grid at (68, 70)
# Calculating probability for grid at (68, 71)
# Calculating probability for grid at (68, 72)
# Calculating probability for grid at (68, 73)
# Calculating probability for grid at (68, 74)
# Calculating probability for grid at (68, 75)
# Calculating probability for grid at (68, 76)
# Calculating probability for grid at (68, 77)
# Calculating probability for grid at (68, 78)
# Calculating probability for grid at (68, 79)
# Calculating probability for grid at (68, 80)
# Calculating probability for grid at (68, 81)
# Calculating probability for grid at (68, 82)
# Calculating probability for grid at (68, 83)
# Calculating probability for grid at (68, 84)
# Calculating probability for grid at (68, 85)
# Calculating probability for grid at (68, 86)
# Calculating probability for grid at (68, 87)
# Calculating probability for grid at (68, 88)
# Calculating probability for grid at (68, 89)
# Calculating probability for grid at (68, 90)
# Calculating probability for grid at (68, 91)
# Calculating probability for grid at (68, 92)
# Calculating probability for grid at (68, 93)
# Calculating probability for grid at (68, 95)
# Calculating probability for grid at (69, 69)
# Calculating probability for grid at (69, 70)
# Calculating probability for grid at (69, 71)
# Calculating probability for grid at (69, 72)
# Calculating probability for grid at (69, 73)
# Calculating probability for grid at (69, 74)
# Calculating probability for grid at (69, 75)
# Calculating probability for grid at (69, 76)
# Calculating probability for grid at (69, 77)
# Calculating probability for grid at (69, 78)
# Calculating probability for grid at (69, 79)
# Calculating probability for grid at (69, 80)
# Calculating probability for grid at (69, 81)
# Calculating probability for grid at (69, 82)
# Calculating probability for grid at (69, 83)
# Calculating probability for grid at (69, 84)
# Calculating probability for grid at (69, 85)
# Calculating probability for grid at (69, 86)
# Calculating probability for grid at (69, 87)
# Calculating probability for grid at (69, 88)
# Calculating probability for grid at (69, 89)
# Calculating probability for grid at (69, 90)
# Calculating probability for grid at (69, 91)
# Calculating probability for grid at (69, 92)
# Calculating probability for grid at (69, 93)
# Calculating probability for grid at (69, 94)
# Calculating probability for grid at (70, 70)
# Calculating probability for grid at (70, 71)
# Calculating probability for grid at (70, 72)
# Calculating probability for grid at (70, 73)
# Calculating probability for grid at (70, 74)
# Calculating probability for grid at (70, 75)
# Calculating probability for grid at (70, 76)
# Calculating probability for grid at (70, 77)
# Calculating probability for grid at (70, 78)
# Calculating probability for grid at (70, 79)
# Calculating probability for grid at (70, 80)
# Calculating probability for grid at (70, 81)
# Calculating probability for grid at (70, 82)
# Calculating probability for grid at (70, 83)
# Calculating probability for grid at (70, 84)
# Calculating probability for grid at (70, 85)
# Calculating probability for grid at (70, 86)
# Calculating probability for grid at (70, 87)
# Calculating probability for grid at (70, 88)
# Calculating probability for grid at (70, 89)
# Calculating probability for grid at (70, 90)
# Calculating probability for grid at (70, 91)
# Calculating probability for grid at (70, 93)
# Calculating probability for grid at (70, 94)
# Calculating probability for grid at (71, 71)
# Calculating probability for grid at (71, 72)
# Calculating probability for grid at (71, 73)
# Calculating probability for grid at (71, 74)
# Calculating probability for grid at (71, 75)
# Calculating probability for grid at (71, 76)
# Calculating probability for grid at (71, 77)
# Calculating probability for grid at (71, 78)
# Calculating probability for grid at (71, 79)
# Calculating probability for grid at (71, 80)
# Calculating probability for grid at (71, 81)
# Calculating probability for grid at (71, 82)
# Calculating probability for grid at (71, 83)
# Calculating probability for grid at (71, 84)
# Calculating probability for grid at (71, 85)
# Calculating probability for grid at (71, 86)
# Calculating probability for grid at (71, 87)
# Calculating probability for grid at (71, 88)
# Calculating probability for grid at (71, 89)
# Calculating probability for grid at (71, 90)
# Calculating probability for grid at (71, 91)
# Calculating probability for grid at (71, 92)
# Calculating probability for grid at (72, 72)
# Calculating probability for grid at (72, 73)
# Calculating probability for grid at (72, 74)
# Calculating probability for grid at (72, 75)
# Calculating probability for grid at (72, 76)
# Calculating probability for grid at (72, 77)
# Calculating probability for grid at (72, 78)
# Calculating probability for grid at (72, 79)
# Calculating probability for grid at (72, 80)
# Calculating probability for grid at (72, 81)
# Calculating probability for grid at (72, 82)
# Calculating probability for grid at (72, 83)
# Calculating probability for grid at (72, 84)
# Calculating probability for grid at (72, 85)
# Calculating probability for grid at (72, 86)
# Calculating probability for grid at (72, 87)
# Calculating probability for grid at (72, 88)
# Calculating probability for grid at (72, 89)
# Calculating probability for grid at (72, 90)
# Calculating probability for grid at (72, 91)
# Calculating probability for grid at (73, 73)
# Calculating probability for grid at (73, 74)
# Calculating probability for grid at (73, 75)
# Calculating probability for grid at (73, 76)
# Calculating probability for grid at (73, 77)
# Calculating probability for grid at (73, 78)
# Calculating probability for grid at (73, 79)
# Calculating probability for grid at (73, 80)
# Calculating probability for grid at (73, 81)
# Calculating probability for grid at (73, 82)
# Calculating probability for grid at (73, 83)
# Calculating probability for grid at (73, 84)
# Calculating probability for grid at (73, 85)
# Calculating probability for grid at (73, 86)
# Calculating probability for grid at (73, 87)
# Calculating probability for grid at (73, 88)
# Calculating probability for grid at (73, 89)
# Calculating probability for grid at (73, 90)
# Calculating probability for grid at (73, 91)
# Calculating probability for grid at (74, 74)
# Calculating probability for grid at (74, 75)
# Calculating probability for grid at (74, 76)
# Calculating probability for grid at (74, 77)
# Calculating probability for grid at (74, 78)
# Calculating probability for grid at (74, 79)
# Calculating probability for grid at (74, 80)
# Calculating probability for grid at (74, 81)
# Calculating probability for grid at (74, 82)
# Calculating probability for grid at (74, 83)
# Calculating probability for grid at (74, 84)
# Calculating probability for grid at (74, 85)
# Calculating probability for grid at (74, 86)
# Calculating probability for grid at (74, 87)
# Calculating probability for grid at (74, 88)
# Calculating probability for grid at (74, 89)
# Calculating probability for grid at (74, 90)
# Calculating probability for grid at (74, 91)
# Calculating probability for grid at (74, 92)
# Calculating probability for grid at (75, 75)
# Calculating probability for grid at (75, 76)
# Calculating probability for grid at (75, 77)
# Calculating probability for grid at (75, 78)
# Calculating probability for grid at (75, 79)
# Calculating probability for grid at (75, 80)
# Calculating probability for grid at (75, 81)
# Calculating probability for grid at (75, 82)
# Calculating probability for grid at (75, 83)
# Calculating probability for grid at (75, 84)
# Calculating probability for grid at (75, 85)
# Calculating probability for grid at (75, 86)
# Calculating probability for grid at (75, 87)
# Calculating probability for grid at (76, 76)
# Calculating probability for grid at (76, 77)
# Calculating probability for grid at (76, 78)
# Calculating probability for grid at (76, 79)
# Calculating probability for grid at (76, 80)
# Calculating probability for grid at (76, 81)
# Calculating probability for grid at (76, 82)
# Calculating probability for grid at (76, 83)
# Calculating probability for grid at (76, 84)
# Calculating probability for grid at (76, 85)
# Calculating probability for grid at (76, 86)
# Calculating probability for grid at (76, 87)
# Calculating probability for grid at (76, 88)
# Calculating probability for grid at (76, 92)
# Calculating probability for grid at (77, 77)
# Calculating probability for grid at (77, 78)
# Calculating probability for grid at (77, 79)
# Calculating probability for grid at (77, 80)
# Calculating probability for grid at (77, 81)
# Calculating probability for grid at (77, 82)
# Calculating probability for grid at (77, 83)
# Calculating probability for grid at (77, 84)
# Calculating probability for grid at (77, 85)
# Calculating probability for grid at (77, 86)
# Calculating probability for grid at (77, 87)
# Calculating probability for grid at (77, 88)
# Calculating probability for grid at (78, 78)
# Calculating probability for grid at (78, 79)
# Calculating probability for grid at (78, 80)
# Calculating probability for grid at (78, 81)
# Calculating probability for grid at (78, 82)
# Calculating probability for grid at (78, 83)
# Calculating probability for grid at (78, 84)
# Calculating probability for grid at (78, 85)
# Calculating probability for grid at (78, 86)
# Calculating probability for grid at (79, 79)
# Calculating probability for grid at (79, 80)
# Calculating probability for grid at (79, 81)
# Calculating probability for grid at (79, 82)
# Calculating probability for grid at (79, 83)
# Calculating probability for grid at (79, 84)
# Calculating probability for grid at (79, 85)
# Calculating probability for grid at (79, 86)
# Calculating probability for grid at (79, 87)
# Calculating probability for grid at (79, 88)
# Calculating probability for grid at (80, 80)
# Calculating probability for grid at (80, 81)
# Calculating probability for grid at (80, 82)
# Calculating probability for grid at (80, 83)
# Calculating probability for grid at (80, 84)
# Calculating probability for grid at (80, 85)
# Calculating probability for grid at (81, 81)
# Calculating probability for grid at (81, 82)
# Calculating probability for grid at (81, 83)
# Calculating probability for grid at (81, 84)
# Calculating probability for grid at (81, 85)
# Calculating probability for grid at (81, 86)
# Calculating probability for grid at (81, 89)
# Calculating probability for grid at (82, 82)
# Calculating probability for grid at (82, 83)
# Calculating probability for grid at (82, 84)
# Calculating probability for grid at (82, 86)
# Calculating probability for grid at (83, 83)
# Calculating probability for grid at (84, 84)
# Time taken by Feynman-Kac computation = 386.5974178314209s

# %% [markdown]
# **Plot solutions**

# %%
# set up plotting parameters
scale = 5
xlabel_size = ylabel_size = 15 + scale
tick_size = 10 + scale
legend_size = 15 + scale
title_size = 15 + scale
cbar_tick_size = 10 + scale



fig_all = plt.figure(figsize=(20, 10))
ax_1l = fig_all.add_subplot(121) 
ax_1m = fig_all.add_subplot(122)


div_1 = make_axes_locatable(ax_1l)
cax_1 = div_1.append_axes('right', '5%', '5%')


div_4 = make_axes_locatable(ax_1m)
cax_4 = div_4.append_axes('right', '5%', '5%')



z_1m  /= (z_1m.sum() * grid.h[0] * grid.h[1])
np.save('{}/circle-fp/data/10D/p_1m_t.npy'.format(repo), z_1m)
im = ax_1m.pcolormesh(x4, x5, z_1m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_1m.set_aspect("auto")



ax_1m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='minor', labelsize=tick_size)


ax_1m.set_title('Monte Carlo solution at time {:.2f}'.format(t), fontsize=title_size)
ax_1m.set_xlabel('x', fontsize=xlabel_size)
ax_1m.set_ylabel('y', fontsize=ylabel_size)


ax_1l.clear()
cax_1.cla()
z_1l /= (z_1l.sum() * grid.h[0] * grid.h[1])
np.save('{}/circle-fp/data/10D/p_1l_t.npy'.format(repo), z_1l)
im = ax_1l.pcolormesh(x4, x5, z_1l.T, cmap='inferno', shading='auto')
ax_1l.set_title('Learned solution at time = {:.2f}'.format(t), fontsize=title_size)
ax_1l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1l.tick_params(axis='both', which='minor', labelsize=tick_size)
cbar = fig_all.colorbar(im, cax=cax_1, ax=ax_1l)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_1l.set_aspect("auto")


fig_all.subplots_adjust(wspace=1.0, hspace=0.4)

ax_1l.set_ylabel(r'$p(x, y)$', fontsize=ylabel_size)
plt.tight_layout()
plt.savefig('{}/plots/10D-time.png'.format(repo))
