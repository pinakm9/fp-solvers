# %%
import os, sys
from pathlib import Path
script_dir = Path(os.path.dirname(os.path.abspath('')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
print(module_dir)

# import the rest of the modules
# %matplotlib nbagg
# %matplotlib inline
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import arch
import pandas as pd
import tensorflow_probability as tfp
import time  
import sim
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from mpl_toolkits.axes_grid1 import make_axes_locatable


dim = 3
n_particles = int(1e5)
n_subdivs = 30
n_int_subdivs = 100
save_folder = '../non-grad3D/data/L63'
n_steps = 5
n_repeats = 100
dt = 0.01
alpha, beta, rho = 10., 8./3., 28.
sigma = 10.
D = sigma**2 / 2.
t = dt * n_steps
dtype = 'float32'


# define drift
def mu(X):
    x, y, z = tf.split(X, [1, 1, 1], axis=-1)
    p = alpha * (y - x)
    q = x * (rho - z) - y 
    r = x * y - beta * z 
    return tf.concat([p, q, r], axis=-1)

locs = np.array([[-1., -1., -1.], [1., 1., 1.]]).astype(dtype)
scales = np.array([[1., 1., 1.], [1., 1., 1.]]).astype(dtype)
weights = np.array([.5, .5]).astype(dtype)
Xs = [tfp.distributions.MultivariateNormalDiag(loc=locs[i], scale_diag=scales[i]) for i in range(len(locs))]
rv0 = tfp.distributions.Mixture(cat=tfp.distributions.Categorical(probs=weights), components=Xs)


X0 =  rv0.sample(n_particles).numpy()
mc_prob = sim.MCProb(save_folder, n_subdivs, lambda X: mu(X).numpy(), sigma,\
                     X0, tick_size=20, title_size=20, cbar_tick_size=15)
mc_prob.ready(n_steps=n_steps, dt=dt, lims=None)
# Out:
# C:\Users\pinak\Documents\GitHub\fp-solvers
# Time taken by propagate is 0.2810959815979004 seconds
# Time taken by set_grid is 0.29363369941711426 seconds
# Time taken by assign_pts is 0.33081483840942383 seconds
# Time taken by ready is 0.9055445194244385 seconds

# %%
# set up plotting parameters
scale = 10
xlabel_size = ylabel_size = 15 + scale
tick_size = 10 + scale
legend_size = 15 + scale
title_size = 15 + scale
cbar_tick_size = 10 + scale

# %%
# load learned solution
dim = 3
n_theta = arch.LSTMForgetNet(50, 3, tf.float32, name="L63")
n_theta.load_weights('../non-grad3D/data/L63/1M/{}'.format(n_theta.name)).expect_partial()
X = tf.random.uniform(shape=(10, dim))
n_theta(*tf.split(X, dim, axis=-1))



grid = mc_prob.get_grid()
low = grid.mins
high = grid.maxs
filter = mc_prob.save_folder + '/ensemble.csv'
method = "Gauss_Legendre"
d = 4
max_comp = 1e6



x_ = np.linspace(low[0], high[0], num=n_subdivs, endpoint=True).astype('float32')
y_ = np.linspace(low[1], high[1], num=n_subdivs, endpoint=True).astype('float32')
z_ = np.linspace(low[2], high[2], num=n_subdivs, endpoint=True).astype('float32')

    
fig_all = plt.figure(figsize=(20, 20))
ax_1l = fig_all.add_subplot(321) 
ax_1m = fig_all.add_subplot(322)


ax_2l = fig_all.add_subplot(323) 
ax_2m = fig_all.add_subplot(324)

ax_3l = fig_all.add_subplot(325) 
ax_3m = fig_all.add_subplot(326)


div_1 = make_axes_locatable(ax_1l)
cax_1 = div_1.append_axes('right', '5%', '5%')
div_2 = make_axes_locatable(ax_2l)
cax_2 = div_2.append_axes('right', '5%', '5%')
div_3 = make_axes_locatable(ax_3l)
cax_3 = div_3.append_axes('right', '5%', '5%')

div_4 = make_axes_locatable(ax_1m)
cax_4 = div_4.append_axes('right', '5%', '5%')
div_5 = make_axes_locatable(ax_2m)
cax_5 = div_5.append_axes('right', '5%', '5%')
div_6 = make_axes_locatable(ax_3m)
cax_6 = div_6.append_axes('right', '5%', '5%')

z_1m = mc_prob.compute_p2(0, 1, save=False)
z_1m  /= (z_1m.sum() * grid.h[0] * grid.h[1])
im = ax_1m.pcolormesh(x_, y_, z_1m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_1m.set_aspect("auto")


z_2m = mc_prob.compute_p2(1, 2, save=False)
z_2m  /= (z_2m.sum() * grid.h[1] * grid.h[2])
im = ax_2m.pcolormesh(y_, z_, z_2m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_5, ax=ax_2m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_2m.set_aspect("auto")

z_3m = mc_prob.compute_p2(2, 0, save=False)
z_3m  /= (z_3m.sum() * grid.h[2] * grid.h[0])
im = ax_3m.pcolormesh(z_, x_, z_3m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_6, ax=ax_3m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_3m.set_aspect("auto")

ax_1m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='minor', labelsize=tick_size)

ax_1m.set_title('Monte Carlo solution at time {:.2f}'.format(t), fontsize=title_size)
ax_1m.set_xlabel('x', fontsize=xlabel_size)
ax_1m.set_ylabel('y', fontsize=ylabel_size)
ax_2m.set_xlabel('y', fontsize=xlabel_size)
ax_2m.set_ylabel('z', fontsize=ylabel_size)
ax_3m.set_xlabel('z', fontsize=xlabel_size)
ax_3m.set_ylabel('x', fontsize=ylabel_size)



fk = sim.FKRec(save_folder='.', n_subdivs=n_subdivs, n_int_subdivs=n_int_subdivs, mu=mu, sigma=sigma,\
               n_theta=n_theta, grid=grid, log_p0=lambda x: tf.reshape(rv0.log_prob(x), (-1, 1)), max_comp=max_comp)


# z_1l = fk.calc_2D_prob(n_steps, dt, n_repeats, 0, 1, filter, method=method, num=n_int_subdivs, d=d)
# ax_1l.clear()
# cax_1.cla()
# z_1l /= (z_1l.sum() * grid.h[0] * grid.h[1])
# im = ax_1l.pcolormesh(x_, y_, z_1l.T, cmap='inferno', shading='auto')
# ax_1l.set_title('Learned solution at time = {:.2f}'.format(t), fontsize=title_size)
# ax_1l.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_1l.tick_params(axis='both', which='minor', labelsize=tick_size)
# cbar = fig_all.colorbar(im, cax=cax_1, ax=ax_1l)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_1l.set_aspect("auto")



# z_2l = fk.calc_2D_prob(n_steps, dt, n_repeats, 1, 2, filter, method=method, num=n_int_subdivs, d=d)
# ax_2l.clear()
# cax_2.cla() 
# z_2l /= (z_2l.sum() *  grid.h[1] * grid.h[2])
# im = ax_2l.pcolormesh(y_, z_, z_2l.T, cmap='inferno')
# ax_2l.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_2l.tick_params(axis='both', which='minor', labelsize=tick_size)
# cbar = fig_all.colorbar(im, cax=cax_2, ax=ax_2l)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_2l.set_aspect("auto")


z_3l = fk.calc_2D_prob(n_steps, dt, n_repeats, 2, 0, filter, method=method, num=n_int_subdivs, d=d)
ax_3l.clear()
cax_3.cla()
z_3l /= (z_3l.sum() *  grid.h[2] * grid.h[0])
im = ax_3l.pcolormesh(z_, x_, z_3l.T, cmap='inferno')
ax_3l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3l.tick_params(axis='both', which='minor', labelsize=tick_size)
cbar = fig_all.colorbar(im, cax=cax_3, ax=ax_3l)
cbar.ax.tick_params(labelsize=cbar_tick_size)
ax_3l.set_aspect("auto")
fig_all.subplots_adjust(wspace=1.0, hspace=0.4)

ax_1l.set_ylabel(r'$p(x, y)$', fontsize=ylabel_size)
ax_2l.set_ylabel(r'$p(y, z)$', fontsize=ylabel_size)
ax_3l.set_ylabel(r'$p(z, x)$', fontsize=ylabel_size)
plt.tight_layout()
plt.savefig('../plots/L63-time.png')
# Out:
# Time taken by compute_p2 is 0.2832906246185303 seconds
# Time taken by compute_p2 is 0.2805318832397461 seconds
# Time taken by compute_p2 is 0.27367305755615234 seconds
# Time taken by set_filter is 0.30022430419921875 seconds
# grid_index = (0, 9), time taken = 0.7850
# grid_index = (0, 11), time taken = 0.9134
# grid_index = (0, 12), time taken = 1.0414
# grid_index = (0, 14), time taken = 1.1653
# grid_index = (1, 8), time taken = 1.2898
# grid_index = (1, 10), time taken = 1.4096
# grid_index = (1, 11), time taken = 1.5335
# grid_index = (1, 12), time taken = 1.6580
# grid_index = (1, 13), time taken = 1.7819
# grid_index = (1, 14), time taken = 1.9060
# grid_index = (1, 15), time taken = 2.0294
# grid_index = (2, 6), time taken = 2.1536
# grid_index = (2, 7), time taken = 2.2775
# grid_index = (2, 8), time taken = 2.3975
# grid_index = (2, 9), time taken = 2.5214
# grid_index = (2, 10), time taken = 2.6454
# grid_index = (2, 11), time taken = 2.7699
# grid_index = (2, 12), time taken = 2.8898
# grid_index = (2, 13), time taken = 3.0143
# grid_index = (2, 14), time taken = 3.1391
# grid_index = (2, 15), time taken = 3.2638
# grid_index = (2, 16), time taken = 3.3846
# grid_index = (2, 18), time taken = 3.5096
# grid_index = (3, 5), time taken = 3.6340
# grid_index = (3, 7), time taken = 3.7603
# grid_index = (3, 8), time taken = 3.8852
# grid_index = (3, 9), time taken = 4.0097
# grid_index = (3, 10), time taken = 4.1338
# grid_index = (3, 11), time taken = 4.2554
# grid_index = (3, 12), time taken = 4.3802
# grid_index = (3, 13), time taken = 4.5005
# grid_index = (3, 14), time taken = 4.6250
# grid_index = (3, 15), time taken = 4.7494
# grid_index = (3, 16), time taken = 4.8744
# grid_index = (3, 17), time taken = 4.9948
# grid_index = (3, 19), time taken = 5.1192
# grid_index = (4, 3), time taken = 5.2432
# grid_index = (4, 4), time taken = 5.3673
# grid_index = (4, 5), time taken = 5.4877
# grid_index = (4, 6), time taken = 5.6122
# grid_index = (4, 7), time taken = 5.7365
# grid_index = (4, 8), time taken = 5.8571
# grid_index = (4, 9), time taken = 5.9810
# grid_index = (4, 10), time taken = 6.1049
# grid_index = (4, 11), time taken = 6.2261
# grid_index = (4, 12), time taken = 6.3528
# grid_index = (4, 13), time taken = 6.4760
# grid_index = (4, 14), time taken = 6.5969
# grid_index = (4, 15), time taken = 6.7213
# grid_index = (4, 16), time taken = 6.8408
# grid_index = (4, 17), time taken = 6.9647
# grid_index = (4, 18), time taken = 7.0887
# grid_index = (4, 19), time taken = 7.2129
# grid_index = (4, 21), time taken = 7.3326
# grid_index = (5, 2), time taken = 7.4566
# grid_index = (5, 3), time taken = 7.5807
# grid_index = (5, 4), time taken = 7.7051
# grid_index = (5, 5), time taken = 7.8251
# grid_index = (5, 6), time taken = 7.9410
# grid_index = (5, 7), time taken = 8.0669
# grid_index = (5, 8), time taken = 8.1928
# grid_index = (5, 9), time taken = 8.3185
# grid_index = (5, 10), time taken = 8.4449
# grid_index = (5, 11), time taken = 8.5638
# grid_index = (5, 12), time taken = 8.6901
# grid_index = (5, 13), time taken = 8.8001
# grid_index = (5, 14), time taken = 8.9255
# grid_index = (5, 15), time taken = 9.0513
# grid_index = (5, 16), time taken = 9.1781
# grid_index = (5, 17), time taken = 9.3040
# grid_index = (5, 18), time taken = 9.4298
# grid_index = (5, 19), time taken = 9.5399
# grid_index = (5, 20), time taken = 9.6655
# grid_index = (5, 21), time taken = 9.7913
# grid_index = (6, 3), time taken = 9.9170
# grid_index = (6, 4), time taken = 10.0425
# grid_index = (6, 5), time taken = 10.1682
# grid_index = (6, 6), time taken = 10.2781
# grid_index = (6, 7), time taken = 10.4047
# grid_index = (6, 8), time taken = 10.5313
# grid_index = (6, 9), time taken = 10.6578
# grid_index = (6, 10), time taken = 10.7833
# grid_index = (6, 11), time taken = 10.9092
# grid_index = (6, 12), time taken = 11.0291
# grid_index = (6, 13), time taken = 11.1451
# grid_index = (6, 14), time taken = 11.2708
# grid_index = (6, 15), time taken = 11.3971
# grid_index = (6, 16), time taken = 11.5239
# grid_index = (6, 17), time taken = 11.6342
# grid_index = (6, 18), time taken = 11.7606
# grid_index = (6, 19), time taken = 11.8870
# grid_index = (6, 20), time taken = 12.0127
# grid_index = (6, 22), time taken = 12.1389
# grid_index = (7, 0), time taken = 12.2650
# grid_index = (7, 1), time taken = 12.3751
# grid_index = (7, 2), time taken = 12.5021
# grid_index = (7, 3), time taken = 12.6320
# grid_index = (7, 4), time taken = 12.7540
# grid_index = (7, 5), time taken = 12.8797
# grid_index = (7, 6), time taken = 13.0058
# grid_index = (7, 7), time taken = 13.1161
# grid_index = (7, 8), time taken = 13.2429
# grid_index = (7, 9), time taken = 13.3689
# grid_index = (7, 10), time taken = 13.4910
# grid_index = (7, 11), time taken = 13.6167
# grid_index = (7, 12), time taken = 13.7427
# grid_index = (7, 13), time taken = 13.8684
# grid_index = (7, 14), time taken = 13.9785
# grid_index = (7, 15), time taken = 14.1048
# grid_index = (7, 16), time taken = 14.2320
# grid_index = (7, 17), time taken = 14.3576
# grid_index = (7, 18), time taken = 14.4834
# grid_index = (7, 19), time taken = 14.6099
# grid_index = (7, 20), time taken = 14.7331
# grid_index = (7, 21), time taken = 14.8461
# grid_index = (8, 2), time taken = 14.9723
# grid_index = (8, 3), time taken = 15.0981
# grid_index = (8, 4), time taken = 15.2245
# grid_index = (8, 5), time taken = 15.3502
# grid_index = (8, 6), time taken = 15.4764
# grid_index = (8, 7), time taken = 15.6025
# grid_index = (8, 8), time taken = 15.7124
# grid_index = (8, 9), time taken = 15.8383
# grid_index = (8, 10), time taken = 15.9638
# grid_index = (8, 11), time taken = 16.0902
# grid_index = (8, 12), time taken = 16.2161
# grid_index = (8, 13), time taken = 16.3430
# grid_index = (8, 14), time taken = 16.4686
# grid_index = (8, 15), time taken = 16.5948
# grid_index = (8, 16), time taken = 16.7205
# grid_index = (8, 17), time taken = 16.8370
# grid_index = (8, 18), time taken = 16.9577
# grid_index = (8, 19), time taken = 17.0841
# grid_index = (8, 20), time taken = 17.2097
# grid_index = (8, 21), time taken = 17.3381
# grid_index = (8, 22), time taken = 17.4615
# grid_index = (8, 23), time taken = 17.5715
# grid_index = (9, 1), time taken = 17.6972
# grid_index = (9, 2), time taken = 17.8228
# grid_index = (9, 3), time taken = 17.9509
# grid_index = (9, 4), time taken = 18.0764
# grid_index = (9, 5), time taken = 18.2022
# grid_index = (9, 6), time taken = 18.3277
# grid_index = (9, 7), time taken = 18.4396
# grid_index = (9, 8), time taken = 18.5697
# grid_index = (9, 9), time taken = 18.6955
# grid_index = (9, 10), time taken = 18.8219
# grid_index = (9, 11), time taken = 18.9484
# grid_index = (9, 12), time taken = 19.0740
# grid_index = (9, 13), time taken = 19.1838
# grid_index = (9, 14), time taken = 19.3096
# grid_index = (9, 15), time taken = 19.4419
# grid_index = (9, 16), time taken = 19.5622
# grid_index = (9, 17), time taken = 19.6878
# grid_index = (9, 18), time taken = 19.8139
# grid_index = (9, 19), time taken = 19.9422
# grid_index = (9, 20), time taken = 20.0661
# grid_index = (9, 21), time taken = 20.1764
# grid_index = (9, 22), time taken = 20.3023
# grid_index = (9, 23), time taken = 20.4279
# grid_index = (9, 24), time taken = 20.5533
# grid_index = (10, 1), time taken = 20.6793
# grid_index = (10, 2), time taken = 20.8059
# grid_index = (10, 3), time taken = 20.9317
# grid_index = (10, 4), time taken = 21.0436
# grid_index = (10, 5), time taken = 21.1685
# grid_index = (10, 6), time taken = 21.2952
# grid_index = (10, 7), time taken = 21.4211
# grid_index = (10, 8), time taken = 21.5480
# grid_index = (10, 9), time taken = 21.6586
# grid_index = (10, 10), time taken = 21.7841
# grid_index = (10, 11), time taken = 21.9098
# grid_index = (10, 12), time taken = 22.0449
# grid_index = (10, 13), time taken = 22.1618
# grid_index = (10, 14), time taken = 22.2875
# grid_index = (10, 15), time taken = 22.4141
# grid_index = (10, 16), time taken = 22.5387
# grid_index = (10, 17), time taken = 22.6491
# grid_index = (10, 18), time taken = 22.7753
# grid_index = (10, 19), time taken = 22.9012
# grid_index = (10, 20), time taken = 23.0272
# grid_index = (10, 21), time taken = 23.1532
# grid_index = (10, 22), time taken = 23.2793
# grid_index = (10, 23), time taken = 23.4058
# grid_index = (10, 24), time taken = 23.5318
# grid_index = (10, 25), time taken = 23.6468
# grid_index = (10, 26), time taken = 23.7686
# grid_index = (11, 0), time taken = 23.8940
# grid_index = (11, 1), time taken = 24.0206
# grid_index = (11, 2), time taken = 24.1477
# grid_index = (11, 3), time taken = 24.2723
# grid_index = (11, 4), time taken = 24.3824
# grid_index = (11, 5), time taken = 24.5080
# grid_index = (11, 6), time taken = 24.6339
# grid_index = (11, 7), time taken = 24.7598
# grid_index = (11, 8), time taken = 24.8855
# grid_index = (11, 9), time taken = 25.0113
# grid_index = (11, 10), time taken = 25.1373
# grid_index = (11, 11), time taken = 25.2633
# grid_index = (11, 12), time taken = 25.3733
# grid_index = (11, 13), time taken = 25.4989
# grid_index = (11, 14), time taken = 25.6245
# grid_index = (11, 15), time taken = 25.7505
# grid_index = (11, 16), time taken = 25.8763
# grid_index = (11, 17), time taken = 26.0021
# grid_index = (11, 18), time taken = 26.1280
# grid_index = (11, 19), time taken = 26.2485
# grid_index = (11, 20), time taken = 26.3640
# grid_index = (11, 21), time taken = 26.4907
# grid_index = (11, 22), time taken = 26.6164
# grid_index = (11, 23), time taken = 26.7425
# grid_index = (11, 24), time taken = 26.8690
# grid_index = (11, 25), time taken = 26.9797
# grid_index = (12, 1), time taken = 27.1054
# grid_index = (12, 2), time taken = 27.2317
# grid_index = (12, 3), time taken = 27.3585
# grid_index = (12, 4), time taken = 27.4844
# grid_index = (12, 5), time taken = 27.6100
# grid_index = (12, 6), time taken = 27.7358
# grid_index = (12, 7), time taken = 27.8618
# grid_index = (12, 8), time taken = 27.9718
# grid_index = (12, 9), time taken = 28.0974
# grid_index = (12, 10), time taken = 28.2228
# grid_index = (12, 11), time taken = 28.3507
# grid_index = (12, 12), time taken = 28.4740
# grid_index = (12, 13), time taken = 28.5995
# grid_index = (12, 14), time taken = 28.7261
# grid_index = (12, 15), time taken = 28.8524
# grid_index = (12, 16), time taken = 28.9780
# grid_index = (12, 17), time taken = 29.1037
# grid_index = (12, 18), time taken = 29.2294
# grid_index = (12, 19), time taken = 29.3554
# grid_index = (12, 20), time taken = 29.4655
# grid_index = (12, 21), time taken = 29.5909
# grid_index = (12, 22), time taken = 29.7178
# grid_index = (12, 23), time taken = 29.8518
# grid_index = (12, 24), time taken = 29.9715
# grid_index = (12, 25), time taken = 30.0974
# grid_index = (13, 0), time taken = 30.2227
# grid_index = (13, 1), time taken = 30.3484
# grid_index = (13, 2), time taken = 30.4752
# grid_index = (13, 3), time taken = 30.5856
# grid_index = (13, 4), time taken = 30.7113
# grid_index = (13, 5), time taken = 30.8383
# grid_index = (13, 6), time taken = 30.9650
# grid_index = (13, 7), time taken = 31.0908
# grid_index = (13, 8), time taken = 31.2165
# grid_index = (13, 9), time taken = 31.3434
# grid_index = (13, 10), time taken = 31.4546
# grid_index = (13, 11), time taken = 31.5800
# grid_index = (13, 12), time taken = 31.7054
# grid_index = (13, 13), time taken = 31.8312
# grid_index = (13, 14), time taken = 31.9571
# grid_index = (13, 15), time taken = 32.0837
# grid_index = (13, 16), time taken = 32.2099
# grid_index = (13, 17), time taken = 32.3361
# grid_index = (13, 18), time taken = 32.4562
# grid_index = (13, 19), time taken = 32.5729
# grid_index = (13, 20), time taken = 32.6984
# grid_index = (13, 21), time taken = 32.8243
# grid_index = (13, 22), time taken = 32.9575
# grid_index = (13, 23), time taken = 33.0765
# grid_index = (13, 24), time taken = 33.2030
# grid_index = (13, 25), time taken = 33.3291
# grid_index = (13, 26), time taken = 33.4391
# grid_index = (13, 27), time taken = 33.5693
# grid_index = (14, 0), time taken = 33.6950
# grid_index = (14, 1), time taken = 33.8201
# grid_index = (14, 2), time taken = 33.9307
# grid_index = (14, 3), time taken = 34.0726
# grid_index = (14, 4), time taken = 34.1983
# grid_index = (14, 5), time taken = 34.3240
# grid_index = (14, 6), time taken = 34.4340
# grid_index = (14, 7), time taken = 34.5600
# grid_index = (14, 8), time taken = 34.6857
# grid_index = (14, 9), time taken = 34.8116
# grid_index = (14, 10), time taken = 34.9368
# grid_index = (14, 11), time taken = 35.0628
# grid_index = (14, 12), time taken = 35.1728
# grid_index = (14, 13), time taken = 35.2984
# grid_index = (14, 14), time taken = 35.4244
# grid_index = (14, 15), time taken = 35.5598
# grid_index = (14, 16), time taken = 35.6768
# grid_index = (14, 17), time taken = 35.8025
# grid_index = (14, 18), time taken = 35.9284
# grid_index = (14, 19), time taken = 36.0537
# grid_index = (14, 20), time taken = 36.1798
# grid_index = (14, 21), time taken = 36.3055
# grid_index = (14, 22), time taken = 36.4156
# grid_index = (14, 23), time taken = 36.5411
# grid_index = (14, 24), time taken = 36.6669
# grid_index = (14, 25), time taken = 36.7931
# grid_index = (14, 26), time taken = 36.9196
# grid_index = (14, 27), time taken = 37.0464
# grid_index = (14, 28), time taken = 37.1724
# grid_index = (15, 0), time taken = 37.2981
# grid_index = (15, 1), time taken = 37.4080
# grid_index = (15, 2), time taken = 37.5336
# grid_index = (15, 3), time taken = 37.6619
# grid_index = (15, 4), time taken = 37.7854
# grid_index = (15, 5), time taken = 37.9112
# grid_index = (15, 6), time taken = 38.0372
# grid_index = (15, 7), time taken = 38.1617
# grid_index = (15, 8), time taken = 38.2732
# grid_index = (15, 9), time taken = 38.3992
# grid_index = (15, 10), time taken = 38.5231
# grid_index = (15, 11), time taken = 38.6489
# grid_index = (15, 12), time taken = 38.7750
# grid_index = (15, 13), time taken = 38.9013
# grid_index = (15, 14), time taken = 39.0279
# grid_index = (15, 15), time taken = 39.1532
# grid_index = (15, 16), time taken = 39.2770
# grid_index = (15, 17), time taken = 39.3978
# grid_index = (15, 18), time taken = 39.5250
# grid_index = (15, 19), time taken = 39.6351
# grid_index = (15, 20), time taken = 39.7637
# grid_index = (15, 21), time taken = 39.8973
# grid_index = (15, 22), time taken = 40.0216
# grid_index = (15, 23), time taken = 40.1461
# grid_index = (15, 24), time taken = 40.2705
# grid_index = (15, 25), time taken = 40.3939
# grid_index = (15, 26), time taken = 40.5142
# grid_index = (15, 27), time taken = 40.6387
# grid_index = (15, 29), time taken = 40.7650
# grid_index = (16, 0), time taken = 40.8834
# grid_index = (16, 1), time taken = 41.0090
# grid_index = (16, 2), time taken = 41.1351
# grid_index = (16, 3), time taken = 41.2614
# grid_index = (16, 4), time taken = 41.3716
# grid_index = (16, 5), time taken = 41.4992
# grid_index = (16, 6), time taken = 41.6260
# grid_index = (16, 7), time taken = 41.7524
# grid_index = (16, 8), time taken = 41.8784
# grid_index = (16, 9), time taken = 42.0042
# grid_index = (16, 10), time taken = 42.1300
# grid_index = (16, 11), time taken = 42.2558
# grid_index = (16, 12), time taken = 42.3674
# grid_index = (16, 13), time taken = 42.4918
# grid_index = (16, 14), time taken = 42.6187
# grid_index = (16, 15), time taken = 42.7443
# grid_index = (16, 16), time taken = 42.8704
# grid_index = (16, 17), time taken = 42.9961
# grid_index = (16, 18), time taken = 43.1222
# grid_index = (16, 19), time taken = 43.2479
# grid_index = (16, 20), time taken = 43.3744
# grid_index = (16, 21), time taken = 43.5006
# grid_index = (16, 22), time taken = 43.6268
# grid_index = (16, 23), time taken = 43.7365
# grid_index = (16, 24), time taken = 43.8705
# grid_index = (16, 25), time taken = 43.9888
# grid_index = (16, 26), time taken = 44.1143
# grid_index = (16, 27), time taken = 44.2403
# grid_index = (16, 28), time taken = 44.3722
# grid_index = (16, 29), time taken = 44.4924
# grid_index = (17, 0), time taken = 44.6188
# grid_index = (17, 1), time taken = 44.7458
# grid_index = (17, 2), time taken = 44.8721
# grid_index = (17, 3), time taken = 44.9824
# grid_index = (17, 4), time taken = 45.1081
# grid_index = (17, 5), time taken = 45.2336
# grid_index = (17, 6), time taken = 45.3592
# grid_index = (17, 7), time taken = 45.4859
# grid_index = (17, 8), time taken = 45.6118
# grid_index = (17, 9), time taken = 45.7387
# grid_index = (17, 10), time taken = 45.8652
# grid_index = (17, 11), time taken = 45.9916
# grid_index = (17, 12), time taken = 46.1176
# grid_index = (17, 13), time taken = 46.2427
# grid_index = (17, 14), time taken = 46.3529
# grid_index = (17, 15), time taken = 46.4788
# grid_index = (17, 16), time taken = 46.6042
# grid_index = (17, 17), time taken = 46.7307
# grid_index = (17, 18), time taken = 46.8571
# grid_index = (17, 19), time taken = 46.9855
# grid_index = (17, 20), time taken = 47.1120
# grid_index = (17, 21), time taken = 47.2377
# grid_index = (17, 22), time taken = 47.3634
# grid_index = (17, 23), time taken = 47.4902
# grid_index = (17, 24), time taken = 47.6000
# grid_index = (17, 25), time taken = 47.7256
# grid_index = (17, 26), time taken = 47.8514
# grid_index = (17, 27), time taken = 47.9802
# grid_index = (17, 29), time taken = 48.1034
# grid_index = (18, 2), time taken = 48.2295
# grid_index = (18, 3), time taken = 48.3552
# grid_index = (18, 4), time taken = 48.4810
# grid_index = (18, 5), time taken = 48.5962
# grid_index = (18, 6), time taken = 48.7224
# grid_index = (18, 7), time taken = 48.8482
# grid_index = (18, 8), time taken = 48.9739
# grid_index = (18, 9), time taken = 49.0999
# grid_index = (18, 10), time taken = 49.2264
# grid_index = (18, 11), time taken = 49.3515
# grid_index = (18, 12), time taken = 49.4610
# grid_index = (18, 13), time taken = 49.5869
# grid_index = (18, 14), time taken = 49.7135
# grid_index = (18, 15), time taken = 49.8389
# grid_index = (18, 16), time taken = 49.9648
# grid_index = (18, 17), time taken = 50.0909
# grid_index = (18, 18), time taken = 50.2166
# grid_index = (18, 19), time taken = 50.3428
# grid_index = (18, 20), time taken = 50.4685
# grid_index = (18, 21), time taken = 50.5847
# grid_index = (18, 22), time taken = 50.7048
# grid_index = (18, 23), time taken = 50.8313
# grid_index = (18, 24), time taken = 50.9569
# grid_index = (18, 25), time taken = 51.0851
# grid_index = (18, 26), time taken = 51.2088
# grid_index = (19, 1), time taken = 51.3353
# grid_index = (19, 2), time taken = 51.4454
# grid_index = (19, 3), time taken = 51.5709
# grid_index = (19, 4), time taken = 51.6969
# grid_index = (19, 5), time taken = 51.8230
# grid_index = (19, 6), time taken = 51.9487
# grid_index = (19, 7), time taken = 52.0754
# grid_index = (19, 8), time taken = 52.1863
# grid_index = (19, 9), time taken = 52.3114
# grid_index = (19, 10), time taken = 52.4374
# grid_index = (19, 11), time taken = 52.5628
# grid_index = (19, 12), time taken = 52.6901
# grid_index = (19, 13), time taken = 52.8155
# grid_index = (19, 14), time taken = 52.9412
# grid_index = (19, 15), time taken = 53.0668
# grid_index = (19, 16), time taken = 53.1935
# grid_index = (19, 17), time taken = 53.3191
# grid_index = (19, 18), time taken = 53.4457
# grid_index = (19, 19), time taken = 53.5653
# grid_index = (19, 20), time taken = 53.6915
# grid_index = (19, 21), time taken = 53.8171
# grid_index = (19, 22), time taken = 53.9271
# grid_index = (19, 23), time taken = 54.0532
# grid_index = (19, 24), time taken = 54.1870
# grid_index = (19, 25), time taken = 54.3052
# grid_index = (19, 26), time taken = 54.4309
# grid_index = (19, 27), time taken = 54.5562
# grid_index = (20, 1), time taken = 54.6813
# grid_index = (20, 2), time taken = 54.7916
# grid_index = (20, 3), time taken = 54.9173
# grid_index = (20, 4), time taken = 55.0434
# grid_index = (20, 5), time taken = 55.1702
# grid_index = (20, 6), time taken = 55.2958
# grid_index = (20, 7), time taken = 55.4236
# grid_index = (20, 8), time taken = 55.5493
# grid_index = (20, 9), time taken = 55.6593
# grid_index = (20, 10), time taken = 55.7893
# grid_index = (20, 11), time taken = 55.9108
# grid_index = (20, 12), time taken = 56.0375
# grid_index = (20, 13), time taken = 56.1629
# grid_index = (20, 14), time taken = 56.2896
# grid_index = (20, 15), time taken = 56.4151
# grid_index = (20, 16), time taken = 56.5420
# grid_index = (20, 17), time taken = 56.6678
# grid_index = (20, 18), time taken = 56.7942
# grid_index = (20, 19), time taken = 56.9044
# grid_index = (20, 20), time taken = 57.0310
# grid_index = (20, 21), time taken = 57.1571
# grid_index = (20, 22), time taken = 57.2840
# grid_index = (20, 23), time taken = 57.4111
# grid_index = (20, 24), time taken = 57.5367
# grid_index = (20, 25), time taken = 57.6624
# grid_index = (20, 26), time taken = 57.7880
# grid_index = (20, 27), time taken = 57.9144
# grid_index = (21, 3), time taken = 58.0241
# grid_index = (21, 4), time taken = 58.1496
# grid_index = (21, 5), time taken = 58.2753
# grid_index = (21, 6), time taken = 58.4020
# grid_index = (21, 7), time taken = 58.5351
# grid_index = (21, 8), time taken = 58.6612
# grid_index = (21, 9), time taken = 58.7712
# grid_index = (21, 10), time taken = 58.8970
# grid_index = (21, 11), time taken = 59.0226
# grid_index = (21, 12), time taken = 59.1482
# grid_index = (21, 13), time taken = 59.2734
# grid_index = (21, 14), time taken = 59.3997
# grid_index = (21, 15), time taken = 59.5258
# grid_index = (21, 16), time taken = 59.6518
# grid_index = (21, 17), time taken = 59.7619
# grid_index = (21, 18), time taken = 59.8956
# grid_index = (21, 19), time taken = 60.0140
# grid_index = (21, 20), time taken = 60.1406
# grid_index = (21, 21), time taken = 60.2666
# grid_index = (21, 22), time taken = 60.3926
# grid_index = (21, 23), time taken = 60.5186
# grid_index = (21, 24), time taken = 60.6287
# grid_index = (21, 25), time taken = 60.7543
# grid_index = (21, 26), time taken = 60.8797
# grid_index = (21, 27), time taken = 61.0057
# grid_index = (22, 4), time taken = 61.1324
# grid_index = (22, 5), time taken = 61.2583
# grid_index = (22, 7), time taken = 61.3842
# grid_index = (22, 8), time taken = 61.5102
# grid_index = (22, 9), time taken = 61.6359
# grid_index = (22, 10), time taken = 61.7616
# grid_index = (22, 11), time taken = 61.8716
# grid_index = (22, 12), time taken = 61.9971
# grid_index = (22, 13), time taken = 62.1222
# grid_index = (22, 14), time taken = 62.2475
# grid_index = (22, 15), time taken = 62.3734
# grid_index = (22, 16), time taken = 62.4993
# grid_index = (22, 17), time taken = 62.6251
# grid_index = (22, 18), time taken = 62.7507
# grid_index = (22, 19), time taken = 62.8764
# grid_index = (22, 20), time taken = 63.0024
# grid_index = (22, 21), time taken = 63.1283
# grid_index = (22, 22), time taken = 63.2544
# grid_index = (22, 23), time taken = 63.3644
# grid_index = (22, 24), time taken = 63.4995
# grid_index = (22, 25), time taken = 63.6153
# grid_index = (22, 26), time taken = 63.7409
# grid_index = (22, 27), time taken = 63.8670
# grid_index = (23, 8), time taken = 63.9996
# grid_index = (23, 10), time taken = 64.1209
# grid_index = (23, 11), time taken = 64.2463
# grid_index = (23, 12), time taken = 64.3722
# grid_index = (23, 13), time taken = 64.4999
# grid_index = (23, 14), time taken = 64.6241
# grid_index = (23, 15), time taken = 64.7341
# grid_index = (23, 16), time taken = 64.8597
# grid_index = (23, 17), time taken = 64.9852
# grid_index = (23, 18), time taken = 65.1109
# grid_index = (23, 19), time taken = 65.2363
# grid_index = (23, 20), time taken = 65.3617
# grid_index = (23, 21), time taken = 65.4873
# grid_index = (23, 22), time taken = 65.6135
# grid_index = (23, 23), time taken = 65.7401
# grid_index = (23, 24), time taken = 65.8669
# grid_index = (23, 25), time taken = 65.9926
# grid_index = (23, 26), time taken = 66.1186
# grid_index = (24, 4), time taken = 66.2444
# grid_index = (24, 8), time taken = 66.3699
# grid_index = (24, 10), time taken = 66.4957
# grid_index = (24, 11), time taken = 66.6055
# grid_index = (24, 12), time taken = 66.7309
# grid_index = (24, 13), time taken = 66.8726
# grid_index = (24, 14), time taken = 66.9980
# grid_index = (24, 15), time taken = 67.1087
# grid_index = (24, 16), time taken = 67.2342
# grid_index = (24, 17), time taken = 67.3599
# grid_index = (24, 18), time taken = 67.4859
# grid_index = (24, 19), time taken = 67.6119
# grid_index = (24, 20), time taken = 67.7380
# grid_index = (24, 21), time taken = 67.8652
# grid_index = (24, 22), time taken = 67.9914
# grid_index = (24, 23), time taken = 68.1141
# grid_index = (24, 24), time taken = 68.2384
# grid_index = (24, 25), time taken = 68.3628
# grid_index = (24, 26), time taken = 68.4796
# grid_index = (24, 27), time taken = 68.6121
# grid_index = (25, 9), time taken = 68.7362
# grid_index = (25, 10), time taken = 68.8602
# grid_index = (25, 12), time taken = 68.9842
# grid_index = (25, 13), time taken = 69.1076
# grid_index = (25, 14), time taken = 69.2322
# grid_index = (25, 15), time taken = 69.3541
# grid_index = (25, 16), time taken = 69.4795
# grid_index = (25, 17), time taken = 69.6027
# grid_index = (25, 18), time taken = 69.7273
# grid_index = (25, 19), time taken = 69.8483
# grid_index = (25, 20), time taken = 69.9724
# grid_index = (25, 21), time taken = 70.0963
# grid_index = (25, 22), time taken = 70.2217
# grid_index = (25, 23), time taken = 70.3462
# grid_index = (25, 24), time taken = 70.4706
# grid_index = (25, 26), time taken = 70.5953
# grid_index = (26, 9), time taken = 70.7201
# grid_index = (26, 11), time taken = 70.8411
# grid_index = (26, 12), time taken = 70.9652
# grid_index = (26, 13), time taken = 71.0878
# grid_index = (26, 14), time taken = 71.2089
# grid_index = (26, 15), time taken = 71.3378
# grid_index = (26, 16), time taken = 71.4540
# grid_index = (26, 17), time taken = 71.5904
# grid_index = (26, 18), time taken = 71.7099
# grid_index = (26, 19), time taken = 71.8382
# grid_index = (26, 20), time taken = 71.9562
# grid_index = (26, 21), time taken = 72.0820
# grid_index = (26, 22), time taken = 72.2107
# grid_index = (26, 23), time taken = 72.3347
# grid_index = (26, 25), time taken = 72.4449
# grid_index = (27, 13), time taken = 72.5705
# grid_index = (27, 14), time taken = 72.6960
# grid_index = (27, 15), time taken = 72.8214
# grid_index = (27, 16), time taken = 72.9471
# grid_index = (27, 17), time taken = 73.0727
# grid_index = (27, 18), time taken = 73.1902
# grid_index = (27, 19), time taken = 73.3162
# grid_index = (27, 20), time taken = 73.4433
# grid_index = (27, 21), time taken = 73.5695
# grid_index = (28, 14), time taken = 73.6960
# grid_index = (28, 16), time taken = 73.8221
# grid_index = (28, 19), time taken = 73.9481
# grid_index = (29, 13), time taken = 74.0581
# Time taken by calc_2D_prob is 74.11321592330933 seconds

# %%
n_subdivs = 100
mc0 = sim.MCProb(save_folder, n_subdivs, lambda X: mu(X).numpy(), sigma,\
                     X0 = rv0.sample(int(1e7)).numpy(), tick_size=20, title_size=20, cbar_tick_size=15)
mc0.ready(n_steps=0, dt=dt, lims=None)
grid = mc0.get_grid()
low = grid.mins
high = grid.maxs


x_ = np.linspace(low[0], high[0], num=n_subdivs, endpoint=True).astype('float32')
y_ = np.linspace(low[1], high[1], num=n_subdivs, endpoint=True).astype('float32')
z_ = np.linspace(low[2], high[2], num=n_subdivs, endpoint=True).astype('float32')

    
fig_all = plt.figure(figsize=(10, 20))
ax_1m = fig_all.add_subplot(111)
# ax_2m = fig_all.add_subplot(312) 
# ax_3m = fig_all.add_subplot(313)

div_4 = make_axes_locatable(ax_1m)
cax_4 = div_4.append_axes('right', '5%', '5%')
# div_5 = make_axes_locatable(ax_2m)
# cax_5 = div_5.append_axes('right', '5%', '5%')
# div_6 = make_axes_locatable(ax_3m)
# cax_6 = div_6.append_axes('right', '5%', '5%')

z_1m = mc0.compute_p2(0, 1, save=False)
z_1m  /= (z_1m.sum() * grid.h[0] * grid.h[1])
im = ax_1m.pcolormesh(x_, y_, z_1m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_1m.set_aspect("auto")


# z_2m = mc0.compute_p2(1, 2, save=False)
# z_2m  /= (z_2m.sum() * grid.h[1] * grid.h[2])
# im = ax_2m.pcolormesh(y_, z_, z_2m.T, cmap='inferno', shading='auto')
# cbar = fig_all.colorbar(im, cax=cax_5, ax=ax_2m)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_2m.set_aspect("auto")

# z_3m = mc0.compute_p2(2, 0, save=False)
# z_3m  /= (z_3m.sum() * grid.h[2] * grid.h[0])
# im = ax_3m.pcolormesh(z_, x_, z_3m.T, cmap='inferno', shading='auto')
# cbar = fig_all.colorbar(im, cax=cax_6, ax=ax_3m)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_3m.set_aspect("auto")

ax_1m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='minor', labelsize=tick_size)
# ax_2m.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_2m.tick_params(axis='both', which='minor', labelsize=tick_size)
# ax_3m.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_3m.tick_params(axis='both', which='minor', labelsize=tick_size)

ax_1m.set_title('Monte Carlo solution at time {:.2f}'.format(t), fontsize=title_size)
ax_1m.set_xlabel('x', fontsize=xlabel_size)
ax_1m.set_ylabel('y', fontsize=ylabel_size)
# ax_2m.set_xlabel('y', fontsize=xlabel_size)
# ax_2m.set_ylabel('z', fontsize=ylabel_size)
# ax_3m.set_xlabel('z', fontsize=xlabel_size)
# ax_3m.set_ylabel('x', fontsize=ylabel_size)

plt.tight_layout()
plt.savefig('../plots/L63-0.png')
# Out:
# Time taken by propagate is 20.990049839019775 seconds
# Time taken by set_grid is 27.98115301132202 seconds
# Time taken by assign_pts is 32.551573276519775 seconds
# Time taken by ready is 81.52277612686157 seconds
# Time taken by compute_p2 is 32.2434606552124 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16280/2401849671.py in <module>
#      29 im = ax_1m.pcolormesh(x_, y_, z_1m.T, cmap='inferno', shading='auto')
#      30 cbar = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
# ---> 31 cbar.ax.tick_params(labelsize=cbar_tick_size)
#      32 #cbar.formatter.set_powerlimits((0, 0))
#      33 ax_1m.set_aspect("auto")
#
# NameError: name 'cbar_tick_size' is not defined
