# %%
import os, sys
from pathlib import Path
script_dir = Path(os.path.dirname(os.path.abspath('')))
module_dir = str(script_dir)
sys.path.insert(0, module_dir + '/modules')
print(module_dir)

# import the rest of the modules
# %matplotlib nbagg
# %matplotlib inline
import numpy as np
import tensorflow as tf 
import matplotlib.pyplot as plt
import arch
import pandas as pd
import tensorflow_probability as tfp
import time  
import sim
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.animation as animation
from mpl_toolkits.axes_grid1 import make_axes_locatable


dim = 3
n_particles = int(1e5)
n_subdivs = 30
n_int_subdivs = 100
save_folder = '../non-grad3D/data/L63'
n_steps = 5
n_repeats = 100
dt = 0.01
alpha, beta, rho = 10., 8./3., 28.
sigma = 10.
D = sigma**2 / 2.
t = dt * n_steps
dtype = 'float32'


# define drift
def mu(X):
    x, y, z = tf.split(X, [1, 1, 1], axis=-1)
    p = alpha * (y - x)
    q = x * (rho - z) - y 
    r = x * y - beta * z 
    return tf.concat([p, q, r], axis=-1)

locs = 2.*np.array([[-1., -1., -1.], [1., 1., 1.]]).astype(dtype)
scales = np.array([[1., 1., 1.], [1., 1., 1.]]).astype(dtype)
weights = np.array([.5, .5]).astype(dtype)
Xs = [tfp.distributions.MultivariateNormalDiag(loc=locs[i], scale_diag=scales[i]) for i in range(len(locs))]
rv0 = tfp.distributions.Mixture(cat=tfp.distributions.Categorical(probs=weights), components=Xs)


X0 =  rv0.sample(n_particles).numpy()
mc_prob = sim.MCProb(save_folder, n_subdivs, lambda X: mu(X).numpy(), sigma,\
                     X0, tick_size=20, title_size=20, cbar_tick_size=15)
mc_prob.ready(n_steps=n_steps, dt=dt, lims=None)
# Out:
# C:\Users\pinak\Documents\GitHub\fp-solvers
# Time taken by propagate is 0.24831843376159668 seconds
# Time taken by set_grid is 0.2692718505859375 seconds
# Time taken by assign_pts is 0.31597375869750977 seconds
# Time taken by ready is 0.833564043045044 seconds

# %%
# set up plotting parameters
scale = 10
xlabel_size = ylabel_size = 15 + scale
tick_size = 10 + scale
legend_size = 15 + scale
title_size = 15 + scale
cbar_tick_size = 10 + scale

# %%
# load learned solution
dim = 3
n_theta = arch.LSTMForgetNet(50, 3, tf.float32, name="L63")
n_theta.load_weights('../non-grad3D/data/L63/1M/{}'.format(n_theta.name)).expect_partial()
X = tf.random.uniform(shape=(10, dim))
n_theta(*tf.split(X, dim, axis=-1))



grid = mc_prob.get_grid()
low = grid.mins
high = grid.maxs
filter = mc_prob.save_folder + '/ensemble.csv'
method = "Gauss_Legendre"
d = 4
max_comp = 1e6



x_ = np.linspace(low[0], high[0], num=n_subdivs, endpoint=True).astype('float32')
y_ = np.linspace(low[1], high[1], num=n_subdivs, endpoint=True).astype('float32')
z_ = np.linspace(low[2], high[2], num=n_subdivs, endpoint=True).astype('float32')

    
fig_all = plt.figure(figsize=(20, 20))
ax_1l = fig_all.add_subplot(321) 
ax_1m = fig_all.add_subplot(322)


ax_2l = fig_all.add_subplot(323) 
ax_2m = fig_all.add_subplot(324)

ax_3l = fig_all.add_subplot(325) 
ax_3m = fig_all.add_subplot(326)


div_1 = make_axes_locatable(ax_1l)
cax_1 = div_1.append_axes('right', '5%', '5%')
div_2 = make_axes_locatable(ax_2l)
cax_2 = div_2.append_axes('right', '5%', '5%')
div_3 = make_axes_locatable(ax_3l)
cax_3 = div_3.append_axes('right', '5%', '5%')

div_4 = make_axes_locatable(ax_1m)
cax_4 = div_4.append_axes('right', '5%', '5%')
div_5 = make_axes_locatable(ax_2m)
cax_5 = div_5.append_axes('right', '5%', '5%')
div_6 = make_axes_locatable(ax_3m)
cax_6 = div_6.append_axes('right', '5%', '5%')

z_1m = mc_prob.compute_p2(0, 1, save=False)
z_1m  /= (z_1m.sum() * grid.h[0] * grid.h[1])
im = ax_1m.pcolormesh(x_, y_, z_1m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_4, ax=ax_1m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_1m.set_aspect("auto")


z_2m = mc_prob.compute_p2(1, 2, save=False)
z_2m  /= (z_2m.sum() * grid.h[1] * grid.h[2])
im = ax_2m.pcolormesh(y_, z_, z_2m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_5, ax=ax_2m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_2m.set_aspect("auto")

z_3m = mc_prob.compute_p2(2, 0, save=False)
z_3m  /= (z_3m.sum() * grid.h[2] * grid.h[0])
im = ax_3m.pcolormesh(z_, x_, z_3m.T, cmap='inferno', shading='auto')
cbar = fig_all.colorbar(im, cax=cax_6, ax=ax_3m)
cbar.ax.tick_params(labelsize=cbar_tick_size)
#cbar.formatter.set_powerlimits((0, 0))
ax_3m.set_aspect("auto")

ax_1m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_1m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_2m.tick_params(axis='both', which='minor', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3m.tick_params(axis='both', which='minor', labelsize=tick_size)

ax_1m.set_title('Monte Carlo solution at time {:.2f}'.format(t), fontsize=title_size)
ax_1m.set_xlabel('x', fontsize=xlabel_size)
ax_1m.set_ylabel('y', fontsize=ylabel_size)
ax_2m.set_xlabel('y', fontsize=xlabel_size)
ax_2m.set_ylabel('z', fontsize=ylabel_size)
ax_3m.set_xlabel('z', fontsize=xlabel_size)
ax_3m.set_ylabel('x', fontsize=ylabel_size)



fk = sim.FKRec(save_folder='.', n_subdivs=n_subdivs, n_int_subdivs=n_int_subdivs, mu=mu, sigma=sigma,\
               n_theta=n_theta, grid=grid, log_p0=lambda x: tf.reshape(rv0.log_prob(x), (-1, 1)), max_comp=max_comp)


# z_1l = fk.calc_2D_prob(n_steps, dt, n_repeats, 0, 1, filter, method=method, num=n_int_subdivs, d=d)
# ax_1l.clear()
# cax_1.cla()
# z_1l /= (z_1l.sum() * grid.h[0] * grid.h[1])
# im = ax_1l.pcolormesh(x_, y_, z_1l.T, cmap='inferno', shading='auto')
# ax_1l.set_title('Learned solution at time = {:.2f}'.format(t), fontsize=title_size)
# ax_1l.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_1l.tick_params(axis='both', which='minor', labelsize=tick_size)
# cbar = fig_all.colorbar(im, cax=cax_1, ax=ax_1l)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_1l.set_aspect("auto")



# z_2l = fk.calc_2D_prob(n_steps, dt, n_repeats, 1, 2, filter, method=method, num=n_int_subdivs, d=d)
# ax_2l.clear()
# cax_2.cla() 
# z_2l /= (z_2l.sum() *  grid.h[1] * grid.h[2])
# im = ax_2l.pcolormesh(y_, z_, z_2l.T, cmap='inferno')
# ax_2l.tick_params(axis='both', which='major', labelsize=tick_size)
# ax_2l.tick_params(axis='both', which='minor', labelsize=tick_size)
# cbar = fig_all.colorbar(im, cax=cax_2, ax=ax_2l)
# cbar.ax.tick_params(labelsize=cbar_tick_size)
# #cbar.formatter.set_powerlimits((0, 0))
# ax_2l.set_aspect("auto")


z_3l = fk.calc_2D_prob(n_steps, dt, n_repeats, 2, 0, filter, method=method, num=n_int_subdivs, d=d)
ax_3l.clear()
cax_3.cla()
z_3l /= (z_3l.sum() *  grid.h[2] * grid.h[0])
im = ax_3l.pcolormesh(z_, x_, z_3l.T, cmap='inferno')
ax_3l.tick_params(axis='both', which='major', labelsize=tick_size)
ax_3l.tick_params(axis='both', which='minor', labelsize=tick_size)
cbar = fig_all.colorbar(im, cax=cax_3, ax=ax_3l)
cbar.ax.tick_params(labelsize=cbar_tick_size)
ax_3l.set_aspect("auto")
fig_all.subplots_adjust(wspace=0.5, hspace=0.4)

ax_1l.set_ylabel(r'$p(x, y)$', fontsize=ylabel_size)
ax_2l.set_ylabel(r'$p(y, z)$', fontsize=ylabel_size)
ax_3l.set_ylabel(r'$p(z, x)$', fontsize=ylabel_size)
plt.tight_layout()
plt.savefig('../plots/L63-time.png')
# Out:
# Time taken by compute_p2 is 0.2768411636352539 seconds
# Time taken by compute_p2 is 0.2891411781311035 seconds
# Time taken by compute_p2 is 0.28046751022338867 seconds
# Time taken by set_filter is 0.2991800308227539 seconds
# grid_index = (0, 13), time taken = 0.8109
# grid_index = (0, 14), time taken = 0.9394
# grid_index = (1, 9), time taken = 1.0639
# grid_index = (1, 11), time taken = 1.1846
# grid_index = (1, 14), time taken = 1.3091
# grid_index = (1, 17), time taken = 1.4337
# grid_index = (2, 9), time taken = 1.5591
# grid_index = (2, 10), time taken = 1.6798
# grid_index = (2, 11), time taken = 1.8034
# grid_index = (2, 13), time taken = 1.9277
# grid_index = (2, 14), time taken = 2.0521
# grid_index = (2, 15), time taken = 2.1720
# grid_index = (2, 20), time taken = 2.2960
# grid_index = (3, 8), time taken = 2.4208
# grid_index = (3, 10), time taken = 2.5447
# grid_index = (3, 11), time taken = 2.6702
# grid_index = (3, 12), time taken = 2.7958
# grid_index = (3, 13), time taken = 2.9171
# grid_index = (3, 14), time taken = 3.0418
# grid_index = (3, 15), time taken = 3.1656
# grid_index = (3, 16), time taken = 3.2895
# grid_index = (3, 17), time taken = 3.4136
# grid_index = (3, 18), time taken = 3.5383
# grid_index = (3, 23), time taken = 3.6631
# grid_index = (4, 8), time taken = 3.7890
# grid_index = (4, 9), time taken = 3.9130
# grid_index = (4, 10), time taken = 4.0411
# grid_index = (4, 11), time taken = 4.1630
# grid_index = (4, 12), time taken = 4.2905
# grid_index = (4, 13), time taken = 4.4150
# grid_index = (4, 14), time taken = 4.5357
# grid_index = (4, 15), time taken = 4.6598
# grid_index = (4, 16), time taken = 4.7836
# grid_index = (4, 17), time taken = 4.9110
# grid_index = (4, 18), time taken = 5.0324
# grid_index = (4, 19), time taken = 5.1569
# grid_index = (4, 21), time taken = 5.2804
# grid_index = (4, 22), time taken = 5.4013
# grid_index = (5, 3), time taken = 5.5260
# grid_index = (5, 5), time taken = 5.6538
# grid_index = (5, 6), time taken = 5.7819
# grid_index = (5, 7), time taken = 5.9059
# grid_index = (5, 8), time taken = 6.0301
# grid_index = (5, 9), time taken = 6.1537
# grid_index = (5, 10), time taken = 6.2759
# grid_index = (5, 11), time taken = 6.4004
# grid_index = (5, 12), time taken = 6.5252
# grid_index = (5, 13), time taken = 6.6503
# grid_index = (5, 14), time taken = 6.7743
# grid_index = (5, 15), time taken = 6.8951
# grid_index = (5, 16), time taken = 7.0200
# grid_index = (5, 17), time taken = 7.1441
# grid_index = (5, 18), time taken = 7.2685
# grid_index = (5, 19), time taken = 7.3891
# grid_index = (5, 21), time taken = 7.5166
# grid_index = (5, 22), time taken = 7.6407
# grid_index = (6, 4), time taken = 7.7624
# grid_index = (6, 6), time taken = 7.8865
# grid_index = (6, 7), time taken = 8.0119
# grid_index = (6, 8), time taken = 8.1361
# grid_index = (6, 9), time taken = 8.2611
# grid_index = (6, 10), time taken = 8.3815
# grid_index = (6, 11), time taken = 8.5090
# grid_index = (6, 12), time taken = 8.6331
# grid_index = (6, 13), time taken = 8.7572
# grid_index = (6, 14), time taken = 8.8853
# grid_index = (6, 15), time taken = 9.0068
# grid_index = (6, 16), time taken = 9.1308
# grid_index = (6, 17), time taken = 9.2549
# grid_index = (6, 18), time taken = 9.3765
# grid_index = (6, 19), time taken = 9.5012
# grid_index = (6, 20), time taken = 9.6244
# grid_index = (6, 21), time taken = 9.7480
# grid_index = (6, 22), time taken = 9.8725
# grid_index = (6, 24), time taken = 9.9962
# grid_index = (7, 3), time taken = 10.1201
# grid_index = (7, 4), time taken = 10.2402
# grid_index = (7, 6), time taken = 10.3646
# grid_index = (7, 7), time taken = 10.4895
# grid_index = (7, 8), time taken = 10.6152
# grid_index = (7, 9), time taken = 10.7391
# grid_index = (7, 10), time taken = 10.8652
# grid_index = (7, 11), time taken = 10.9916
# grid_index = (7, 12), time taken = 11.1143
# grid_index = (7, 13), time taken = 11.2387
# grid_index = (7, 14), time taken = 11.3633
# grid_index = (7, 15), time taken = 11.4874
# grid_index = (7, 16), time taken = 11.6119
# grid_index = (7, 17), time taken = 11.7370
# grid_index = (7, 18), time taken = 11.8571
# grid_index = (7, 19), time taken = 11.9812
# grid_index = (7, 20), time taken = 12.1081
# grid_index = (7, 21), time taken = 12.2284
# grid_index = (7, 22), time taken = 12.3552
# grid_index = (7, 23), time taken = 12.4809
# grid_index = (8, 5), time taken = 12.6041
# grid_index = (8, 6), time taken = 12.7289
# grid_index = (8, 7), time taken = 12.8533
# grid_index = (8, 8), time taken = 12.9789
# grid_index = (8, 9), time taken = 13.1026
# grid_index = (8, 10), time taken = 13.2262
# grid_index = (8, 11), time taken = 13.3511
# grid_index = (8, 12), time taken = 13.4764
# grid_index = (8, 13), time taken = 13.6012
# grid_index = (8, 14), time taken = 13.7268
# grid_index = (8, 15), time taken = 13.8514
# grid_index = (8, 16), time taken = 13.9754
# grid_index = (8, 17), time taken = 14.0999
# grid_index = (8, 18), time taken = 14.2207
# grid_index = (8, 19), time taken = 14.3488
# grid_index = (8, 20), time taken = 14.4724
# grid_index = (8, 21), time taken = 14.5950
# grid_index = (8, 22), time taken = 14.7199
# grid_index = (8, 23), time taken = 14.8449
# grid_index = (8, 24), time taken = 14.9712
# grid_index = (9, 3), time taken = 15.0947
# grid_index = (9, 4), time taken = 15.2177
# grid_index = (9, 5), time taken = 15.3402
# grid_index = (9, 6), time taken = 15.4638
# grid_index = (9, 7), time taken = 15.5879
# grid_index = (9, 8), time taken = 15.7088
# grid_index = (9, 9), time taken = 15.8331
# grid_index = (9, 10), time taken = 15.9566
# grid_index = (9, 11), time taken = 16.0808
# grid_index = (9, 12), time taken = 16.2048
# grid_index = (9, 13), time taken = 16.3289
# grid_index = (9, 14), time taken = 16.4515
# grid_index = (9, 15), time taken = 16.5757
# grid_index = (9, 16), time taken = 16.7026
# grid_index = (9, 17), time taken = 16.8251
# grid_index = (9, 18), time taken = 16.9493
# grid_index = (9, 19), time taken = 17.0742
# grid_index = (9, 20), time taken = 17.1985
# grid_index = (9, 21), time taken = 17.3230
# grid_index = (9, 22), time taken = 17.4439
# grid_index = (9, 23), time taken = 17.5676
# grid_index = (9, 24), time taken = 17.6929
# grid_index = (10, 4), time taken = 17.8160
# grid_index = (10, 5), time taken = 17.9405
# grid_index = (10, 6), time taken = 18.0648
# grid_index = (10, 7), time taken = 18.1893
# grid_index = (10, 8), time taken = 18.3136
# grid_index = (10, 9), time taken = 18.4416
# grid_index = (10, 10), time taken = 18.5661
# grid_index = (10, 11), time taken = 18.6907
# grid_index = (10, 12), time taken = 18.8116
# grid_index = (10, 13), time taken = 18.9365
# grid_index = (10, 14), time taken = 19.0605
# grid_index = (10, 15), time taken = 19.1887
# grid_index = (10, 16), time taken = 19.3120
# grid_index = (10, 17), time taken = 19.4339
# grid_index = (10, 18), time taken = 19.5579
# grid_index = (10, 19), time taken = 19.6819
# grid_index = (10, 20), time taken = 19.8061
# grid_index = (10, 21), time taken = 19.9317
# grid_index = (10, 22), time taken = 20.0517
# grid_index = (10, 23), time taken = 20.1758
# grid_index = (10, 24), time taken = 20.3014
# grid_index = (10, 26), time taken = 20.4257
# grid_index = (11, 3), time taken = 20.5498
# grid_index = (11, 4), time taken = 20.6738
# grid_index = (11, 5), time taken = 20.7979
# grid_index = (11, 6), time taken = 20.9195
# grid_index = (11, 7), time taken = 21.0440
# grid_index = (11, 8), time taken = 21.1719
# grid_index = (11, 9), time taken = 21.2920
# grid_index = (11, 10), time taken = 21.4160
# grid_index = (11, 11), time taken = 21.5449
# grid_index = (11, 12), time taken = 21.6688
# grid_index = (11, 13), time taken = 21.7936
# grid_index = (11, 14), time taken = 21.9177
# grid_index = (11, 15), time taken = 22.0393
# grid_index = (11, 16), time taken = 22.1670
# grid_index = (11, 17), time taken = 22.2874
# grid_index = (11, 18), time taken = 22.4128
# grid_index = (11, 19), time taken = 22.5374
# grid_index = (11, 20), time taken = 22.6611
# grid_index = (11, 21), time taken = 22.7852
# grid_index = (11, 22), time taken = 22.9095
# grid_index = (11, 23), time taken = 23.0335
# grid_index = (11, 24), time taken = 23.1578
# grid_index = (11, 25), time taken = 23.2819
# grid_index = (12, 0), time taken = 23.4063
# grid_index = (12, 1), time taken = 23.5295
# grid_index = (12, 3), time taken = 23.6576
# grid_index = (12, 4), time taken = 23.7817
# grid_index = (12, 5), time taken = 23.9058
# grid_index = (12, 6), time taken = 24.0310
# grid_index = (12, 7), time taken = 24.1547
# grid_index = (12, 8), time taken = 24.2791
# grid_index = (12, 9), time taken = 24.4034
# grid_index = (12, 10), time taken = 24.5234
# grid_index = (12, 11), time taken = 24.6479
# grid_index = (12, 12), time taken = 24.7723
# grid_index = (12, 13), time taken = 24.8973
# grid_index = (12, 14), time taken = 25.0216
# grid_index = (12, 15), time taken = 25.1492
# grid_index = (12, 16), time taken = 25.2733
# grid_index = (12, 17), time taken = 25.3957
# grid_index = (12, 18), time taken = 25.5214
# grid_index = (12, 19), time taken = 25.6454
# grid_index = (12, 20), time taken = 25.7699
# grid_index = (12, 21), time taken = 25.8942
# grid_index = (12, 22), time taken = 26.0158
# grid_index = (12, 23), time taken = 26.1396
# grid_index = (12, 24), time taken = 26.2637
# grid_index = (12, 25), time taken = 26.3878
# grid_index = (12, 26), time taken = 26.5123
# grid_index = (12, 29), time taken = 26.6368
# grid_index = (13, 3), time taken = 26.7609
# grid_index = (13, 4), time taken = 26.8850
# grid_index = (13, 5), time taken = 27.0094
# grid_index = (13, 6), time taken = 27.1305
# grid_index = (13, 7), time taken = 27.2548
# grid_index = (13, 8), time taken = 27.3789
# grid_index = (13, 9), time taken = 27.5038
# grid_index = (13, 10), time taken = 27.6248
# grid_index = (13, 11), time taken = 27.7524
# grid_index = (13, 12), time taken = 27.8774
# grid_index = (13, 13), time taken = 28.0033
# grid_index = (13, 14), time taken = 28.1258
# grid_index = (13, 15), time taken = 28.2500
# grid_index = (13, 16), time taken = 28.3742
# grid_index = (13, 17), time taken = 28.4991
# grid_index = (13, 18), time taken = 28.6247
# grid_index = (13, 19), time taken = 28.7539
# grid_index = (13, 20), time taken = 28.8745
# grid_index = (13, 21), time taken = 29.0017
# grid_index = (13, 22), time taken = 29.1264
# grid_index = (13, 23), time taken = 29.2506
# grid_index = (13, 24), time taken = 29.3715
# grid_index = (13, 25), time taken = 29.4959
# grid_index = (13, 26), time taken = 29.6199
# grid_index = (13, 27), time taken = 29.7415
# grid_index = (14, 1), time taken = 29.8682
# grid_index = (14, 2), time taken = 29.9934
# grid_index = (14, 3), time taken = 30.1173
# grid_index = (14, 4), time taken = 30.2374
# grid_index = (14, 5), time taken = 30.3616
# grid_index = (14, 6), time taken = 30.4858
# grid_index = (14, 7), time taken = 30.6100
# grid_index = (14, 8), time taken = 30.7305
# grid_index = (14, 9), time taken = 30.8546
# grid_index = (14, 10), time taken = 30.9786
# grid_index = (14, 11), time taken = 31.1027
# grid_index = (14, 12), time taken = 31.2295
# grid_index = (14, 13), time taken = 31.3534
# grid_index = (14, 14), time taken = 31.4735
# grid_index = (14, 15), time taken = 31.5986
# grid_index = (14, 16), time taken = 31.7237
# grid_index = (14, 17), time taken = 31.8455
# grid_index = (14, 18), time taken = 31.9700
# grid_index = (14, 19), time taken = 32.0962
# grid_index = (14, 20), time taken = 32.2193
# grid_index = (14, 21), time taken = 32.3448
# grid_index = (14, 22), time taken = 32.4683
# grid_index = (14, 23), time taken = 32.5900
# grid_index = (14, 24), time taken = 32.7151
# grid_index = (14, 25), time taken = 32.8394
# grid_index = (14, 26), time taken = 32.9638
# grid_index = (14, 28), time taken = 33.0878
# grid_index = (15, 3), time taken = 33.2172
# grid_index = (15, 4), time taken = 33.3417
# grid_index = (15, 5), time taken = 33.4657
# grid_index = (15, 6), time taken = 33.5867
# grid_index = (15, 7), time taken = 33.7116
# grid_index = (15, 8), time taken = 33.8352
# grid_index = (15, 9), time taken = 33.9605
# grid_index = (15, 10), time taken = 34.0859
# grid_index = (15, 11), time taken = 34.2111
# grid_index = (15, 12), time taken = 34.3348
# grid_index = (15, 13), time taken = 34.4595
# grid_index = (15, 14), time taken = 34.5840
# grid_index = (15, 15), time taken = 34.7061
# grid_index = (15, 16), time taken = 34.8306
# grid_index = (15, 17), time taken = 34.9547
# grid_index = (15, 18), time taken = 35.0827
# grid_index = (15, 19), time taken = 35.2075
# grid_index = (15, 20), time taken = 35.3310
# grid_index = (15, 21), time taken = 35.4553
# grid_index = (15, 22), time taken = 35.5770
# grid_index = (15, 23), time taken = 35.7023
# grid_index = (15, 24), time taken = 35.8269
# grid_index = (15, 25), time taken = 35.9514
# grid_index = (15, 26), time taken = 36.0781
# grid_index = (15, 27), time taken = 36.2020
# grid_index = (16, 2), time taken = 36.3260
# grid_index = (16, 3), time taken = 36.4461
# grid_index = (16, 4), time taken = 36.5742
# grid_index = (16, 5), time taken = 36.6962
# grid_index = (16, 6), time taken = 36.8205
# grid_index = (16, 7), time taken = 36.9494
# grid_index = (16, 8), time taken = 37.0735
# grid_index = (16, 9), time taken = 37.1943
# grid_index = (16, 10), time taken = 37.3178
# grid_index = (16, 11), time taken = 37.4437
# grid_index = (16, 12), time taken = 37.5668
# grid_index = (16, 13), time taken = 37.6903
# grid_index = (16, 14), time taken = 37.8150
# grid_index = (16, 15), time taken = 37.9373
# grid_index = (16, 16), time taken = 38.0618
# grid_index = (16, 17), time taken = 38.1858
# grid_index = (16, 18), time taken = 38.3139
# grid_index = (16, 19), time taken = 38.4362
# grid_index = (16, 20), time taken = 38.5619
# grid_index = (16, 21), time taken = 38.6857
# grid_index = (16, 22), time taken = 38.8118
# grid_index = (16, 23), time taken = 38.9366
# grid_index = (16, 24), time taken = 39.0605
# grid_index = (16, 25), time taken = 39.1886
# grid_index = (16, 26), time taken = 39.3097
# grid_index = (17, 1), time taken = 39.4343
# grid_index = (17, 2), time taken = 39.5598
# grid_index = (17, 3), time taken = 39.6810
# grid_index = (17, 4), time taken = 39.8058
# grid_index = (17, 5), time taken = 39.9307
# grid_index = (17, 6), time taken = 40.0544
# grid_index = (17, 7), time taken = 40.1826
# grid_index = (17, 8), time taken = 40.3062
# grid_index = (17, 9), time taken = 40.4261
# grid_index = (17, 10), time taken = 40.5516
# grid_index = (17, 11), time taken = 40.6790
# grid_index = (17, 12), time taken = 40.8052
# grid_index = (17, 13), time taken = 40.9272
# grid_index = (17, 14), time taken = 41.0522
# grid_index = (17, 15), time taken = 41.1763
# grid_index = (17, 16), time taken = 41.3004
# grid_index = (17, 17), time taken = 41.4245
# grid_index = (17, 18), time taken = 41.5451
# grid_index = (17, 19), time taken = 41.6745
# grid_index = (17, 20), time taken = 41.7972
# grid_index = (17, 21), time taken = 41.9249
# grid_index = (17, 22), time taken = 42.0504
# grid_index = (17, 23), time taken = 42.1749
# grid_index = (17, 24), time taken = 42.3016
# grid_index = (17, 25), time taken = 42.4257
# grid_index = (17, 26), time taken = 42.5500
# grid_index = (17, 27), time taken = 42.6744
# grid_index = (17, 28), time taken = 42.7980
# grid_index = (18, 2), time taken = 42.9242
# grid_index = (18, 4), time taken = 43.0525
# grid_index = (18, 5), time taken = 43.1786
# grid_index = (18, 6), time taken = 43.2994
# grid_index = (18, 7), time taken = 43.4283
# grid_index = (18, 8), time taken = 43.5535
# grid_index = (18, 9), time taken = 43.6784
# grid_index = (18, 10), time taken = 43.8039
# grid_index = (18, 11), time taken = 43.9278
# grid_index = (18, 12), time taken = 44.0519
# grid_index = (18, 13), time taken = 44.1813
# grid_index = (18, 14), time taken = 44.3023
# grid_index = (18, 15), time taken = 44.4271
# grid_index = (18, 16), time taken = 44.5509
# grid_index = (18, 17), time taken = 44.6750
# grid_index = (18, 18), time taken = 44.7991
# grid_index = (18, 19), time taken = 44.9237
# grid_index = (18, 20), time taken = 45.0495
# grid_index = (18, 21), time taken = 45.1724
# grid_index = (18, 22), time taken = 45.2966
# grid_index = (18, 23), time taken = 45.4221
# grid_index = (18, 24), time taken = 45.5474
# grid_index = (18, 25), time taken = 45.6721
# grid_index = (18, 26), time taken = 45.7987
# grid_index = (18, 28), time taken = 45.9266
# grid_index = (19, 3), time taken = 46.0501
# grid_index = (19, 4), time taken = 46.1746
# grid_index = (19, 5), time taken = 46.3024
# grid_index = (19, 6), time taken = 46.4269
# grid_index = (19, 7), time taken = 46.5517
# grid_index = (19, 8), time taken = 46.6762
# grid_index = (19, 9), time taken = 46.8003
# grid_index = (19, 10), time taken = 46.9265
# grid_index = (19, 11), time taken = 47.0521
# grid_index = (19, 12), time taken = 47.1769
# grid_index = (19, 13), time taken = 47.3010
# grid_index = (19, 14), time taken = 47.4251
# grid_index = (19, 15), time taken = 47.5532
# grid_index = (19, 16), time taken = 47.6742
# grid_index = (19, 17), time taken = 47.8019
# grid_index = (19, 18), time taken = 47.9260
# grid_index = (19, 19), time taken = 48.0461
# grid_index = (19, 20), time taken = 48.1738
# grid_index = (19, 21), time taken = 48.2986
# grid_index = (19, 22), time taken = 48.4218
# grid_index = (19, 23), time taken = 48.5480
# grid_index = (19, 24), time taken = 48.6718
# grid_index = (19, 25), time taken = 48.7991
# grid_index = (19, 26), time taken = 48.9208
# grid_index = (19, 27), time taken = 49.0458
# grid_index = (19, 29), time taken = 49.1748
# grid_index = (20, 3), time taken = 49.2973
# grid_index = (20, 4), time taken = 49.4253
# grid_index = (20, 5), time taken = 49.5493
# grid_index = (20, 6), time taken = 49.6743
# grid_index = (20, 7), time taken = 49.7980
# grid_index = (20, 8), time taken = 49.9224
# grid_index = (20, 9), time taken = 50.0505
# grid_index = (20, 10), time taken = 50.1736
# grid_index = (20, 11), time taken = 50.2964
# grid_index = (20, 12), time taken = 50.4230
# grid_index = (20, 13), time taken = 50.5431
# grid_index = (20, 14), time taken = 50.6675
# grid_index = (20, 15), time taken = 50.7916
# grid_index = (20, 16), time taken = 50.9167
# grid_index = (20, 17), time taken = 51.0443
# grid_index = (20, 18), time taken = 51.1692
# grid_index = (20, 19), time taken = 51.2908
# grid_index = (20, 20), time taken = 51.4149
# grid_index = (20, 21), time taken = 51.5390
# grid_index = (20, 22), time taken = 51.6648
# grid_index = (20, 23), time taken = 51.7902
# grid_index = (20, 24), time taken = 51.9150
# grid_index = (20, 25), time taken = 52.0393
# grid_index = (20, 26), time taken = 52.1641
# grid_index = (20, 27), time taken = 52.2900
# grid_index = (20, 28), time taken = 52.4177
# grid_index = (21, 4), time taken = 52.5418
# grid_index = (21, 5), time taken = 52.6678
# grid_index = (21, 6), time taken = 52.7918
# grid_index = (21, 7), time taken = 52.9169
# grid_index = (21, 8), time taken = 53.0473
# grid_index = (21, 9), time taken = 53.1727
# grid_index = (21, 10), time taken = 53.2966
# grid_index = (21, 11), time taken = 53.4214
# grid_index = (21, 12), time taken = 53.5451
# grid_index = (21, 13), time taken = 53.6692
# grid_index = (21, 14), time taken = 53.7936
# grid_index = (21, 15), time taken = 53.9220
# grid_index = (21, 16), time taken = 54.0430
# grid_index = (21, 17), time taken = 54.1671
# grid_index = (21, 18), time taken = 54.2912
# grid_index = (21, 19), time taken = 54.4158
# grid_index = (21, 20), time taken = 54.5414
# grid_index = (21, 21), time taken = 54.6667
# grid_index = (21, 22), time taken = 54.7905
# grid_index = (21, 23), time taken = 54.9189
# grid_index = (21, 24), time taken = 55.0440
# grid_index = (21, 25), time taken = 55.1656
# grid_index = (21, 26), time taken = 55.2917
# grid_index = (21, 27), time taken = 55.4158
# grid_index = (22, 5), time taken = 55.5429
# grid_index = (22, 6), time taken = 55.6672
# grid_index = (22, 7), time taken = 55.7910
# grid_index = (22, 8), time taken = 55.9146
# grid_index = (22, 9), time taken = 56.0423
# grid_index = (22, 10), time taken = 56.1671
# grid_index = (22, 11), time taken = 56.2923
# grid_index = (22, 12), time taken = 56.4167
# grid_index = (22, 13), time taken = 56.5414
# grid_index = (22, 14), time taken = 56.6674
# grid_index = (22, 15), time taken = 56.7911
# grid_index = (22, 16), time taken = 56.9152
# grid_index = (22, 17), time taken = 57.0393
# grid_index = (22, 18), time taken = 57.1681
# grid_index = (22, 19), time taken = 57.2930
# grid_index = (22, 20), time taken = 57.4176
# grid_index = (22, 21), time taken = 57.5437
# grid_index = (22, 22), time taken = 57.6700
# grid_index = (22, 23), time taken = 57.7939
# grid_index = (22, 24), time taken = 57.9225
# grid_index = (22, 25), time taken = 58.0466
# grid_index = (22, 26), time taken = 58.1720
# grid_index = (23, 4), time taken = 58.2968
# grid_index = (23, 5), time taken = 58.4205
# grid_index = (23, 6), time taken = 58.5446
# grid_index = (23, 7), time taken = 58.6687
# grid_index = (23, 8), time taken = 58.7914
# grid_index = (23, 9), time taken = 58.9150
# grid_index = (23, 10), time taken = 59.0392
# grid_index = (23, 11), time taken = 59.1662
# grid_index = (23, 12), time taken = 59.2880
# grid_index = (23, 13), time taken = 59.4121
# grid_index = (23, 14), time taken = 59.5367
# grid_index = (23, 15), time taken = 59.6608
# grid_index = (23, 16), time taken = 59.7855
# grid_index = (23, 17), time taken = 59.9088
# grid_index = (23, 18), time taken = 60.0339
# grid_index = (23, 19), time taken = 60.1588
# grid_index = (23, 20), time taken = 60.2835
# grid_index = (23, 21), time taken = 60.4082
# grid_index = (23, 22), time taken = 60.5323
# grid_index = (23, 23), time taken = 60.6581
# grid_index = (23, 24), time taken = 60.7826
# grid_index = (23, 25), time taken = 60.9072
# grid_index = (23, 26), time taken = 61.0313
# grid_index = (24, 5), time taken = 61.1562
# grid_index = (24, 6), time taken = 61.2799
# grid_index = (24, 7), time taken = 61.4040
# grid_index = (24, 8), time taken = 61.5321
# grid_index = (24, 9), time taken = 61.6522
# grid_index = (24, 10), time taken = 61.7758
# grid_index = (24, 11), time taken = 61.9042
# grid_index = (24, 12), time taken = 62.0254
# grid_index = (24, 13), time taken = 62.1520
# grid_index = (24, 14), time taken = 62.2765
# grid_index = (24, 15), time taken = 62.4011
# grid_index = (24, 16), time taken = 62.5262
# grid_index = (24, 17), time taken = 62.6503
# grid_index = (24, 18), time taken = 62.7747
# grid_index = (24, 19), time taken = 62.8988
# grid_index = (24, 20), time taken = 63.0229
# grid_index = (24, 21), time taken = 63.1445
# grid_index = (24, 22), time taken = 63.2687
# grid_index = (24, 23), time taken = 63.3968
# grid_index = (24, 25), time taken = 63.5209
# grid_index = (24, 26), time taken = 63.6450
# grid_index = (25, 2), time taken = 63.7662
# grid_index = (25, 7), time taken = 63.8913
# grid_index = (25, 8), time taken = 64.0154
# grid_index = (25, 9), time taken = 64.1428
# grid_index = (25, 10), time taken = 64.2656
# grid_index = (25, 11), time taken = 64.3912
# grid_index = (25, 12), time taken = 64.5190
# grid_index = (25, 13), time taken = 64.6444
# grid_index = (25, 14), time taken = 64.7683
# grid_index = (25, 15), time taken = 64.8932
# grid_index = (25, 16), time taken = 65.0171
# grid_index = (25, 17), time taken = 65.1453
# grid_index = (25, 18), time taken = 65.2694
# grid_index = (25, 19), time taken = 65.3935
# grid_index = (25, 20), time taken = 65.5180
# grid_index = (25, 21), time taken = 65.6396
# grid_index = (25, 22), time taken = 65.7641
# grid_index = (25, 23), time taken = 65.8888
# grid_index = (25, 24), time taken = 66.0099
# grid_index = (25, 25), time taken = 66.1362
# grid_index = (26, 9), time taken = 66.2614
# grid_index = (26, 11), time taken = 66.3867
# grid_index = (26, 12), time taken = 66.5125
# grid_index = (26, 13), time taken = 66.6361
# grid_index = (26, 14), time taken = 66.7603
# grid_index = (26, 15), time taken = 66.8803
# grid_index = (26, 16), time taken = 67.0072
# grid_index = (26, 17), time taken = 67.1313
# grid_index = (26, 18), time taken = 67.2567
# grid_index = (26, 19), time taken = 67.3810
# grid_index = (26, 20), time taken = 67.5099
# grid_index = (26, 21), time taken = 67.6342
# grid_index = (26, 22), time taken = 67.7583
# grid_index = (26, 23), time taken = 67.8839
# grid_index = (26, 24), time taken = 68.0044
# grid_index = (26, 26), time taken = 68.1285
# grid_index = (26, 28), time taken = 68.2516
# grid_index = (27, 11), time taken = 68.3776
# grid_index = (27, 13), time taken = 68.5043
# grid_index = (27, 14), time taken = 68.6269
# grid_index = (27, 15), time taken = 68.7516
# grid_index = (27, 16), time taken = 68.8752
# grid_index = (27, 17), time taken = 68.9993
# grid_index = (27, 18), time taken = 69.1243
# grid_index = (27, 19), time taken = 69.2522
# grid_index = (27, 20), time taken = 69.3754
# grid_index = (27, 21), time taken = 69.4997
# grid_index = (27, 22), time taken = 69.6273
# grid_index = (27, 23), time taken = 69.7490
# grid_index = (27, 24), time taken = 69.8743
# grid_index = (27, 26), time taken = 69.9992
# grid_index = (28, 12), time taken = 70.1230
# grid_index = (28, 13), time taken = 70.2480
# grid_index = (28, 14), time taken = 70.3721
# grid_index = (28, 16), time taken = 70.4967
# grid_index = (28, 17), time taken = 70.6207
# grid_index = (28, 18), time taken = 70.7449
# grid_index = (28, 19), time taken = 70.8698
# grid_index = (28, 20), time taken = 70.9960
# grid_index = (28, 21), time taken = 71.1208
# grid_index = (28, 22), time taken = 71.2429
# grid_index = (29, 12), time taken = 71.3722
# grid_index = (29, 15), time taken = 71.4962
# grid_index = (29, 16), time taken = 71.6206
# grid_index = (29, 17), time taken = 71.7450
# grid_index = (29, 18), time taken = 71.8712
# grid_index = (29, 24), time taken = 71.9968
# Time taken by calc_2D_prob is 72.0371880531311 seconds
